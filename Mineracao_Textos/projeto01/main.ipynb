# %%
import sys
import os

# Obtém o caminho do diretório do script atual
script_dir = os.getcwd()

# Adiciona o diretório pai ao caminho do sistema
sys.path.append(script_dir)

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Leia o arquivo CSV
train_base = pd.read_csv(r'data\train.csv')
test_base = pd.read_csv(r'data\test.csv')

# %%
print(len(train_base))
train_base
# Out:
# 303
#      ID_QUESTAO  LABEL_QUESTAO  \
# 0           101              0
# 1           102              0
# 2           103              0
# 3           104              0
# 4           105              0
# ..          ...            ...
# 298         399              0
# 299         400              0
# 300         401              0
# 301         402              0
# 302         403              0
#
#                                      ENUNCIADO_QUESTAO  \
# 0    A perfuração de poços para a extração de petró...
# 1    A  combustão completa de combustíveis fósseis ...
# 2    No Autódromo de Interlagos, um carro de Fórmul...
# 3    Alterações no genoma podem ser ocasionadas por...
# 4    Os materiais são classificados pela sua nature...
# ..                                                 ...
# 298  De modo geral, a palavra “aromático” invoca as...
# 299  Os resultados de um ensaio clínico randomizado...
# 300  O protozoário Trypanosoma cruzi, causador da d...
# 301  O sinal sonoro oriundo da queda de um grande b...
# 302  Em 2002, um mecânico da cidade mineira de Uber...
#
#                                          ALTERNATIVA_A  \
# 0    redução da atividade do fitoplâncton, em decor...
# 1    gasolina é uma mistura de hidrocarbonetos com ...
# 2                 Radial, apontada para fora da curva.
# 3                                               Cavalo
# 4                                                    I
# ..                                                 ...
# 298                                      ramificações.
# 299                   predação do vírus pela bactéria.
# 300                                     Autoimunidade.
# 301                                       Sinal\nSinal
# 302                                          Difração.
#
#                                          ALTERNATIVA_B  \
# 0    intoxicação dos animais filtradores, em decorr...
# 1                                           60% menor.
# 2               Radial, apontada para dentro da curva.
# 3                                               Ovelha
# 4                                                   II
# ..                                                 ...
# 298                                      insaturações.
# 299             esterilização de mosquitos infectados.
# 300                                Hipersensibilidade.
# 301  A distância L, em metro, entre o barco e a gel...
# 302                                          Absorção.
#
#                                          ALTERNATIVA_C  \
# 0    bioacumulação do óleo no zooplâncton, por caus...
# 1                                           46% menor.
# 2    Aceleração nula, portanto, sem direção nem sen...
# 3                                                Veado
# 4                                                  III
# ..                                                 ...
# 298  H3\nH\nO\nOH\nO\nCH3\nH\nO\nSalicilato de meti...
# 299   alteração no genótipo do mosquito pela bactéria.
# 300                        Ativação da resposta inata.
# 301                                            14 400.
# 302                                       Polarização.
#
#                                          ALTERNATIVA_D  \
# 0    mortandade dos peixes, causada pela obstrução ...
# 1                                          108% maior.
# 2    Tangencial, apontada no sentido da velocidade ...
# 3                                                Porco
# 4                                                   IV
# ..                                                 ...
# 298                                átomos de oxigênio.
# 299   competição do vírus e da bactéria no hospedeiro.
# 300               Apresentação de antígeno específico.
# 301                                             5 240.
# 302                                          Reflexão.
#
#                                          ALTERNATIVA_E
# 0    dizimação da população de bentônicos, pelo seu...
# 1                                         66% maior.\n
# 2    Tangencial, apontada no sentido contrário à ve...
# 3                                               Vaca\n
# 4                                                  V\n
# ..                                                 ...
# 298                        carbonos assimétricos.\n/\n
# 299  inserção de material genético do vírus na bact...
# 300  Desencadeamento de processo anti-inflamatório....
# 301                                          100.\n/\n
# 302      Refração.\n/\nMatemática e suas Tecnologias\n
#
# [303 rows x 8 columns]

# %%
print(len(test_base))
test_base
# Out:
# 101
#      ID_QUESTAO                                  ENUNCIADO_QUESTAO  \
# 0           241  TEXTO I\nNo cordel intitulado Senhor dos Anéis...
# 1            90  Metais são contaminantes encontrados em efluen...
# 2           313  O Recife fervilhava no começo da década de 199...
# 3           386  Em 2002, foi publicado um artigo científico qu...
# 4           361  Em 2017, foi inaugurado, no estado da Bahia, o...
# ..          ...                                                ...
# 96          288  Seis em cada dez pessoas com 15 anos ou mais n...
# 97          163  Não que Pelino fosse químico, longe disso; mas...
# 98          208  De um lado, ancorados pela prática médica euro...
# 99           37  Leia a posteridade, ó pátrio Rio, \n       Em ...
# 100         148  TEXTO I\nCorreu à sala dos retratos, abriu o p...
#
#                                          ALTERNATIVA_A  \
# 0                                            Mercúrio.
# 1    mais altas nos produtores do que nos decomposi...
# 2    utilização de aparelhos musicais eletrônicos e...
# 3                                          Estrogênio.
# 4                                         1 000 000 m2
# ..                                                 ...
# 96   promovam a melhoria da aptidão física da popul...
# 97   contestar o ensino de regras em detrimento do ...
# 98                         adoção de rituais místicos.
# 99   busca o seu reconhecimento literário entre as ...
# 100  pouca complexidade musical das composições aju...
#
#                                          ALTERNATIVA_B  \
# 0                                             Júpiter.
# 1    iguais para todos nos diferentes níveis trófic...
# 2    ocupação de espaços da natureza local para a p...
# 3                                           Feromônio.
# 4                                           500 000 m2
# ..                                                 ...
# 96   combatam o sedentarismo presente em parcela si...
# 97   resgatar valores patrióticos relacionados às t...
# 98                       rejeição dos dogmas cristãos.
# 99   contempla com sentimento de cumplicidade a nat...
# 100  prevalência de referências musicais africanas ...
#
#                                          ALTERNATIVA_C  \
# 0                                               Urano.
# 1    mais baixas nos consumidores secundários e ter...
# 2    substituição de antigas práticas musicais, com...
# 3                                        Testosterona.
# 4                                           250 000 m2
# ..                                                 ...
# 96   facilitem a adoção da prática de exercícios, c...
# 97   adotar uma perspectiva complacente em relação ...
# 98                      superação da tradição popular.
# 99   lamenta os efeitos produzidos pelos atos de co...
# 100  incipiente atribuição de prestígio social a mú...
#
#                                          ALTERNATIVA_D  \
# 0                                             Saturno.
# 1    mais altas nos consumidores primários do que n...
# 2    recuperação de composições tradicionais folcló...
# 3                                       Somatotrofina.
# 4                                           100 000 m2
# ..                                                 ...
# 96   auxiliem na construção de mais instalações esp...
# 97   invalidar os usos da língua pautados pelos pre...
# 98                   imposição da farmacologia nativa.
# 99   encontra na simplicidade das imagens a express...
# 100  tensa relação entre o erudito e o popular na c...
#
#                                          ALTERNATIVA_E
# 0                                            Netuno.\n
# 1    mais baixas nos de níveis tróficos de menor or...
# 2    integração de referenciais culturais de difere...
# 3                  Hormônio folículo estimulante.\n/\n
# 4                                       20 000 m2\n/\n
# ..                                                 ...
# 96   estimulem o incentivo fiscal para a iniciativa...
# 97   desconsiderar diferentes níveis de formalidade...
# 98                  conjugação de saberes empíricos.\n
# 99   recorre a elementos mitológicos da cultura clá...
# 100  importância atribuída à música clássica na soc...
#
# [101 rows x 7 columns]

# %%
print(train_base.keys())
# Out:
# Index(['ID_QUESTAO', 'LABEL_QUESTAO', 'ENUNCIADO_QUESTAO', 'ALTERNATIVA_A',
#        'ALTERNATIVA_B', 'ALTERNATIVA_C', 'ALTERNATIVA_D', 'ALTERNATIVA_E'],
#       dtype='object')

# %%
quest = 100
print(train_base['ENUNCIADO_QUESTAO'][quest])
print(train_base['ALTERNATIVA_C'][quest])
print(train_base['LABEL_QUESTAO'][quest])
# Out:
# O protagonismo indígena vem optando por uma estratégia de “des-invisibilização”,
# valendo-se da dinâmica das novas tecnologias. Em outubro de 2012, após receberem
# uma liminar lhes negando o direito a permanecer em suas terras, os Guarani de Pyelito
# Kue divulgaram uma carta na qual se dispunham a morrer, mas não a sair de suas terras.
# Esse fato foi amplamente divulgado, gerando uma grande mobilização na internet, que
# levou milhares de pessoas a escolherem seu lado, divulgando a hashtag
# “#somostodosGuarani-Kaiowá” ou acrescentando o sobrenome Guarani-Kaiowá a seus
# nomes nos perfis das principais redes sociais.
# CAPIBERIBE, A.; BONILLA, O. A ocupação do Congresso: contra o que
# lutam os índios? Estudos Avançados, n. 83, 2015 (adaptado).
# A estratégia comunicativa adotada pelos indígenas, no contexto em pauta, teve por efeito
# inserir as comunidades no mercado global.
# 1

# %%
stopwords = ['a', 'à', 'adeus', 'agora', 'aguenta', 'ah', 'ai', 'ainda', 'além', 'algo', 'algum', 'alguma', 'algumas', 'alguns', 'ali', 'além', 'ambos', 'antes', 
             'apenas', 'apoio', 'após', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aqui', 'aquilo', 'as', 'às', 'assim', 'até', 'atrás', 'através', 'atual', 'àquele', 
             'àqueles', 'àquela', 'àquelas', 'bem', 'bom', 'brevemente', 'cada', 'caminho', 'catorze', 'cedo', 'cento', 'certamente', 'certeza', 'cima', 'cinco', 'coisa', 
             'com', 'como', 'comprido', 'conhecido', 'conselho', 'conselho', 'contigo', 'contra', 'corrente', 'custa', 'da', 'dá', 'daquela', 'daquelas', 'daquele', 'daqueles', 
             'dar', 'das', 'de', 'debaixo', 'demais', 'dentro', 'depois', 'desde', 'dessa', 'dessas', 'desse', 'desses', 'desta', 'destas', 'deste', 'destes', 'deve', 'deverá', 
             'dez', 'dezanove', 'dezasseis', 'dezassete', 'dezoito', 'dia', 'diante', 'direita', 'diz', 'dizem', 'dizer', 'do', 'dois', 'dos', 'doze', 'duas', 'dúvida', 'e', 'é', 
             'ela', 'elas', 'ele', 'eles', 'em', 'embora', 'entre', 'então', 'era', 'essa', 'essas', 'esse', 'esses', 'esta', 'está', 'estar', 'estas', 'estava', 'este', 'esteja', 
             'estejam', 'estejamos', 'estes', 'esteve', 'estive', 'estivemos', 'estiver', 'estivera', 'estiveram', 'estiverem', 'estivermos', 'estivesse', 'estivessem', 'estivéramos', 
             'estivéssemos', 'eu', 'exemplo', 'faço', 'falta', 'favor', 'faz', 'fazeis', 'fazem', 'fazemos', 'fazer', 'fazes', 'fez', 'fim', 'final', 'foi', 'fomos', 'for', 'fora', 
             'foram', 'forem', 'forma', 'foste', 'fostes', 'fui', 'geral', 'grande', 'grandes', 'grupo', 'há', 'hoje', 'hora', 'horas', 'isso', 'isto', 'já', 'lá', 'lado', 'local', 
             'logo', 'longe', 'lugar', 'maior', 'maioria', 'mais', 'mal', 'mas', 'máximo', 'me', 'meio', 'menor', 'menos', 'mês', 'meses', 'mesmo', 'meu', 'meus', 'mil', 'minha', 
             'minhas', 'momento', 'muito', 'muitos', 'na', 'nada', 'naquela', 'naquelas', 'naquele', 'naqueles', 'nas', 'nem', 'nenhum', 'nenhuma', 'nenhumas', 'nenhuns', 'nessa', 
             'nessas', 'nesse', 'nesses', 'nesta', 'nestas', 'neste', 'nestes', 'ninguém', 'no', 'noite', 'nome', 'nos', 'nós', 'nossa', 'nossas', 'nosso', 'nossos', 'nova', 'novas', 
             'nove', 'novo', 'novos', 'num', 'numa', 'número', 'números', 'nunca', 'o', 'obra', 'obrigada', 'obrigado', 'oitava', 'oitavo', 'oito', 'onde', 'ontem', 'onze', 'os', 'ou', 
             'outra', 'outras', 'outro', 'outros', 'para', 'parece', 'parte', 'partir', 'paucas', 'pela', 'pelas', 'pelo', 'pelos', 'perto', 'pode', 'pôde', 'podem', 'poder', 'poderá', 
             'podia', 'põe', 'põem', 'ponto', 'pontos', 'por', 'porque', 'porquê', 'pouca', 'pouco', 'povo', 'primeira', 'primeiro', 'própria', 'próprias', 'próprio', 'próprios', 
             'quais', 'quáis', 'qual', 'qualquer', 'quando', 'quanto', 'quantos', 'quarta', 'quarto', 'quatro', 'que', 'quê', 'quem', 'quer', 'quereis', 'querem', 'queremas', 'queres', 
             'quero', 'questão', 'quinta', 'quinto', 'quinze', 'relação', 'sabe', 'saber', 'se', 'segunda', 'segundo', 'sei', 'seis', 'sem', 'sempre', 'ser', 'será', 'serão', 'seremos', 
             'si', 'sido', 'sob', 'sobre', 'sou', 'sua', 'suas', 'tal', 'também', 'tanto', 'tarde', 'te', 'tem', 'têm', 'temos', 'tempo', 'tendes', 'tendo', 'tenha', 'tenham', 
             'tenhamos', 'tenho', 'tens', 'tentar', 'tentaram', 'tentámos', 'tente', 'tentei', 'tentemos', 'tentes', 'ter', 'terá', 'terão', 'teremos', 'teu', 'teus', 'teve', 'ti', 
             'tido', 'tinha', 'tinham', 'tínhamos', 'tive', 'tivemos', 'tiver', 'tivera', 'tiveram', 'tiverem']

# %%
import string
from nltk.tokenize.regexp import RegexpTokenizer

def preprocess(text : str):
    print(text)
    
    for pontuation in string.punctuation:
        text = text.replace(pontuation, '')

    text = text.lower()

    print(text)

    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(text)
    print(tokens)
    
    
    return tokens

preprocess(train_base['ENUNCIADO_QUESTAO'][1])
# Out:
# A  combustão completa de combustíveis fósseis produz água e dióxido de carbono (CO2,
# massa molar 44 g mol−1). A União Europeia estabeleceu, desde 2012, limite de emissão
# veicular de 130 g de CO2 por quilômetro rodado (valor aplicável a uma média de veículos de
# um mesmo fabricante), tendo como penalidade multa, caso o fabricante ultrapasse a meta. A
# gasolina é uma mistura de hidrocarbonetos com cerca de oito carbonos em sua composição,
# incluindo isômeros do octano (C8H18). Considere que em uma cidade o consumo médio diário
# dos carros de um fabricante seja de 10 km L−1 de gasolina, formada apenas por
# octano (massa molar 114 g mol−1) e que sua densidade seja 0,70 kg L−1.
# A diferença de emissão de CO2 dos carros desse fabricante em relação ao limite estabelecido
# na União Europeia é
# a  combustão completa de combustíveis fósseis produz água e dióxido de carbono co2
# massa molar 44 g mol−1 a união europeia estabeleceu desde 2012 limite de emissão
# veicular de 130 g de co2 por quilômetro rodado valor aplicável a uma média de veículos de
# um mesmo fabricante tendo como penalidade multa caso o fabricante ultrapasse a meta a
# gasolina é uma mistura de hidrocarbonetos com cerca de oito carbonos em sua composição
# incluindo isômeros do octano c8h18 considere que em uma cidade o consumo médio diário
# dos carros de um fabricante seja de 10 km l−1 de gasolina formada apenas por
# octano massa molar 114 g mol−1 e que sua densidade seja 070 kg l−1
# a diferença de emissão de co2 dos carros desse fabricante em relação ao limite estabelecido
# na união europeia é
# ['a', 'combustão', 'completa', 'de', 'combustíveis', 'fósseis', 'produz', 'água', 'e', 'dióxido', 'de', 'carbono', 'co2', 'massa', 'molar', '44', 'g', 'mol', '1', 'a', 'união', 'europeia', 'estabeleceu', 'desde', '2012', 'limite', 'de', 'emissão', 'veicular', 'de', '130', 'g', 'de', 'co2', 'por', 'quilômetro', 'rodado', 'valor', 'aplicável', 'a', 'uma', 'média', 'de', 'veículos', 'de', 'um', 'mesmo', 'fabricante', 'tendo', 'como', 'penalidade', 'multa', 'caso', 'o', 'fabricante', 'ultrapasse', 'a', 'meta', 'a', 'gasolina', 'é', 'uma', 'mistura', 'de', 'hidrocarbonetos', 'com', 'cerca', 'de', 'oito', 'carbonos', 'em', 'sua', 'composição', 'incluindo', 'isômeros', 'do', 'octano', 'c8h18', 'considere', 'que', 'em', 'uma', 'cidade', 'o', 'consumo', 'médio', 'diário', 'dos', 'carros', 'de', 'um', 'fabricante', 'seja', 'de', '10', 'km', 'l', '1', 'de', 'gasolina', 'formada', 'apenas', 'por', 'octano', 'massa', 'molar', '114', 'g', 'mol', '1', 'e', 'que', 'sua', 'densidade', 'seja', '070', 'kg', 'l', '1', 'a', 'diferença', 'de', 'emissão', 'de', 'co2', 'dos', 'carros', 'desse', 'fabricante', 'em', 'relação', 'ao', 'limite', 'estabelecido', 'na', 'união', 'europeia', 'é']
# ['a',
#  'combustão',
#  'completa',
#  'de',
#  'combustíveis',
#  'fósseis',
#  'produz',
#  'água',
#  'e',
#  'dióxido',
#  'de',
#  'carbono',
#  'co2',
#  'massa',
#  'molar',
#  '44',
#  'g',
#  'mol',
#  '1',
#  'a',
#  'união',
#  'europeia',
#  'estabeleceu',
#  'desde',
#  '2012',
#  'limite',
#  'de',
#  'emissão',
#  'veicular',
#  'de',
#  '130',
#  'g',
#  'de',
#  'co2',
#  'por',
#  'quilômetro',
#  'rodado',
#  'valor',
#  'aplicável',
#  'a',
#  'uma',
#  'média',
#  'de',
#  'veículos',
#  'de',
#  'um',
#  'mesmo',
#  'fabricante',
#  'tendo',
#  'como',
#  'penalidade',
#  'multa',
#  'caso',
#  'o',
#  'fabricante',
#  'ultrapasse',
#  'a',
#  'meta',
#  'a',
#  'gasolina',
#  'é',
#  'uma',
#  'mistura',
#  'de',
#  'hidrocarbonetos',
#  'com',
#  'cerca',
#  'de',
#  'oito',
#  'carbonos',
#  'em',
#  'sua',
#  'composição',
#  'incluindo',
#  'isômeros',
#  'do',
#  'octano',
#  'c8h18',
#  'considere',
#  'que',
#  'em',
#  'uma',
#  'cidade',
#  'o',
#  'consumo',
#  'médio',
#  'diário',
#  'dos',
#  'carros',
#  'de',
#  'um',
#  'fabricante',
#  'seja',
#  'de',
#  '10',
#  'km',
#  'l',
#  '1',
#  'de',
#  'gasolina',
#  'formada',
#  'apenas',
#  'por',
#  'octano',
#  'massa',
#  'molar',
#  '114',
#  'g',
#  'mol',
#  '1',
#  'e',
#  'que',
#  'sua',
#  'densidade',
#  'seja',
#  '070',
#  'kg',
#  'l',
#  '1',
#  'a',
#  'diferença',
#  'de',
#  'emissão',
#  'de',
#  'co2',
#  'dos',
#  'carros',
#  'desse',
#  'fabricante',
#  'em',
#  'relação',
#  'ao',
#  'limite',
#  'estabelecido',
#  'na',
#  'união',
#  'europeia',
#  'é']
