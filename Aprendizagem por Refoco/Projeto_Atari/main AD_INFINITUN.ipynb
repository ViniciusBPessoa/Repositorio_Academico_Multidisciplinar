# %% [markdown]
# ### Inicialização (fazendo o arquivo se encotrar no repositorio)
#
# Normalmente uso um repositório contendo material de várias diferentes cadeiras nesse caso as seguintes linhas servem para que todos os importes possam ser encontrados adequadamente.

# %%
import sys
import os

# Obtém o caminho do diretório do script atual
script_dir = os.getcwd()

# Adiciona o diretório pai ao caminho do sistema
sys.path.append(script_dir)

# %% [markdown]
# ### Importando bibliotecas necessárias

# %%
import pygame # Nos repositórios de referência essa lib é sempre importada tendo em vista que o gymnasium (gym) utiliza a mesma, deve evitar problemas

import time # será utilizada para coletar o período temporal necessário para que algumas funções sejam executadas
from datetime import datetime

import numpy as np # numpy por motivos óbvios  

import torch # Todas as redes neurais serão criados utilizando PyTorch
import torch.nn as nn
import torch.optim as optim


import matplotlib.pyplot as plt # Demonstração de Gráficos e imagens

# %%
from pathlib import Path
from base64 import b64encode
from IPython.display import HTML, display, clear_output

# %% [markdown]
# Importando módulos próprios:
#
# 1 - importando os módulos DQN e de edição de imagens (Para caber a proposta da atividade)
#
# 2 - import de auxiliares do DQN (buffer, escolha de ação, função de perda)
#
# 3 -  import do gymnasium como gym (biblioteca contendo os ambientes usados)
#
# 4 - inicializando o PyTorch CPU ou GPU caso a mesma esteja disponível

# %%
from modelos import dqn_models
from wrappers.atari_wrappers import *
from DQN_aux.DQN_aux import *

import gymnasium as gym

# verifica a disponibilidade da GPU
if torch.cuda.is_available():
    is_gpu = torch.device("cuda")
else:
    is_gpu = torch.device("cpu")

torch.set_default_device(is_gpu) # instanciando onde a rede neural deve rodar

# %% [markdown]
# ## definição de algumas funções importantes

# %% [markdown]
# #### Definição da função que salva vídeos com uma rede neural previamente treinada ou de forma aleatória (epsilon = 1.0 para aleatoriedade total).

# %%
# Baseada na minha versão (Pablo)
def record_video_q_neuralnet(env_name, qnet, episodes=3, folder='videos/', prefix='rl-video', epsilon=0.0):
    """
    Grava um vídeo a partir de uma política epsilon-greedy definida pela 'qtable' e pelo valor de 'epsilon'.
    - env_name: A string do ambiente cadastrada no gymnasium ou uma instância da classe. Ao final, o ambiente é fechado (função `close()`).
    - qnet: A rede neural que representa a função Q.
    - episodes: Número de episódios completos que serão executados.
    - prefiz: Prefixo do nome dos arquivos de vídeo.
    - folder: Pasta onde os arquivos de vídeo serão salvos.
    - epsilon: Valor do parâmetro da política "epsilon-greedy" usada para escolher as ações.
    """
    if isinstance(env_name, str):
        env = gym.make(env_name, render_mode="rgb_array")
    else:
        env = env_name
    rec_env = gym.wrappers.RecordVideo(env, folder, episode_trigger=lambda i : True, name_prefix=prefix)
    num_steps = 0
    for epi in range(episodes):
        state, _ = rec_env.reset()
        num_steps += 1
        epi_reward = 0.0
        done = False
        while not done:
            action = choose_action(qnet, env, state, epsilon)
            state, r, termi, trunc, _ = rec_env.step(action)
            done = termi or trunc
            num_steps += 1
            epi_reward += r
        print(f"Episode {epi}: {num_steps} steps / return {epi_reward:.2f}")
    rec_env.close()
    env.close()

# %% [markdown]
# ### Função de treinamento DQN!

# %%
def DQN_TRAIN(env, env_name, gamma, qnet, qnet_lr, target_qnet, target_update_freq, replay_size, batch_size, epsilon_f, epsilon_decay_period, NUM_STAPS):

    """
    Treina um agente utilizando o algoritmo Deep Q-Network (DQN) em um ambiente de aprendizado por reforço.

    Args:
        env: O ambiente de aprendizado por reforço. Pode ser uma instância da classe do ambiente ou uma string 
            que representa o nome do ambiente registrado no Gym.
        env_name (str): O nome do ambiente (usado para fins de logging e salvamento).
        gamma (float): O fator de desconto para recompensas futuras.
        qnet (torch.nn.Module): A rede neural que representa a função Q.
        qnet_lr (float): A taxa de aprendizado para o otimizador Adam utilizado para treinar a rede neural.
        target_qnet (torch.nn.Module): A rede neural que representa a função Q-alvo.
        target_update_freq (int): A frequência com que os pesos da rede alvo são atualizados.
        replay_size (int): O tamanho do buffer de experiência usado para amostragem durante o treinamento.
        batch_size (int): O tamanho do lote usado para atualizar os pesos da rede neural.
        epsilon_f (float): O valor inicial de epsilon para a política epsilon-greedy.
        epsilon_decay_period (int): O período de decaimento para o valor de epsilon.
        NUM_STAPS (int): O número total de passos de treinamento a serem executados.
    """

    # Cria o otimizador, que vai fazer o ajuste dos pesos da 'qnet',
    # Usa uma técnica de gradiente descendente de destaque, chamada ADAM
    optimizer = optim.Adam(qnet.parameters(), lr=qnet_lr)

    # Para o logging de dados, para serem exibidos no tensorboard
    writer = SummaryWriter(comment="-" + env_name)

    buffer = DQNExperienceBuffer(replay_size)

    start_time_str = datetime.now().strftime("%Y-%m-%d,%H-%M-%S")
    episode_reward_list = []
    step = 0
    epsilon = 1.0

    state, _ = env.reset()
    episode_reward = 0.0
    episode_start_step = 0
    episode_start_time = time.time()

    while True:
        step += 1

        # Decaimento linear do epsilon
        epsilon = max(epsilon_f, 1.0 - step / epsilon_decay_period)

        action = choose_action(qnet, env, state, epsilon)

        # Faz um passo / Aplica uma ação no ambiente
        new_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        episode_reward += reward

        # Adiciona no buffer
        buffer.append(state, action, reward, terminated, new_state)
        state = new_state

        if done:
            episode_reward_list.append(episode_reward)
            speed = (step - episode_start_step) / (time.time() - episode_start_time + 0.00001)

            state, _ = env.reset()
            episode_reward = 0.0
            episode_start_step = step
            episode_start_time = time.time()

            # Abaixo, faz vários loggings de dados
            mean_reward = np.mean(episode_reward_list[-100:])
            print(f"{step}: finished {len(episode_reward_list)} episodes, mean reward {mean_reward:.3f}, eps {epsilon:.2f}, speed {speed:.2f} steps/s")
            writer.add_scalar("epsilon", epsilon, step)
            writer.add_scalar("epi_reward_100", mean_reward, step)
            writer.add_scalar("epi_reward", episode_reward, step)

            # Testa se "resolveu" o ambiente
            if step > NUM_STAPS:
                print(f"Solved in {step} steps with mean reward {mean_reward:.3f}")
                # Verifica se o diretório existe e, se não, cria-o
                model_dir = 'models/' + env_name
                if not os.path.exists(model_dir):
                    os.makedirs(model_dir)
                filename = model_dir + "-" + start_time_str + ".dat"
                torch.save(qnet.state_dict(), filename)
                print(f"Model saved as {filename}") 
                break

        if len(buffer) < replay_size:
            continue

        # Faz a 'tgt_net' receber os mesmos valores de pesos da 'qnet', na frequência indicada
        if step % target_update_freq == 0:
            target_qnet.load_state_dict(qnet.state_dict())

        # Escolhendo amostras aleatórios do buffer e faz uma atualização dos pesos da rede
        optimizer.zero_grad()
        batch = buffer.sample(batch_size)
        loss_t = calc_loss(batch, qnet, target_qnet, gamma)
        loss_t.backward()
        optimizer.step()

    writer.close()
    return episode_reward_list

# %%
def display_videos_from_path(video_folder='', prefix='rl-video', speed=1.0):
    """
    :param video_path: (str) Path to the folder containing videos
    :param prefix: (str) To filter the video files
    """
    html = []
    for mp4 in Path(video_folder).glob("{}*.mp4".format(prefix)):
        video_b64 = b64encode(mp4.read_bytes())
        html.append('''<video alt="{}" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                    </video>'''.format(mp4, video_b64.decode('ascii')))
    display(HTML(data="<br>".join(html)))
    
    # Add JavaScript code to set playback speed
    display(HTML(f'''
        <script>
        var videos = document.getElementsByTagName('video');
        for (var i = 0; i < videos.length; i++) {{
            videos[i].playbackRate = {speed};
        }}
        </script>
        '''))

# %% [markdown]
# ### Agora vamos definir os valores de entrada para o treinamento e inicializa o ambiente (env)

# %%
ATARI_ENV_NAME = "ALE/SpaceInvaders-v5"

NUM_STAPS = 3_000_000 # numero de passos desejados (1000000) 

# Parâmetros do DQN
GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 20_000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1_500

EPSILON_DECAY_PERIOD = 100_000
EPSILON_FINAL = 0.02

N_STAPS_FOR_OBS = 4 # número de passos que geram um "Estado"

env = gym.make(ATARI_ENV_NAME)

# %% [markdown]
# ### aplicando os wrappers como Start, recorte, redução de 3 para 1 canal

# %%
# Aplica os wrappers do DQN para ambientes Atari
enva = MaxAndSkipEnv(env)
envb = FireResetEnv(enva)
envc = ProcessFrame84(envb)
envd = ImageToPyTorch(envc)
enve = BufferWrapper(envd, N_STAPS_FOR_OBS)
envf = ScaledFloatFrame(enve)

# %% [markdown]
# ### inicializa as redes neurais via PyTorch

# %%
# Cria as redes neurais
qnet = dqn_models.DQNNet(envf.observation_space.shape, envf.action_space.n)
qtarget = dqn_models.DQNNet(envf.observation_space.shape, envf.action_space.n)

# %% [markdown]
# ### Demonstrando o resultade de alguns wrappers

# %%
# Mostrando a tela do ambiente original, e outras telas após passar por alguns wrappers
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12,5))

s, _ = env.reset()
ax1.imshow(s)
ax1.set_title('Tela antes de iniciar')

s, _ = envb.reset()
ax2.imshow(s)
ax2.set_title('Tela da partida iniciada automaticamente')

s, _ = envd.reset()
ax3.imshow(s[0], cmap='gray', vmin=0, vmax=255)  # exibe em escala de cinza
ax3.set_title('Imagem processada');

# %% [markdown]
# ### Realiza o treinamento utilizando os valores oferecidos anteriormente

# %%
inicio = time.time()

lisat_fim = DQN_TRAIN(
    env = envf,
    env_name = ATARI_ENV_NAME,
    gamma = GAMMA,
    qnet = qnet,
    qnet_lr = LEARNING_RATE,
    target_qnet = qtarget,
    target_update_freq = SYNC_TARGET_FRAMES,
    replay_size = REPLAY_SIZE,
    batch_size = BATCH_SIZE,
    epsilon_f = EPSILON_FINAL,
    epsilon_decay_period = EPSILON_DECAY_PERIOD,
    NUM_STAPS = NUM_STAPS)

fim = time.time()

Tempo_total = fim - inicio
# Out:
# 110: finished 1 episodes, mean reward 125.000, eps 1.00, speed 347.36 steps/s
# 189: finished 2 episodes, mean reward 92.500, eps 1.00, speed 218.56 steps/s
# 309: finished 3 episodes, mean reward 98.333, eps 1.00, speed 188.57 steps/s
# 477: finished 4 episodes, mean reward 133.750, eps 1.00, speed 377.61 steps/s
# 605: finished 5 episodes, mean reward 143.000, eps 0.99, speed 399.55 steps/s
# 710: finished 6 episodes, mean reward 129.167, eps 0.99, speed 371.45 steps/s
# 785: finished 7 episodes, mean reward 113.571, eps 0.99, speed 265.23 steps/s
# 931: finished 8 episodes, mean reward 117.500, eps 0.99, speed 309.04 steps/s
# 1052: finished 9 episodes, mean reward 118.889, eps 0.99, speed 380.99 steps/s
# 1161: finished 10 episodes, mean reward 110.000, eps 0.99, speed 292.78 steps/s
# 1313: finished 11 episodes, mean reward 137.727, eps 0.99, speed 302.64 steps/s
# 1530: finished 12 episodes, mean reward 172.917, eps 0.98, speed 378.77 steps/s
# 1629: finished 13 episodes, mean reward 165.385, eps 0.98, speed 427.41 steps/s
# 1706: finished 14 episodes, mean reward 155.714, eps 0.98, speed 330.92 steps/s
# 1844: finished 15 episodes, mean reward 153.667, eps 0.98, speed 270.47 steps/s
# 2063: finished 16 episodes, mean reward 160.312, eps 0.98, speed 181.50 steps/s
# 2132: finished 17 episodes, mean reward 154.412, eps 0.98, speed 128.30 steps/s
# 2195: finished 18 episodes, mean reward 147.778, eps 0.98, speed 118.31 steps/s
# 2312: finished 19 episodes, mean reward 143.684, eps 0.98, speed 132.82 steps/s
# 2488: finished 20 episodes, mean reward 144.500, eps 0.98, speed 264.69 steps/s
# 2586: finished 21 episodes, mean reward 140.238, eps 0.97, speed 272.28 steps/s
# 2721: finished 22 episodes, mean reward 142.500, eps 0.97, speed 211.25 steps/s
# 2815: finished 23 episodes, mean reward 139.783, eps 0.97, speed 241.22 steps/s
# 2978: finished 24 episodes, mean reward 140.000, eps 0.97, speed 324.52 steps/s
# 3091: finished 25 episodes, mean reward 137.800, eps 0.97, speed 306.18 steps/s
# 3205: finished 26 episodes, mean reward 133.846, eps 0.97, speed 412.84 steps/s
# 3363: finished 27 episodes, mean reward 131.481, eps 0.97, speed 301.37 steps/s
# 3543: finished 28 episodes, mean reward 139.107, eps 0.96, speed 314.94 steps/s
# 3665: finished 29 episodes, mean reward 139.138, eps 0.96, speed 320.01 steps/s
# 3874: finished 30 episodes, mean reward 139.167, eps 0.96, speed 327.34 steps/s
# 4028: finished 31 episodes, mean reward 141.774, eps 0.96, speed 268.88 steps/s
# 4145: finished 32 episodes, mean reward 140.938, eps 0.96, speed 338.19 steps/s
# 4243: finished 33 episodes, mean reward 139.697, eps 0.96, speed 381.36 steps/s
# 4356: finished 34 episodes, mean reward 138.382, eps 0.96, speed 326.35 steps/s
# 4499: finished 35 episodes, mean reward 138.286, eps 0.96, speed 316.78 steps/s
# 4594: finished 36 episodes, mean reward 137.361, eps 0.95, speed 385.83 steps/s
# 4721: finished 37 episodes, mean reward 136.892, eps 0.95, speed 359.12 steps/s
# 4972: finished 38 episodes, mean reward 139.474, eps 0.95, speed 314.55 steps/s
# 5091: finished 39 episodes, mean reward 137.179, eps 0.95, speed 394.72 steps/s
# 5153: finished 40 episodes, mean reward 134.500, eps 0.95, speed 422.19 steps/s
# 5244: finished 41 episodes, mean reward 132.317, eps 0.95, speed 378.03 steps/s
# 5358: finished 42 episodes, mean reward 129.881, eps 0.95, speed 374.49 steps/s
# 5483: finished 43 episodes, mean reward 128.023, eps 0.95, speed 398.90 steps/s
# 5687: finished 44 episodes, mean reward 131.364, eps 0.94, speed 394.21 steps/s
# 5850: finished 45 episodes, mean reward 131.444, eps 0.94, speed 334.10 steps/s
# 5965: finished 46 episodes, mean reward 130.761, eps 0.94, speed 396.98 steps/s
# 6065: finished 47 episodes, mean reward 128.830, eps 0.94, speed 290.26 steps/s
# 6235: finished 48 episodes, mean reward 130.625, eps 0.94, speed 378.56 steps/s
# 6468: finished 49 episodes, mean reward 132.653, eps 0.94, speed 451.45 steps/s
# 6569: finished 50 episodes, mean reward 130.200, eps 0.93, speed 433.65 steps/s
# 6781: finished 51 episodes, mean reward 133.235, eps 0.93, speed 431.53 steps/s
# 6897: finished 52 episodes, mean reward 132.212, eps 0.93, speed 438.81 steps/s
# 7011: finished 53 episodes, mean reward 130.943, eps 0.93, speed 407.84 steps/s
# 7115: finished 54 episodes, mean reward 129.444, eps 0.93, speed 382.63 steps/s
# 7179: finished 55 episodes, mean reward 128.000, eps 0.93, speed 369.10 steps/s
# 7370: finished 56 episodes, mean reward 128.750, eps 0.93, speed 402.14 steps/s
# 7434: finished 57 episodes, mean reward 127.018, eps 0.93, speed 378.78 steps/s
# 7630: finished 58 episodes, mean reward 128.190, eps 0.92, speed 375.72 steps/s
# 7751: finished 59 episodes, mean reward 128.051, eps 0.92, speed 296.68 steps/s
# 7867: finished 60 episodes, mean reward 128.083, eps 0.92, speed 370.07 steps/s
# 7984: finished 61 episodes, mean reward 127.787, eps 0.92, speed 305.34 steps/s
# 8150: finished 62 episodes, mean reward 128.145, eps 0.92, speed 331.45 steps/s
# 8268: finished 63 episodes, mean reward 127.540, eps 0.92, speed 377.67 steps/s
# 8453: finished 64 episodes, mean reward 130.781, eps 0.92, speed 404.65 steps/s
# 8568: finished 65 episodes, mean reward 130.615, eps 0.91, speed 344.17 steps/s
# 8665: finished 66 episodes, mean reward 130.303, eps 0.91, speed 333.85 steps/s
# 8752: finished 67 episodes, mean reward 129.254, eps 0.91, speed 319.15 steps/s
# 8864: finished 68 episodes, mean reward 129.265, eps 0.91, speed 405.50 steps/s
# 8966: finished 69 episodes, mean reward 128.986, eps 0.91, speed 398.99 steps/s
# 9059: finished 70 episodes, mean reward 128.857, eps 0.91, speed 346.99 steps/s
# 9171: finished 71 episodes, mean reward 127.817, eps 0.91, speed 387.49 steps/s
# 9368: finished 72 episodes, mean reward 130.000, eps 0.91, speed 327.80 steps/s
# 9485: finished 73 episodes, mean reward 128.767, eps 0.91, speed 441.74 steps/s
# 9602: finished 74 episodes, mean reward 128.716, eps 0.90, speed 394.35 steps/s
# 9775: finished 75 episodes, mean reward 129.400, eps 0.90, speed 381.78 steps/s
# 9858: finished 76 episodes, mean reward 129.079, eps 0.90, speed 433.46 steps/s
# 9976: finished 77 episodes, mean reward 129.740, eps 0.90, speed 397.07 steps/s
# 10094: finished 78 episodes, mean reward 129.231, eps 0.90, speed 395.03 steps/s
# 10385: finished 79 episodes, mean reward 132.152, eps 0.90, speed 358.93 steps/s
# 10555: finished 80 episodes, mean reward 131.562, eps 0.89, speed 367.87 steps/s
# 10654: finished 81 episodes, mean reward 131.173, eps 0.89, speed 361.91 steps/s
# 10762: finished 82 episodes, mean reward 131.037, eps 0.89, speed 364.82 steps/s
# 10933: finished 83 episodes, mean reward 131.687, eps 0.89, speed 326.89 steps/s
# 11033: finished 84 episodes, mean reward 130.714, eps 0.89, speed 389.57 steps/s
# 11124: finished 85 episodes, mean reward 130.588, eps 0.89, speed 318.55 steps/s
# 11195: finished 86 episodes, mean reward 129.477, eps 0.89, speed 333.01 steps/s
# 11422: finished 87 episodes, mean reward 131.437, eps 0.89, speed 344.61 steps/s
# 11492: finished 88 episodes, mean reward 130.341, eps 0.89, speed 272.04 steps/s
# 11588: finished 89 episodes, mean reward 129.831, eps 0.88, speed 368.36 steps/s
# 11692: finished 90 episodes, mean reward 129.444, eps 0.88, speed 366.13 steps/s
# 11812: finished 91 episodes, mean reward 130.000, eps 0.88, speed 353.42 steps/s
# 11922: finished 92 episodes, mean reward 130.054, eps 0.88, speed 337.85 steps/s
# 12015: finished 93 episodes, mean reward 128.871, eps 0.88, speed 357.71 steps/s
# 12136: finished 94 episodes, mean reward 128.830, eps 0.88, speed 301.63 steps/s
# 12264: finished 95 episodes, mean reward 128.632, eps 0.88, speed 287.59 steps/s
# 12359: finished 96 episodes, mean reward 128.021, eps 0.88, speed 365.83 steps/s
# 12460: finished 97 episodes, mean reward 128.299, eps 0.88, speed 278.50 steps/s
# 12649: finished 98 episodes, mean reward 132.602, eps 0.87, speed 293.49 steps/s
# 12783: finished 99 episodes, mean reward 132.626, eps 0.87, speed 338.51 steps/s
# 12965: finished 100 episodes, mean reward 135.250, eps 0.87, speed 313.44 steps/s
# 13042: finished 101 episodes, mean reward 134.350, eps 0.87, speed 301.00 steps/s
# 13186: finished 102 episodes, mean reward 137.450, eps 0.87, speed 340.18 steps/s
# 13256: finished 103 episodes, mean reward 136.850, eps 0.87, speed 340.52 steps/s
# 13353: finished 104 episodes, mean reward 134.750, eps 0.87, speed 336.65 steps/s
# 13473: finished 105 episodes, mean reward 135.150, eps 0.87, speed 304.50 steps/s
# 13579: finished 106 episodes, mean reward 135.600, eps 0.86, speed 241.01 steps/s
# 13697: finished 107 episodes, mean reward 135.950, eps 0.86, speed 207.08 steps/s
# 13842: finished 108 episodes, mean reward 136.100, eps 0.86, speed 287.90 steps/s
# 13941: finished 109 episodes, mean reward 135.400, eps 0.86, speed 323.14 steps/s
# 14073: finished 110 episodes, mean reward 136.700, eps 0.86, speed 324.73 steps/s
# 14166: finished 111 episodes, mean reward 133.050, eps 0.86, speed 263.57 steps/s
# 14247: finished 112 episodes, mean reward 127.900, eps 0.86, speed 242.07 steps/s
# 14316: finished 113 episodes, mean reward 127.300, eps 0.86, speed 269.98 steps/s
# 14454: finished 114 episodes, mean reward 128.650, eps 0.86, speed 288.61 steps/s
# 14572: finished 115 episodes, mean reward 127.900, eps 0.85, speed 358.69 steps/s
# 14688: finished 116 episodes, mean reward 126.400, eps 0.85, speed 325.44 steps/s
# 14817: finished 117 episodes, mean reward 126.950, eps 0.85, speed 341.24 steps/s
# 15068: finished 118 episodes, mean reward 130.450, eps 0.85, speed 355.55 steps/s
# 15198: finished 119 episodes, mean reward 131.400, eps 0.85, speed 308.61 steps/s
# 15348: finished 120 episodes, mean reward 132.400, eps 0.85, speed 348.83 steps/s
# 15503: finished 121 episodes, mean reward 135.950, eps 0.84, speed 365.12 steps/s
# 15587: finished 122 episodes, mean reward 134.250, eps 0.84, speed 344.37 steps/s
# 15727: finished 123 episodes, mean reward 134.600, eps 0.84, speed 322.17 steps/s
# 16048: finished 124 episodes, mean reward 139.150, eps 0.84, speed 365.60 steps/s
# 16133: finished 125 episodes, mean reward 139.300, eps 0.84, speed 380.21 steps/s
# 16282: finished 126 episodes, mean reward 141.200, eps 0.84, speed 380.79 steps/s
# 16380: finished 127 episodes, mean reward 141.000, eps 0.84, speed 287.25 steps/s
# 16556: finished 128 episodes, mean reward 139.850, eps 0.83, speed 298.36 steps/s
# 16664: finished 129 episodes, mean reward 139.350, eps 0.83, speed 354.30 steps/s
# 16771: finished 130 episodes, mean reward 139.050, eps 0.83, speed 388.12 steps/s
# 16927: finished 131 episodes, mean reward 139.000, eps 0.83, speed 342.76 steps/s
# 17078: finished 132 episodes, mean reward 138.400, eps 0.83, speed 333.25 steps/s
# 17208: finished 133 episodes, mean reward 138.500, eps 0.83, speed 345.67 steps/s
# 17327: finished 134 episodes, mean reward 138.550, eps 0.83, speed 305.32 steps/s
# 17515: finished 135 episodes, mean reward 139.450, eps 0.82, speed 376.17 steps/s
# 17684: finished 136 episodes, mean reward 140.900, eps 0.82, speed 349.80 steps/s
# 17781: finished 137 episodes, mean reward 140.700, eps 0.82, speed 341.07 steps/s
# 17862: finished 138 episodes, mean reward 138.800, eps 0.82, speed 349.89 steps/s
# 17957: finished 139 episodes, mean reward 138.800, eps 0.82, speed 341.71 steps/s
# 18025: finished 140 episodes, mean reward 139.250, eps 0.82, speed 395.96 steps/s
# 18143: finished 141 episodes, mean reward 140.350, eps 0.82, speed 309.27 steps/s
# 18280: finished 142 episodes, mean reward 141.450, eps 0.82, speed 363.87 steps/s
# 18362: finished 143 episodes, mean reward 142.000, eps 0.82, speed 334.17 steps/s
# 18478: finished 144 episodes, mean reward 139.700, eps 0.82, speed 357.17 steps/s
# 18713: finished 145 episodes, mean reward 143.350, eps 0.81, speed 352.96 steps/s
# 18829: finished 146 episodes, mean reward 142.900, eps 0.81, speed 315.57 steps/s
# 19014: finished 147 episodes, mean reward 146.600, eps 0.81, speed 340.57 steps/s
# 19138: finished 148 episodes, mean reward 145.550, eps 0.81, speed 359.95 steps/s
# 19214: finished 149 episodes, mean reward 143.350, eps 0.81, speed 349.30 steps/s
# 19342: finished 150 episodes, mean reward 144.500, eps 0.81, speed 350.92 steps/s
# 19434: finished 151 episodes, mean reward 142.400, eps 0.81, speed 336.45 steps/s
# 19555: finished 152 episodes, mean reward 143.200, eps 0.80, speed 222.46 steps/s
# 19679: finished 153 episodes, mean reward 143.950, eps 0.80, speed 242.69 steps/s
# 19769: finished 154 episodes, mean reward 144.200, eps 0.80, speed 241.23 steps/s
# 19891: finished 155 episodes, mean reward 144.350, eps 0.80, speed 237.61 steps/s
# 20113: finished 156 episodes, mean reward 144.700, eps 0.80, speed 69.41 steps/s
# 20229: finished 157 episodes, mean reward 144.900, eps 0.80, speed 47.98 steps/s
# 20389: finished 158 episodes, mean reward 144.950, eps 0.80, speed 48.97 steps/s
# 20547: finished 159 episodes, mean reward 146.300, eps 0.79, speed 49.09 steps/s
# 20711: finished 160 episodes, mean reward 148.900, eps 0.79, speed 54.21 steps/s
# 20823: finished 161 episodes, mean reward 149.000, eps 0.79, speed 53.32 steps/s
# 20950: finished 162 episodes, mean reward 148.350, eps 0.79, speed 51.58 steps/s
# 21062: finished 163 episodes, mean reward 148.500, eps 0.79, speed 54.56 steps/s
# 21165: finished 164 episodes, mean reward 146.200, eps 0.79, speed 53.27 steps/s
# 21251: finished 165 episodes, mean reward 145.300, eps 0.79, speed 55.74 steps/s
# 21367: finished 166 episodes, mean reward 144.550, eps 0.79, speed 51.15 steps/s
# 21443: finished 167 episodes, mean reward 144.200, eps 0.79, speed 57.06 steps/s
# 21649: finished 168 episodes, mean reward 144.300, eps 0.78, speed 52.62 steps/s
# 21810: finished 169 episodes, mean reward 145.900, eps 0.78, speed 51.49 steps/s
# 21963: finished 170 episodes, mean reward 145.850, eps 0.78, speed 53.92 steps/s
# 22171: finished 171 episodes, mean reward 148.500, eps 0.78, speed 50.28 steps/s
# 22445: finished 172 episodes, mean reward 147.300, eps 0.78, speed 47.97 steps/s
# 22595: finished 173 episodes, mean reward 149.150, eps 0.77, speed 36.98 steps/s
# 22690: finished 174 episodes, mean reward 148.400, eps 0.77, speed 48.86 steps/s
# 22896: finished 175 episodes, mean reward 149.850, eps 0.77, speed 52.39 steps/s
# 23021: finished 176 episodes, mean reward 149.350, eps 0.77, speed 41.31 steps/s
# 23108: finished 177 episodes, mean reward 148.500, eps 0.77, speed 50.98 steps/s
# 23263: finished 178 episodes, mean reward 151.900, eps 0.77, speed 51.88 steps/s
# 23429: finished 179 episodes, mean reward 151.550, eps 0.77, speed 54.36 steps/s
# 23590: finished 180 episodes, mean reward 151.100, eps 0.76, speed 54.15 steps/s
# 23707: finished 181 episodes, mean reward 150.750, eps 0.76, speed 53.92 steps/s
# 23799: finished 182 episodes, mean reward 150.300, eps 0.76, speed 53.48 steps/s
# 23937: finished 183 episodes, mean reward 150.100, eps 0.76, speed 55.33 steps/s
# 24064: finished 184 episodes, mean reward 153.050, eps 0.76, speed 35.66 steps/s
# 24223: finished 185 episodes, mean reward 153.650, eps 0.76, speed 44.93 steps/s
# 24373: finished 186 episodes, mean reward 157.050, eps 0.76, speed 40.61 steps/s
# 24557: finished 187 episodes, mean reward 155.450, eps 0.75, speed 45.26 steps/s
# 24685: finished 188 episodes, mean reward 156.500, eps 0.75, speed 49.57 steps/s
# 24802: finished 189 episodes, mean reward 156.600, eps 0.75, speed 50.89 steps/s
# 24869: finished 190 episodes, mean reward 156.100, eps 0.75, speed 46.02 steps/s
# 24995: finished 191 episodes, mean reward 155.500, eps 0.75, speed 46.76 steps/s
# 25113: finished 192 episodes, mean reward 155.150, eps 0.75, speed 49.05 steps/s
# 25205: finished 193 episodes, mean reward 156.050, eps 0.75, speed 47.51 steps/s
# 25403: finished 194 episodes, mean reward 157.550, eps 0.75, speed 48.26 steps/s
# 25510: finished 195 episodes, mean reward 157.850, eps 0.74, speed 35.14 steps/s
# 25599: finished 196 episodes, mean reward 158.000, eps 0.74, speed 43.43 steps/s
# 25721: finished 197 episodes, mean reward 158.200, eps 0.74, speed 44.65 steps/s
# 25827: finished 198 episodes, mean reward 153.400, eps 0.74, speed 48.40 steps/s
# 25944: finished 199 episodes, mean reward 153.100, eps 0.74, speed 44.34 steps/s
# 26130: finished 200 episodes, mean reward 151.000, eps 0.74, speed 44.71 steps/s
# 26217: finished 201 episodes, mean reward 150.700, eps 0.74, speed 45.12 steps/s
# 26326: finished 202 episodes, mean reward 147.800, eps 0.74, speed 50.37 steps/s
# 26418: finished 203 episodes, mean reward 147.500, eps 0.74, speed 51.09 steps/s
# 26526: finished 204 episodes, mean reward 148.250, eps 0.73, speed 52.19 steps/s
# 26735: finished 205 episodes, mean reward 148.800, eps 0.73, speed 52.05 steps/s
# 26832: finished 206 episodes, mean reward 148.450, eps 0.73, speed 54.22 steps/s
# 26903: finished 207 episodes, mean reward 148.750, eps 0.73, speed 51.85 steps/s
# 27019: finished 208 episodes, mean reward 147.600, eps 0.73, speed 53.97 steps/s
# 27134: finished 209 episodes, mean reward 147.550, eps 0.73, speed 49.48 steps/s
# 27227: finished 210 episodes, mean reward 147.000, eps 0.73, speed 49.34 steps/s
# 27405: finished 211 episodes, mean reward 148.600, eps 0.73, speed 51.74 steps/s
# 27557: finished 212 episodes, mean reward 149.100, eps 0.72, speed 51.20 steps/s
# 27672: finished 213 episodes, mean reward 150.100, eps 0.72, speed 51.14 steps/s
# 27742: finished 214 episodes, mean reward 148.600, eps 0.72, speed 56.94 steps/s
# 27870: finished 215 episodes, mean reward 148.900, eps 0.72, speed 57.98 steps/s
# 27995: finished 216 episodes, mean reward 148.800, eps 0.72, speed 57.46 steps/s
# 28099: finished 217 episodes, mean reward 148.400, eps 0.72, speed 52.76 steps/s
# 28270: finished 218 episodes, mean reward 146.250, eps 0.72, speed 53.96 steps/s
# 28334: finished 219 episodes, mean reward 144.950, eps 0.72, speed 58.09 steps/s
# 28506: finished 220 episodes, mean reward 144.450, eps 0.71, speed 58.14 steps/s
# 28578: finished 221 episodes, mean reward 140.650, eps 0.71, speed 53.51 steps/s
# 28678: finished 222 episodes, mean reward 140.950, eps 0.71, speed 54.16 steps/s
# 28800: finished 223 episodes, mean reward 140.250, eps 0.71, speed 53.47 steps/s
# 28979: finished 224 episodes, mean reward 136.900, eps 0.71, speed 58.59 steps/s
# 29097: finished 225 episodes, mean reward 137.550, eps 0.71, speed 57.26 steps/s
# 29208: finished 226 episodes, mean reward 136.600, eps 0.71, speed 52.02 steps/s
# 29406: finished 227 episodes, mean reward 138.300, eps 0.71, speed 54.41 steps/s
# 29523: finished 228 episodes, mean reward 136.700, eps 0.70, speed 58.12 steps/s
# 29672: finished 229 episodes, mean reward 137.600, eps 0.70, speed 57.88 steps/s
# 29766: finished 230 episodes, mean reward 137.250, eps 0.70, speed 52.08 steps/s
# 29925: finished 231 episodes, mean reward 136.050, eps 0.70, speed 53.76 steps/s
# 30043: finished 232 episodes, mean reward 136.850, eps 0.70, speed 57.46 steps/s
# 30158: finished 233 episodes, mean reward 136.800, eps 0.70, speed 58.29 steps/s
# 30289: finished 234 episodes, mean reward 136.900, eps 0.70, speed 53.64 steps/s
# 30491: finished 235 episodes, mean reward 136.350, eps 0.70, speed 53.61 steps/s
# 30640: finished 236 episodes, mean reward 135.250, eps 0.69, speed 55.39 steps/s
# 30733: finished 237 episodes, mean reward 134.400, eps 0.69, speed 56.04 steps/s
# 30856: finished 238 episodes, mean reward 135.050, eps 0.69, speed 56.63 steps/s
# 30983: finished 239 episodes, mean reward 135.600, eps 0.69, speed 56.90 steps/s
# 31050: finished 240 episodes, mean reward 135.000, eps 0.69, speed 57.28 steps/s
# 31181: finished 241 episodes, mean reward 134.450, eps 0.69, speed 51.81 steps/s
# 31250: finished 242 episodes, mean reward 133.450, eps 0.69, speed 53.66 steps/s
# 31364: finished 243 episodes, mean reward 133.600, eps 0.69, speed 57.80 steps/s
# 31605: finished 244 episodes, mean reward 136.000, eps 0.68, speed 56.93 steps/s
# 31722: finished 245 episodes, mean reward 131.800, eps 0.68, speed 52.72 steps/s
# 31908: finished 246 episodes, mean reward 132.800, eps 0.68, speed 53.84 steps/s
# 32004: finished 247 episodes, mean reward 129.700, eps 0.68, speed 54.39 steps/s
# 32177: finished 248 episodes, mean reward 130.100, eps 0.68, speed 56.68 steps/s
# 32433: finished 249 episodes, mean reward 132.400, eps 0.68, speed 56.11 steps/s
# 32553: finished 250 episodes, mean reward 132.200, eps 0.67, speed 53.82 steps/s
# 32645: finished 251 episodes, mean reward 131.700, eps 0.67, speed 58.01 steps/s
# 32759: finished 252 episodes, mean reward 130.800, eps 0.67, speed 52.29 steps/s
# 32876: finished 253 episodes, mean reward 130.550, eps 0.67, speed 56.51 steps/s
# 33068: finished 254 episodes, mean reward 131.550, eps 0.67, speed 56.50 steps/s
# 33206: finished 255 episodes, mean reward 133.200, eps 0.67, speed 56.07 steps/s
# 33371: finished 256 episodes, mean reward 134.150, eps 0.67, speed 53.98 steps/s
# 33495: finished 257 episodes, mean reward 134.150, eps 0.67, speed 52.47 steps/s
# 33632: finished 258 episodes, mean reward 132.900, eps 0.66, speed 54.92 steps/s
# 33787: finished 259 episodes, mean reward 131.950, eps 0.66, speed 56.59 steps/s
# 33873: finished 260 episodes, mean reward 128.200, eps 0.66, speed 55.28 steps/s
# 34049: finished 261 episodes, mean reward 128.700, eps 0.66, speed 47.04 steps/s
# 34198: finished 262 episodes, mean reward 129.750, eps 0.66, speed 53.22 steps/s
# 34313: finished 263 episodes, mean reward 128.850, eps 0.66, speed 50.81 steps/s
# 34512: finished 264 episodes, mean reward 130.050, eps 0.65, speed 38.58 steps/s
# 34616: finished 265 episodes, mean reward 130.400, eps 0.65, speed 47.27 steps/s
# 34723: finished 266 episodes, mean reward 131.200, eps 0.65, speed 49.79 steps/s
# 34886: finished 267 episodes, mean reward 133.100, eps 0.65, speed 55.58 steps/s
# 35002: finished 268 episodes, mean reward 132.350, eps 0.65, speed 49.11 steps/s
# 35164: finished 269 episodes, mean reward 131.200, eps 0.65, speed 44.24 steps/s
# 35233: finished 270 episodes, mean reward 130.700, eps 0.65, speed 49.25 steps/s
# 35327: finished 271 episodes, mean reward 128.050, eps 0.65, speed 50.27 steps/s
# 35472: finished 272 episodes, mean reward 127.900, eps 0.65, speed 49.66 steps/s
# 35574: finished 273 episodes, mean reward 126.100, eps 0.64, speed 53.26 steps/s
# 35668: finished 274 episodes, mean reward 126.250, eps 0.64, speed 54.37 steps/s
# 35757: finished 275 episodes, mean reward 123.200, eps 0.64, speed 51.34 steps/s
# 35978: finished 276 episodes, mean reward 125.300, eps 0.64, speed 51.95 steps/s
# 36072: finished 277 episodes, mean reward 125.000, eps 0.64, speed 53.70 steps/s
# 36250: finished 278 episodes, mean reward 122.700, eps 0.64, speed 52.91 steps/s
# 36324: finished 279 episodes, mean reward 119.950, eps 0.64, speed 51.30 steps/s
# 36413: finished 280 episodes, mean reward 120.100, eps 0.64, speed 51.22 steps/s
# 36532: finished 281 episodes, mean reward 120.500, eps 0.63, speed 50.68 steps/s
# 36607: finished 282 episodes, mean reward 120.500, eps 0.63, speed 51.72 steps/s
# 36847: finished 283 episodes, mean reward 120.950, eps 0.63, speed 53.31 steps/s
# 36999: finished 284 episodes, mean reward 120.050, eps 0.63, speed 54.85 steps/s
# 37070: finished 285 episodes, mean reward 118.450, eps 0.63, speed 52.38 steps/s
# 37284: finished 286 episodes, mean reward 117.450, eps 0.63, speed 53.01 steps/s
# 37414: finished 287 episodes, mean reward 117.400, eps 0.63, speed 52.06 steps/s
# 37528: finished 288 episodes, mean reward 117.100, eps 0.62, speed 51.03 steps/s
# 37659: finished 289 episodes, mean reward 116.650, eps 0.62, speed 53.27 steps/s
# 37785: finished 290 episodes, mean reward 117.450, eps 0.62, speed 53.26 steps/s
# 37878: finished 291 episodes, mean reward 117.150, eps 0.62, speed 48.67 steps/s
# 37966: finished 292 episodes, mean reward 117.250, eps 0.62, speed 53.31 steps/s
# 38054: finished 293 episodes, mean reward 116.300, eps 0.62, speed 50.56 steps/s
# 38155: finished 294 episodes, mean reward 114.000, eps 0.62, speed 53.09 steps/s
# 38287: finished 295 episodes, mean reward 113.750, eps 0.62, speed 54.62 steps/s
# 38415: finished 296 episodes, mean reward 113.650, eps 0.62, speed 54.58 steps/s
# 38623: finished 297 episodes, mean reward 115.050, eps 0.61, speed 53.96 steps/s
# 38832: finished 298 episodes, mean reward 117.900, eps 0.61, speed 39.96 steps/s
# 39008: finished 299 episodes, mean reward 119.050, eps 0.61, speed 37.31 steps/s
# 39120: finished 300 episodes, mean reward 117.800, eps 0.61, speed 38.22 steps/s
# 39291: finished 301 episodes, mean reward 120.350, eps 0.61, speed 37.06 steps/s
# 39347: finished 302 episodes, mean reward 119.700, eps 0.61, speed 37.46 steps/s
# 39550: finished 303 episodes, mean reward 121.150, eps 0.60, speed 37.14 steps/s
# 39617: finished 304 episodes, mean reward 120.300, eps 0.60, speed 34.37 steps/s
# 39800: finished 305 episodes, mean reward 119.900, eps 0.60, speed 36.89 steps/s
# 39933: finished 306 episodes, mean reward 120.850, eps 0.60, speed 36.94 steps/s
# 40155: finished 307 episodes, mean reward 122.550, eps 0.60, speed 32.41 steps/s
# 40337: finished 308 episodes, mean reward 123.550, eps 0.60, speed 29.92 steps/s
# 40521: finished 309 episodes, mean reward 124.650, eps 0.59, speed 36.41 steps/s
# 40695: finished 310 episodes, mean reward 125.650, eps 0.59, speed 41.88 steps/s
# 40798: finished 311 episodes, mean reward 124.650, eps 0.59, speed 40.40 steps/s
# 41005: finished 312 episodes, mean reward 126.800, eps 0.59, speed 37.62 steps/s
# 41195: finished 313 episodes, mean reward 131.100, eps 0.59, speed 41.64 steps/s
# 41276: finished 314 episodes, mean reward 131.050, eps 0.59, speed 42.62 steps/s
# 41351: finished 315 episodes, mean reward 131.500, eps 0.59, speed 39.82 steps/s
# 41591: finished 316 episodes, mean reward 135.050, eps 0.58, speed 41.44 steps/s
# 41693: finished 317 episodes, mean reward 134.800, eps 0.58, speed 40.22 steps/s
# 41803: finished 318 episodes, mean reward 134.200, eps 0.58, speed 46.03 steps/s
# 41908: finished 319 episodes, mean reward 134.150, eps 0.58, speed 46.64 steps/s
# 42003: finished 320 episodes, mean reward 132.600, eps 0.58, speed 45.46 steps/s
# 42214: finished 321 episodes, mean reward 137.400, eps 0.58, speed 47.07 steps/s
# 42286: finished 322 episodes, mean reward 137.750, eps 0.58, speed 43.55 steps/s
# 42448: finished 323 episodes, mean reward 138.650, eps 0.58, speed 42.70 steps/s
# 42665: finished 324 episodes, mean reward 139.250, eps 0.57, speed 44.94 steps/s
# 42902: finished 325 episodes, mean reward 139.800, eps 0.57, speed 48.27 steps/s
# 43083: finished 326 episodes, mean reward 140.500, eps 0.57, speed 46.85 steps/s
# 43293: finished 327 episodes, mean reward 141.850, eps 0.57, speed 46.75 steps/s
# 43502: finished 328 episodes, mean reward 143.650, eps 0.56, speed 45.24 steps/s
# 43716: finished 329 episodes, mean reward 144.650, eps 0.56, speed 45.77 steps/s
# 43924: finished 330 episodes, mean reward 148.700, eps 0.56, speed 44.83 steps/s
# 44019: finished 331 episodes, mean reward 148.150, eps 0.56, speed 42.55 steps/s
# 44140: finished 332 episodes, mean reward 147.300, eps 0.56, speed 40.34 steps/s
# 44314: finished 333 episodes, mean reward 150.450, eps 0.56, speed 39.50 steps/s
# 44511: finished 334 episodes, mean reward 151.650, eps 0.55, speed 39.92 steps/s
# 44720: finished 335 episodes, mean reward 152.350, eps 0.55, speed 39.63 steps/s
# 44849: finished 336 episodes, mean reward 152.250, eps 0.55, speed 41.66 steps/s
# 44973: finished 337 episodes, mean reward 153.350, eps 0.55, speed 37.13 steps/s
# 45115: finished 338 episodes, mean reward 154.000, eps 0.55, speed 36.16 steps/s
# 45255: finished 339 episodes, mean reward 153.950, eps 0.55, speed 32.88 steps/s
# 45374: finished 340 episodes, mean reward 155.650, eps 0.55, speed 37.84 steps/s
# 45584: finished 341 episodes, mean reward 156.700, eps 0.54, speed 41.66 steps/s
# 45702: finished 342 episodes, mean reward 156.650, eps 0.54, speed 43.09 steps/s
# 45802: finished 343 episodes, mean reward 156.800, eps 0.54, speed 41.82 steps/s
# 45929: finished 344 episodes, mean reward 155.400, eps 0.54, speed 50.88 steps/s
# 46073: finished 345 episodes, mean reward 156.350, eps 0.54, speed 49.49 steps/s
# 46142: finished 346 episodes, mean reward 155.600, eps 0.54, speed 50.55 steps/s
# 46311: finished 347 episodes, mean reward 159.850, eps 0.54, speed 48.10 steps/s
# 46526: finished 348 episodes, mean reward 164.050, eps 0.53, speed 51.08 steps/s
# 46766: finished 349 episodes, mean reward 163.950, eps 0.53, speed 51.21 steps/s
# 46854: finished 350 episodes, mean reward 163.950, eps 0.53, speed 50.77 steps/s
# 46941: finished 351 episodes, mean reward 164.800, eps 0.53, speed 50.79 steps/s
# 47093: finished 352 episodes, mean reward 166.550, eps 0.53, speed 48.13 steps/s
# 47257: finished 353 episodes, mean reward 166.200, eps 0.53, speed 50.81 steps/s
# 47377: finished 354 episodes, mean reward 165.650, eps 0.53, speed 50.31 steps/s
# 47497: finished 355 episodes, mean reward 164.950, eps 0.53, speed 50.78 steps/s
# 47645: finished 356 episodes, mean reward 163.800, eps 0.52, speed 50.11 steps/s
# 47796: finished 357 episodes, mean reward 165.500, eps 0.52, speed 49.39 steps/s
# 48032: finished 358 episodes, mean reward 168.100, eps 0.52, speed 49.20 steps/s
# 48303: finished 359 episodes, mean reward 168.550, eps 0.52, speed 48.95 steps/s
# 48415: finished 360 episodes, mean reward 169.250, eps 0.52, speed 46.71 steps/s
# 48541: finished 361 episodes, mean reward 168.800, eps 0.51, speed 45.65 steps/s
# 48665: finished 362 episodes, mean reward 168.700, eps 0.51, speed 46.99 steps/s
# 48782: finished 363 episodes, mean reward 169.900, eps 0.51, speed 50.41 steps/s
# 48926: finished 364 episodes, mean reward 168.350, eps 0.51, speed 48.12 steps/s
# 49103: finished 365 episodes, mean reward 169.850, eps 0.51, speed 45.39 steps/s
# 49295: finished 366 episodes, mean reward 171.500, eps 0.51, speed 49.80 steps/s
# 49436: finished 367 episodes, mean reward 171.400, eps 0.51, speed 46.02 steps/s
# 49498: finished 368 episodes, mean reward 171.150, eps 0.51, speed 44.81 steps/s
# 49687: finished 369 episodes, mean reward 171.350, eps 0.50, speed 48.96 steps/s
# 49839: finished 370 episodes, mean reward 172.000, eps 0.50, speed 45.06 steps/s
# 49938: finished 371 episodes, mean reward 172.550, eps 0.50, speed 38.60 steps/s
# 50129: finished 372 episodes, mean reward 176.450, eps 0.50, speed 43.18 steps/s
# 50260: finished 373 episodes, mean reward 177.550, eps 0.50, speed 47.30 steps/s
# 50473: finished 374 episodes, mean reward 178.850, eps 0.50, speed 47.09 steps/s
# 50630: finished 375 episodes, mean reward 179.800, eps 0.49, speed 49.49 steps/s
# 50722: finished 376 episodes, mean reward 177.650, eps 0.49, speed 53.22 steps/s
# 50783: finished 377 episodes, mean reward 177.500, eps 0.49, speed 52.67 steps/s
# 50983: finished 378 episodes, mean reward 180.000, eps 0.49, speed 53.57 steps/s
# 51172: finished 379 episodes, mean reward 181.950, eps 0.49, speed 48.63 steps/s
# 51331: finished 380 episodes, mean reward 183.250, eps 0.49, speed 49.34 steps/s
# 51455: finished 381 episodes, mean reward 183.500, eps 0.49, speed 50.27 steps/s
# 51556: finished 382 episodes, mean reward 183.100, eps 0.48, speed 50.70 steps/s
# 51779: finished 383 episodes, mean reward 186.550, eps 0.48, speed 52.73 steps/s
# 52022: finished 384 episodes, mean reward 187.900, eps 0.48, speed 52.03 steps/s
# 52122: finished 385 episodes, mean reward 188.300, eps 0.48, speed 46.87 steps/s
# 52247: finished 386 episodes, mean reward 186.800, eps 0.48, speed 27.00 steps/s
# 52393: finished 387 episodes, mean reward 186.550, eps 0.48, speed 22.95 steps/s
# 52549: finished 388 episodes, mean reward 187.550, eps 0.47, speed 36.94 steps/s
# 52723: finished 389 episodes, mean reward 188.450, eps 0.47, speed 43.07 steps/s
# 52935: finished 390 episodes, mean reward 190.750, eps 0.47, speed 42.95 steps/s
# 53031: finished 391 episodes, mean reward 190.950, eps 0.47, speed 49.17 steps/s
# 53197: finished 392 episodes, mean reward 193.350, eps 0.47, speed 56.38 steps/s
# 53318: finished 393 episodes, mean reward 193.750, eps 0.47, speed 56.51 steps/s
# 53520: finished 394 episodes, mean reward 196.050, eps 0.46, speed 52.10 steps/s
# 53642: finished 395 episodes, mean reward 196.250, eps 0.46, speed 52.88 steps/s
# 53840: finished 396 episodes, mean reward 198.550, eps 0.46, speed 55.75 steps/s
# 53908: finished 397 episodes, mean reward 195.750, eps 0.46, speed 48.66 steps/s
# 54032: finished 398 episodes, mean reward 193.450, eps 0.46, speed 47.65 steps/s
# 54237: finished 399 episodes, mean reward 194.550, eps 0.46, speed 51.10 steps/s
# 54389: finished 400 episodes, mean reward 197.350, eps 0.46, speed 55.83 steps/s
# 54602: finished 401 episodes, mean reward 196.750, eps 0.45, speed 50.89 steps/s
# 54674: finished 402 episodes, mean reward 197.500, eps 0.45, speed 55.87 steps/s
# 54764: finished 403 episodes, mean reward 196.300, eps 0.45, speed 55.50 steps/s
# 54968: finished 404 episodes, mean reward 199.600, eps 0.45, speed 52.03 steps/s
# 55068: finished 405 episodes, mean reward 198.150, eps 0.45, speed 46.09 steps/s
# 55267: finished 406 episodes, mean reward 199.450, eps 0.45, speed 46.32 steps/s
# 55357: finished 407 episodes, mean reward 198.000, eps 0.45, speed 54.10 steps/s
# 55478: finished 408 episodes, mean reward 198.400, eps 0.45, speed 51.23 steps/s
# 55664: finished 409 episodes, mean reward 199.250, eps 0.44, speed 53.20 steps/s
# 55837: finished 410 episodes, mean reward 199.150, eps 0.44, speed 52.83 steps/s
# 55900: finished 411 episodes, mean reward 198.550, eps 0.44, speed 50.90 steps/s
# 56019: finished 412 episodes, mean reward 197.050, eps 0.44, speed 53.93 steps/s
# 56173: finished 413 episodes, mean reward 193.750, eps 0.44, speed 52.78 steps/s
# 56358: finished 414 episodes, mean reward 195.650, eps 0.44, speed 53.03 steps/s
# 56502: finished 415 episodes, mean reward 195.500, eps 0.43, speed 53.68 steps/s
# 56618: finished 416 episodes, mean reward 191.450, eps 0.43, speed 54.75 steps/s
# 56751: finished 417 episodes, mean reward 191.450, eps 0.43, speed 53.87 steps/s
# 56821: finished 418 episodes, mean reward 191.100, eps 0.43, speed 55.87 steps/s
# 56925: finished 419 episodes, mean reward 191.650, eps 0.43, speed 54.91 steps/s
# 57147: finished 420 episodes, mean reward 196.050, eps 0.43, speed 55.18 steps/s
# 57324: finished 421 episodes, mean reward 193.300, eps 0.43, speed 55.09 steps/s
# 57672: finished 422 episodes, mean reward 199.350, eps 0.42, speed 51.28 steps/s
# 57811: finished 423 episodes, mean reward 199.200, eps 0.42, speed 49.00 steps/s
# 58037: finished 424 episodes, mean reward 201.350, eps 0.42, speed 55.50 steps/s
# 58234: finished 425 episodes, mean reward 201.750, eps 0.42, speed 54.86 steps/s
# 58364: finished 426 episodes, mean reward 200.700, eps 0.42, speed 55.34 steps/s
# 58421: finished 427 episodes, mean reward 197.350, eps 0.42, speed 55.15 steps/s
# 58550: finished 428 episodes, mean reward 196.100, eps 0.41, speed 57.08 steps/s
# 58746: finished 429 episodes, mean reward 196.300, eps 0.41, speed 57.75 steps/s
# 58916: finished 430 episodes, mean reward 193.400, eps 0.41, speed 57.32 steps/s
# 59074: finished 431 episodes, mean reward 194.100, eps 0.41, speed 56.94 steps/s
# 59246: finished 432 episodes, mean reward 194.850, eps 0.41, speed 57.17 steps/s
# 59366: finished 433 episodes, mean reward 191.800, eps 0.41, speed 56.49 steps/s
# 59488: finished 434 episodes, mean reward 190.950, eps 0.41, speed 57.52 steps/s
# 59670: finished 435 episodes, mean reward 192.600, eps 0.40, speed 56.38 steps/s
# 59738: finished 436 episodes, mean reward 191.600, eps 0.40, speed 57.59 steps/s
# 59903: finished 437 episodes, mean reward 192.400, eps 0.40, speed 56.83 steps/s
# 59997: finished 438 episodes, mean reward 191.750, eps 0.40, speed 57.85 steps/s
# 60161: finished 439 episodes, mean reward 191.950, eps 0.40, speed 56.79 steps/s
# 60256: finished 440 episodes, mean reward 190.900, eps 0.40, speed 56.71 steps/s
# 60379: finished 441 episodes, mean reward 190.650, eps 0.40, speed 56.62 steps/s
# 60498: finished 442 episodes, mean reward 191.050, eps 0.40, speed 56.43 steps/s
# 60612: finished 443 episodes, mean reward 190.650, eps 0.39, speed 57.36 steps/s
# 60730: finished 444 episodes, mean reward 190.300, eps 0.39, speed 56.36 steps/s
# 60848: finished 445 episodes, mean reward 190.500, eps 0.39, speed 57.14 steps/s
# 60984: finished 446 episodes, mean reward 191.200, eps 0.39, speed 56.55 steps/s
# 61114: finished 447 episodes, mean reward 187.450, eps 0.39, speed 57.60 steps/s
# 61221: finished 448 episodes, mean reward 183.600, eps 0.39, speed 56.66 steps/s
# 61435: finished 449 episodes, mean reward 186.850, eps 0.39, speed 55.11 steps/s
# 61550: finished 450 episodes, mean reward 186.400, eps 0.38, speed 57.32 steps/s
# 61708: finished 451 episodes, mean reward 186.400, eps 0.38, speed 56.13 steps/s
# 61922: finished 452 episodes, mean reward 187.850, eps 0.38, speed 57.09 steps/s
# 62101: finished 453 episodes, mean reward 189.100, eps 0.38, speed 57.13 steps/s
# 62299: finished 454 episodes, mean reward 190.800, eps 0.38, speed 57.77 steps/s
# 62460: finished 455 episodes, mean reward 192.250, eps 0.38, speed 57.07 steps/s
# 62583: finished 456 episodes, mean reward 192.050, eps 0.37, speed 55.85 steps/s
# 62656: finished 457 episodes, mean reward 190.500, eps 0.37, speed 58.06 steps/s
# 62792: finished 458 episodes, mean reward 188.350, eps 0.37, speed 56.08 steps/s
# 62952: finished 459 episodes, mean reward 188.750, eps 0.37, speed 57.81 steps/s
# 63042: finished 460 episodes, mean reward 188.700, eps 0.37, speed 56.95 steps/s
# 63217: finished 461 episodes, mean reward 189.250, eps 0.37, speed 56.74 steps/s
# 63333: finished 462 episodes, mean reward 188.700, eps 0.37, speed 56.96 steps/s
# 63509: finished 463 episodes, mean reward 190.100, eps 0.36, speed 56.30 steps/s
# 63629: finished 464 episodes, mean reward 191.250, eps 0.36, speed 56.10 steps/s
# 63722: finished 465 episodes, mean reward 190.150, eps 0.36, speed 56.65 steps/s
# 63893: finished 466 episodes, mean reward 190.650, eps 0.36, speed 56.91 steps/s
# 64043: finished 467 episodes, mean reward 190.050, eps 0.36, speed 56.36 steps/s
# 64197: finished 468 episodes, mean reward 191.400, eps 0.36, speed 54.72 steps/s
# 64391: finished 469 episodes, mean reward 192.050, eps 0.36, speed 57.89 steps/s
# 64594: finished 470 episodes, mean reward 193.600, eps 0.35, speed 56.29 steps/s
# 64710: finished 471 episodes, mean reward 193.900, eps 0.35, speed 57.35 steps/s
# 64824: finished 472 episodes, mean reward 189.950, eps 0.35, speed 56.37 steps/s
# 64997: finished 473 episodes, mean reward 189.950, eps 0.35, speed 57.60 steps/s
# 65190: finished 474 episodes, mean reward 192.850, eps 0.35, speed 56.38 steps/s
# 65346: finished 475 episodes, mean reward 194.950, eps 0.35, speed 56.02 steps/s
# 65494: finished 476 episodes, mean reward 196.850, eps 0.35, speed 55.67 steps/s
# 65685: finished 477 episodes, mean reward 198.950, eps 0.34, speed 55.85 steps/s
# 65749: finished 478 episodes, mean reward 195.050, eps 0.34, speed 55.22 steps/s
# 65948: finished 479 episodes, mean reward 196.100, eps 0.34, speed 53.03 steps/s
# 66069: finished 480 episodes, mean reward 195.800, eps 0.34, speed 54.20 steps/s
# 66285: finished 481 episodes, mean reward 198.750, eps 0.34, speed 53.69 steps/s
# 66382: finished 482 episodes, mean reward 199.250, eps 0.34, speed 51.94 steps/s
# 66490: finished 483 episodes, mean reward 194.900, eps 0.34, speed 46.94 steps/s
# 66602: finished 484 episodes, mean reward 192.300, eps 0.33, speed 53.66 steps/s
# 66928: finished 485 episodes, mean reward 197.100, eps 0.33, speed 54.97 steps/s
# 67055: finished 486 episodes, mean reward 197.250, eps 0.33, speed 55.46 steps/s
# 67182: finished 487 episodes, mean reward 197.450, eps 0.33, speed 56.14 steps/s
# 67304: finished 488 episodes, mean reward 196.900, eps 0.33, speed 55.72 steps/s
# 67512: finished 489 episodes, mean reward 198.150, eps 0.32, speed 56.27 steps/s
# 67602: finished 490 episodes, mean reward 195.100, eps 0.32, speed 55.89 steps/s
# 67850: finished 491 episodes, mean reward 201.400, eps 0.32, speed 57.39 steps/s
# 68028: finished 492 episodes, mean reward 201.500, eps 0.32, speed 56.24 steps/s
# 68198: finished 493 episodes, mean reward 204.550, eps 0.32, speed 54.46 steps/s
# 68319: finished 494 episodes, mean reward 202.850, eps 0.32, speed 54.14 steps/s
# 68476: finished 495 episodes, mean reward 203.100, eps 0.32, speed 54.75 steps/s
# 68665: finished 496 episodes, mean reward 205.050, eps 0.31, speed 55.37 steps/s
# 68863: finished 497 episodes, mean reward 208.200, eps 0.31, speed 54.88 steps/s
# 69086: finished 498 episodes, mean reward 209.950, eps 0.31, speed 54.77 steps/s
# 69186: finished 499 episodes, mean reward 208.100, eps 0.31, speed 54.13 steps/s
# 69374: finished 500 episodes, mean reward 207.000, eps 0.31, speed 54.44 steps/s
# 69493: finished 501 episodes, mean reward 206.600, eps 0.31, speed 55.30 steps/s
# 69614: finished 502 episodes, mean reward 207.000, eps 0.30, speed 55.09 steps/s
# 69740: finished 503 episodes, mean reward 207.750, eps 0.30, speed 55.99 steps/s
# 69925: finished 504 episodes, mean reward 207.550, eps 0.30, speed 55.44 steps/s
# 70063: finished 505 episodes, mean reward 208.200, eps 0.30, speed 56.08 steps/s
# 70213: finished 506 episodes, mean reward 207.050, eps 0.30, speed 55.80 steps/s
# 70338: finished 507 episodes, mean reward 209.050, eps 0.30, speed 55.90 steps/s
# 70463: finished 508 episodes, mean reward 208.950, eps 0.30, speed 54.97 steps/s
# 70598: finished 509 episodes, mean reward 208.350, eps 0.29, speed 55.52 steps/s
# 70748: finished 510 episodes, mean reward 208.500, eps 0.29, speed 55.38 steps/s
# 70935: finished 511 episodes, mean reward 209.750, eps 0.29, speed 56.65 steps/s
# 71036: finished 512 episodes, mean reward 209.350, eps 0.29, speed 53.90 steps/s
# 71113: finished 513 episodes, mean reward 207.950, eps 0.29, speed 55.33 steps/s
# 71202: finished 514 episodes, mean reward 207.300, eps 0.29, speed 53.77 steps/s
# 71391: finished 515 episodes, mean reward 208.900, eps 0.29, speed 54.10 steps/s
# 71549: finished 516 episodes, mean reward 210.800, eps 0.28, speed 56.20 steps/s
# 71705: finished 517 episodes, mean reward 212.150, eps 0.28, speed 54.41 steps/s
# 71830: finished 518 episodes, mean reward 213.350, eps 0.28, speed 55.20 steps/s
# 71993: finished 519 episodes, mean reward 214.150, eps 0.28, speed 55.02 steps/s
# 72239: finished 520 episodes, mean reward 212.950, eps 0.28, speed 55.10 steps/s
# 72388: finished 521 episodes, mean reward 211.700, eps 0.28, speed 56.53 steps/s
# 72466: finished 522 episodes, mean reward 205.700, eps 0.28, speed 53.97 steps/s
# 72638: finished 523 episodes, mean reward 207.450, eps 0.27, speed 56.26 steps/s
# 72791: finished 524 episodes, mean reward 203.750, eps 0.27, speed 56.00 steps/s
# 72977: finished 525 episodes, mean reward 205.800, eps 0.27, speed 56.57 steps/s
# 73144: finished 526 episodes, mean reward 206.000, eps 0.27, speed 55.99 steps/s
# 73268: finished 527 episodes, mean reward 206.850, eps 0.27, speed 56.11 steps/s
# 73391: finished 528 episodes, mean reward 206.350, eps 0.27, speed 55.08 steps/s
# 73488: finished 529 episodes, mean reward 204.350, eps 0.27, speed 57.02 steps/s
# 73605: finished 530 episodes, mean reward 204.150, eps 0.26, speed 54.25 steps/s
# 73765: finished 531 episodes, mean reward 204.900, eps 0.26, speed 56.73 steps/s
# 73896: finished 532 episodes, mean reward 205.050, eps 0.26, speed 54.95 steps/s
# 74017: finished 533 episodes, mean reward 205.550, eps 0.26, speed 56.03 steps/s
# 74136: finished 534 episodes, mean reward 206.050, eps 0.26, speed 56.52 steps/s
# 74223: finished 535 episodes, mean reward 203.050, eps 0.26, speed 55.24 steps/s
# 74375: finished 536 episodes, mean reward 204.850, eps 0.26, speed 57.09 steps/s
# 74530: finished 537 episodes, mean reward 204.450, eps 0.25, speed 55.25 steps/s
# 74711: finished 538 episodes, mean reward 205.500, eps 0.25, speed 56.28 steps/s
# 74894: finished 539 episodes, mean reward 206.400, eps 0.25, speed 55.37 steps/s
# 75076: finished 540 episodes, mean reward 207.850, eps 0.25, speed 54.78 steps/s
# 75288: finished 541 episodes, mean reward 208.700, eps 0.25, speed 55.48 steps/s
# 75573: finished 542 episodes, mean reward 213.200, eps 0.24, speed 54.51 steps/s
# 75875: finished 543 episodes, mean reward 217.350, eps 0.24, speed 55.26 steps/s
# 76030: finished 544 episodes, mean reward 220.150, eps 0.24, speed 54.83 steps/s
# 76151: finished 545 episodes, mean reward 219.600, eps 0.24, speed 55.15 steps/s
# 76307: finished 546 episodes, mean reward 220.900, eps 0.24, speed 53.78 steps/s
# 76488: finished 547 episodes, mean reward 222.350, eps 0.24, speed 54.49 steps/s
# 76613: finished 548 episodes, mean reward 221.150, eps 0.23, speed 54.86 steps/s
# 76772: finished 549 episodes, mean reward 217.800, eps 0.23, speed 54.26 steps/s
# 76980: finished 550 episodes, mean reward 221.550, eps 0.23, speed 55.63 steps/s
# 77165: finished 551 episodes, mean reward 223.150, eps 0.23, speed 54.66 steps/s
# 77293: finished 552 episodes, mean reward 220.700, eps 0.23, speed 54.51 steps/s
# 77363: finished 553 episodes, mean reward 219.150, eps 0.23, speed 53.00 steps/s
# 77551: finished 554 episodes, mean reward 218.750, eps 0.22, speed 55.41 steps/s
# 77641: finished 555 episodes, mean reward 216.950, eps 0.22, speed 53.90 steps/s
# 77799: finished 556 episodes, mean reward 217.500, eps 0.22, speed 54.00 steps/s
# 77871: finished 557 episodes, mean reward 217.400, eps 0.22, speed 54.36 steps/s
# 78060: finished 558 episodes, mean reward 219.950, eps 0.22, speed 54.94 steps/s
# 78214: finished 559 episodes, mean reward 220.700, eps 0.22, speed 55.02 steps/s
# 78369: finished 560 episodes, mean reward 221.300, eps 0.22, speed 55.19 steps/s
# 78516: finished 561 episodes, mean reward 221.500, eps 0.21, speed 54.43 steps/s
# 78603: finished 562 episodes, mean reward 221.450, eps 0.21, speed 53.88 steps/s
# 78698: finished 563 episodes, mean reward 219.250, eps 0.21, speed 54.37 steps/s
# 78813: finished 564 episodes, mean reward 219.100, eps 0.21, speed 55.04 steps/s
# 78992: finished 565 episodes, mean reward 220.850, eps 0.21, speed 55.06 steps/s
# 79123: finished 566 episodes, mean reward 218.750, eps 0.21, speed 55.56 steps/s
# 79431: finished 567 episodes, mean reward 224.000, eps 0.21, speed 56.45 steps/s
# 79517: finished 568 episodes, mean reward 223.300, eps 0.20, speed 55.81 steps/s
# 79716: finished 569 episodes, mean reward 224.700, eps 0.20, speed 53.70 steps/s
# 79815: finished 570 episodes, mean reward 222.400, eps 0.20, speed 52.66 steps/s
# 79929: finished 571 episodes, mean reward 222.100, eps 0.20, speed 51.43 steps/s
# 80150: finished 572 episodes, mean reward 225.350, eps 0.20, speed 52.12 steps/s
# 80212: finished 573 episodes, mean reward 224.050, eps 0.20, speed 52.24 steps/s
# 80417: finished 574 episodes, mean reward 221.950, eps 0.20, speed 52.06 steps/s
# 80594: finished 575 episodes, mean reward 221.050, eps 0.19, speed 51.78 steps/s
# 80730: finished 576 episodes, mean reward 219.750, eps 0.19, speed 50.96 steps/s
# 81016: finished 577 episodes, mean reward 220.950, eps 0.19, speed 51.59 steps/s
# 81183: finished 578 episodes, mean reward 221.850, eps 0.19, speed 51.62 steps/s
# 81367: finished 579 episodes, mean reward 221.000, eps 0.19, speed 51.81 steps/s
# 81587: finished 580 episodes, mean reward 222.250, eps 0.18, speed 49.61 steps/s
# 81762: finished 581 episodes, mean reward 219.550, eps 0.18, speed 50.13 steps/s
# 81891: finished 582 episodes, mean reward 220.850, eps 0.18, speed 50.95 steps/s
# 82018: finished 583 episodes, mean reward 221.200, eps 0.18, speed 48.65 steps/s
# 82179: finished 584 episodes, mean reward 221.700, eps 0.18, speed 51.72 steps/s
# 82360: finished 585 episodes, mean reward 218.300, eps 0.18, speed 50.89 steps/s
# 82474: finished 586 episodes, mean reward 217.500, eps 0.18, speed 50.94 steps/s
# 82594: finished 587 episodes, mean reward 217.450, eps 0.17, speed 50.46 steps/s
# 82811: finished 588 episodes, mean reward 219.250, eps 0.17, speed 51.17 steps/s
# 83049: finished 589 episodes, mean reward 222.850, eps 0.17, speed 48.58 steps/s
# 83117: finished 590 episodes, mean reward 222.850, eps 0.17, speed 50.43 steps/s
# 83267: finished 591 episodes, mean reward 216.550, eps 0.17, speed 50.63 steps/s
# 83360: finished 592 episodes, mean reward 213.550, eps 0.17, speed 51.34 steps/s
# 83693: finished 593 episodes, mean reward 217.100, eps 0.16, speed 52.17 steps/s
# ...
# 2958129: finished 13890 episodes, mean reward 478.850, eps 0.02, speed 55.41 steps/s
# 2958287: finished 13891 episodes, mean reward 476.650, eps 0.02, speed 54.82 steps/s
# 2958734: finished 13892 episodes, mean reward 482.750, eps 0.02, speed 55.97 steps/s
# 2958948: finished 13893 episodes, mean reward 480.500, eps 0.02, speed 55.51 steps/s
# 2959107: finished 13894 episodes, mean reward 481.700, eps 0.02, speed 54.51 steps/s
# 2959353: finished 13895 episodes, mean reward 482.400, eps 0.02, speed 56.22 steps/s
# 2959715: finished 13896 episodes, mean reward 489.500, eps 0.02, speed 56.19 steps/s
# 2959994: finished 13897 episodes, mean reward 486.750, eps 0.02, speed 55.20 steps/s
# 2960266: finished 13898 episodes, mean reward 488.800, eps 0.02, speed 54.94 steps/s
# 2960446: finished 13899 episodes, mean reward 489.400, eps 0.02, speed 55.46 steps/s
# 2960733: finished 13900 episodes, mean reward 493.100, eps 0.02, speed 54.94 steps/s
# 2961062: finished 13901 episodes, mean reward 497.950, eps 0.02, speed 56.36 steps/s
# 2961315: finished 13902 episodes, mean reward 497.250, eps 0.02, speed 55.03 steps/s
# 2961437: finished 13903 episodes, mean reward 493.550, eps 0.02, speed 54.25 steps/s
# 2961574: finished 13904 episodes, mean reward 493.750, eps 0.02, speed 54.76 steps/s
# 2961767: finished 13905 episodes, mean reward 494.250, eps 0.02, speed 54.69 steps/s
# 2961875: finished 13906 episodes, mean reward 490.800, eps 0.02, speed 54.97 steps/s
# 2962131: finished 13907 episodes, mean reward 493.700, eps 0.02, speed 55.42 steps/s
# 2962280: finished 13908 episodes, mean reward 495.100, eps 0.02, speed 55.11 steps/s
# 2962533: finished 13909 episodes, mean reward 497.450, eps 0.02, speed 56.36 steps/s
# 2962807: finished 13910 episodes, mean reward 503.150, eps 0.02, speed 55.69 steps/s
# 2963053: finished 13911 episodes, mean reward 501.450, eps 0.02, speed 55.59 steps/s
# 2963252: finished 13912 episodes, mean reward 499.200, eps 0.02, speed 54.55 steps/s
# 2963466: finished 13913 episodes, mean reward 498.800, eps 0.02, speed 55.30 steps/s
# 2963668: finished 13914 episodes, mean reward 500.450, eps 0.02, speed 55.34 steps/s
# 2963826: finished 13915 episodes, mean reward 497.650, eps 0.02, speed 54.09 steps/s
# 2964106: finished 13916 episodes, mean reward 500.550, eps 0.02, speed 54.55 steps/s
# 2964381: finished 13917 episodes, mean reward 500.400, eps 0.02, speed 55.00 steps/s
# 2964630: finished 13918 episodes, mean reward 503.250, eps 0.02, speed 55.38 steps/s
# 2964747: finished 13919 episodes, mean reward 498.700, eps 0.02, speed 45.25 steps/s
# 2964945: finished 13920 episodes, mean reward 495.950, eps 0.02, speed 49.93 steps/s
# 2965101: finished 13921 episodes, mean reward 494.250, eps 0.02, speed 53.02 steps/s
# 2965332: finished 13922 episodes, mean reward 493.750, eps 0.02, speed 54.54 steps/s
# 2965630: finished 13923 episodes, mean reward 493.500, eps 0.02, speed 55.16 steps/s
# 2965835: finished 13924 episodes, mean reward 495.300, eps 0.02, speed 55.08 steps/s
# 2965929: finished 13925 episodes, mean reward 490.700, eps 0.02, speed 54.40 steps/s
# 2966298: finished 13926 episodes, mean reward 493.000, eps 0.02, speed 53.92 steps/s
# 2966595: finished 13927 episodes, mean reward 500.600, eps 0.02, speed 50.80 steps/s
# 2966790: finished 13928 episodes, mean reward 499.150, eps 0.02, speed 47.05 steps/s
# 2967063: finished 13929 episodes, mean reward 504.700, eps 0.02, speed 47.75 steps/s
# 2967355: finished 13930 episodes, mean reward 503.800, eps 0.02, speed 48.19 steps/s
# 2967494: finished 13931 episodes, mean reward 502.200, eps 0.02, speed 47.63 steps/s
# 2967678: finished 13932 episodes, mean reward 499.300, eps 0.02, speed 48.05 steps/s
# 2967935: finished 13933 episodes, mean reward 500.400, eps 0.02, speed 48.16 steps/s
# 2968134: finished 13934 episodes, mean reward 502.150, eps 0.02, speed 48.63 steps/s
# 2968384: finished 13935 episodes, mean reward 500.700, eps 0.02, speed 48.20 steps/s
# 2968600: finished 13936 episodes, mean reward 498.950, eps 0.02, speed 45.28 steps/s
# 2968831: finished 13937 episodes, mean reward 498.550, eps 0.02, speed 41.55 steps/s
# 2968978: finished 13938 episodes, mean reward 497.900, eps 0.02, speed 42.15 steps/s
# 2969213: finished 13939 episodes, mean reward 501.500, eps 0.02, speed 49.62 steps/s
# 2969480: finished 13940 episodes, mean reward 500.600, eps 0.02, speed 51.64 steps/s
# 2969706: finished 13941 episodes, mean reward 504.450, eps 0.02, speed 51.07 steps/s
# 2969939: finished 13942 episodes, mean reward 502.550, eps 0.02, speed 53.18 steps/s
# 2970187: finished 13943 episodes, mean reward 502.050, eps 0.02, speed 53.42 steps/s
# 2970432: finished 13944 episodes, mean reward 506.350, eps 0.02, speed 53.94 steps/s
# 2970568: finished 13945 episodes, mean reward 503.000, eps 0.02, speed 54.68 steps/s
# 2970857: finished 13946 episodes, mean reward 504.900, eps 0.02, speed 55.23 steps/s
# 2971113: finished 13947 episodes, mean reward 505.600, eps 0.02, speed 54.71 steps/s
# 2971332: finished 13948 episodes, mean reward 508.000, eps 0.02, speed 55.71 steps/s
# 2971616: finished 13949 episodes, mean reward 510.800, eps 0.02, speed 54.97 steps/s
# 2971797: finished 13950 episodes, mean reward 512.450, eps 0.02, speed 54.51 steps/s
# 2972068: finished 13951 episodes, mean reward 515.350, eps 0.02, speed 55.86 steps/s
# 2972284: finished 13952 episodes, mean reward 513.950, eps 0.02, speed 55.15 steps/s
# 2972593: finished 13953 episodes, mean reward 516.850, eps 0.02, speed 55.65 steps/s
# 2972844: finished 13954 episodes, mean reward 520.250, eps 0.02, speed 55.10 steps/s
# 2972966: finished 13955 episodes, mean reward 518.950, eps 0.02, speed 54.65 steps/s
# 2973233: finished 13956 episodes, mean reward 518.150, eps 0.02, speed 55.56 steps/s
# 2973482: finished 13957 episodes, mean reward 522.500, eps 0.02, speed 55.21 steps/s
# 2973786: finished 13958 episodes, mean reward 522.450, eps 0.02, speed 55.15 steps/s
# 2974043: finished 13959 episodes, mean reward 519.100, eps 0.02, speed 55.23 steps/s
# 2974330: finished 13960 episodes, mean reward 515.100, eps 0.02, speed 55.41 steps/s
# 2974606: finished 13961 episodes, mean reward 519.600, eps 0.02, speed 55.45 steps/s
# 2974772: finished 13962 episodes, mean reward 518.900, eps 0.02, speed 55.28 steps/s
# 2974914: finished 13963 episodes, mean reward 518.900, eps 0.02, speed 54.11 steps/s
# 2975166: finished 13964 episodes, mean reward 521.900, eps 0.02, speed 54.93 steps/s
# 2975314: finished 13965 episodes, mean reward 519.750, eps 0.02, speed 54.49 steps/s
# 2975566: finished 13966 episodes, mean reward 522.050, eps 0.02, speed 55.28 steps/s
# 2975732: finished 13967 episodes, mean reward 517.150, eps 0.02, speed 54.98 steps/s
# 2975963: finished 13968 episodes, mean reward 519.850, eps 0.02, speed 55.87 steps/s
# 2976181: finished 13969 episodes, mean reward 521.000, eps 0.02, speed 55.49 steps/s
# 2976367: finished 13970 episodes, mean reward 521.650, eps 0.02, speed 54.74 steps/s
# 2976485: finished 13971 episodes, mean reward 517.200, eps 0.02, speed 55.17 steps/s
# 2976706: finished 13972 episodes, mean reward 518.350, eps 0.02, speed 54.30 steps/s
# 2976964: finished 13973 episodes, mean reward 522.200, eps 0.02, speed 55.25 steps/s
# 2977203: finished 13974 episodes, mean reward 522.650, eps 0.02, speed 55.74 steps/s
# 2977475: finished 13975 episodes, mean reward 524.050, eps 0.02, speed 55.79 steps/s
# 2977844: finished 13976 episodes, mean reward 530.750, eps 0.02, speed 55.49 steps/s
# 2978113: finished 13977 episodes, mean reward 531.900, eps 0.02, speed 55.10 steps/s
# 2978379: finished 13978 episodes, mean reward 525.450, eps 0.02, speed 52.99 steps/s
# 2978634: finished 13979 episodes, mean reward 528.800, eps 0.02, speed 54.95 steps/s
# 2978961: finished 13980 episodes, mean reward 533.450, eps 0.02, speed 54.67 steps/s
# 2979239: finished 13981 episodes, mean reward 529.300, eps 0.02, speed 54.32 steps/s
# 2979517: finished 13982 episodes, mean reward 531.100, eps 0.02, speed 54.26 steps/s
# 2979769: finished 13983 episodes, mean reward 534.350, eps 0.02, speed 54.28 steps/s
# 2979894: finished 13984 episodes, mean reward 530.850, eps 0.02, speed 53.98 steps/s
# 2980103: finished 13985 episodes, mean reward 534.750, eps 0.02, speed 53.44 steps/s
# 2980379: finished 13986 episodes, mean reward 539.050, eps 0.02, speed 55.08 steps/s
# 2980656: finished 13987 episodes, mean reward 536.700, eps 0.02, speed 55.06 steps/s
# 2980825: finished 13988 episodes, mean reward 534.650, eps 0.02, speed 54.40 steps/s
# 2981031: finished 13989 episodes, mean reward 531.100, eps 0.02, speed 55.00 steps/s
# 2981185: finished 13990 episodes, mean reward 526.600, eps 0.02, speed 54.23 steps/s
# 2981442: finished 13991 episodes, mean reward 530.150, eps 0.02, speed 55.82 steps/s
# 2981729: finished 13992 episodes, mean reward 527.600, eps 0.02, speed 55.89 steps/s
# 2981936: finished 13993 episodes, mean reward 528.300, eps 0.02, speed 53.96 steps/s
# 2982073: finished 13994 episodes, mean reward 525.350, eps 0.02, speed 54.52 steps/s
# 2982351: finished 13995 episodes, mean reward 523.250, eps 0.02, speed 52.69 steps/s
# 2982523: finished 13996 episodes, mean reward 518.300, eps 0.02, speed 53.36 steps/s
# 2982663: finished 13997 episodes, mean reward 520.900, eps 0.02, speed 54.06 steps/s
# 2982879: finished 13998 episodes, mean reward 522.900, eps 0.02, speed 54.44 steps/s
# 2983088: finished 13999 episodes, mean reward 524.700, eps 0.02, speed 54.63 steps/s
# 2983215: finished 14000 episodes, mean reward 517.650, eps 0.02, speed 54.02 steps/s
# 2983362: finished 14001 episodes, mean reward 510.450, eps 0.02, speed 52.89 steps/s
# 2983569: finished 14002 episodes, mean reward 509.700, eps 0.02, speed 54.06 steps/s
# 2983867: finished 14003 episodes, mean reward 513.800, eps 0.02, speed 54.31 steps/s
# 2984044: finished 14004 episodes, mean reward 511.650, eps 0.02, speed 52.74 steps/s
# 2984294: finished 14005 episodes, mean reward 514.650, eps 0.02, speed 53.78 steps/s
# 2984442: finished 14006 episodes, mean reward 517.500, eps 0.02, speed 52.60 steps/s
# 2984650: finished 14007 episodes, mean reward 515.300, eps 0.02, speed 54.49 steps/s
# 2984934: finished 14008 episodes, mean reward 521.150, eps 0.02, speed 54.55 steps/s
# 2985144: finished 14009 episodes, mean reward 517.150, eps 0.02, speed 54.63 steps/s
# 2985366: finished 14010 episodes, mean reward 516.100, eps 0.02, speed 53.74 steps/s
# 2985635: finished 14011 episodes, mean reward 516.000, eps 0.02, speed 54.37 steps/s
# 2985899: finished 14012 episodes, mean reward 514.900, eps 0.02, speed 53.33 steps/s
# 2986153: finished 14013 episodes, mean reward 511.950, eps 0.02, speed 53.84 steps/s
# 2986363: finished 14014 episodes, mean reward 513.150, eps 0.02, speed 53.71 steps/s
# 2986622: finished 14015 episodes, mean reward 516.100, eps 0.02, speed 53.83 steps/s
# 2986898: finished 14016 episodes, mean reward 513.400, eps 0.02, speed 54.97 steps/s
# 2987193: finished 14017 episodes, mean reward 514.650, eps 0.02, speed 55.50 steps/s
# 2987311: finished 14018 episodes, mean reward 510.750, eps 0.02, speed 52.99 steps/s
# 2987576: finished 14019 episodes, mean reward 514.000, eps 0.02, speed 55.11 steps/s
# 2987870: finished 14020 episodes, mean reward 516.800, eps 0.02, speed 55.35 steps/s
# 2988109: finished 14021 episodes, mean reward 518.250, eps 0.02, speed 55.40 steps/s
# 2988331: finished 14022 episodes, mean reward 517.050, eps 0.02, speed 53.65 steps/s
# 2988547: finished 14023 episodes, mean reward 515.900, eps 0.02, speed 53.55 steps/s
# 2988868: finished 14024 episodes, mean reward 516.200, eps 0.02, speed 54.97 steps/s
# 2989111: finished 14025 episodes, mean reward 521.700, eps 0.02, speed 54.61 steps/s
# 2989275: finished 14026 episodes, mean reward 519.600, eps 0.02, speed 54.21 steps/s
# 2989505: finished 14027 episodes, mean reward 515.400, eps 0.02, speed 55.02 steps/s
# 2989821: finished 14028 episodes, mean reward 514.150, eps 0.02, speed 54.85 steps/s
# 2990053: finished 14029 episodes, mean reward 510.950, eps 0.02, speed 54.35 steps/s
# 2990327: finished 14030 episodes, mean reward 511.550, eps 0.02, speed 54.38 steps/s
# 2990463: finished 14031 episodes, mean reward 511.150, eps 0.02, speed 53.85 steps/s
# 2990670: finished 14032 episodes, mean reward 511.650, eps 0.02, speed 54.18 steps/s
# 2990930: finished 14033 episodes, mean reward 512.500, eps 0.02, speed 55.65 steps/s
# 2991174: finished 14034 episodes, mean reward 512.550, eps 0.02, speed 54.39 steps/s
# 2991421: finished 14035 episodes, mean reward 513.000, eps 0.02, speed 54.75 steps/s
# 2991576: finished 14036 episodes, mean reward 513.100, eps 0.02, speed 54.15 steps/s
# 2991792: finished 14037 episodes, mean reward 511.000, eps 0.02, speed 54.74 steps/s
# 2991944: finished 14038 episodes, mean reward 513.150, eps 0.02, speed 54.48 steps/s
# 2992143: finished 14039 episodes, mean reward 507.750, eps 0.02, speed 54.30 steps/s
# 2992391: finished 14040 episodes, mean reward 510.450, eps 0.02, speed 54.95 steps/s
# 2992512: finished 14041 episodes, mean reward 505.950, eps 0.02, speed 53.09 steps/s
# 2992663: finished 14042 episodes, mean reward 508.700, eps 0.02, speed 54.28 steps/s
# 2992882: finished 14043 episodes, mean reward 509.550, eps 0.02, speed 53.70 steps/s
# 2993189: finished 14044 episodes, mean reward 509.900, eps 0.02, speed 55.18 steps/s
# 2993486: finished 14045 episodes, mean reward 514.950, eps 0.02, speed 55.72 steps/s
# 2993725: finished 14046 episodes, mean reward 514.900, eps 0.02, speed 54.55 steps/s
# 2993864: finished 14047 episodes, mean reward 508.750, eps 0.02, speed 53.36 steps/s
# 2994046: finished 14048 episodes, mean reward 510.500, eps 0.02, speed 55.87 steps/s
# 2994167: finished 14049 episodes, mean reward 505.600, eps 0.02, speed 54.49 steps/s
# 2994477: finished 14050 episodes, mean reward 506.950, eps 0.02, speed 55.16 steps/s
# 2994624: finished 14051 episodes, mean reward 503.050, eps 0.02, speed 55.77 steps/s
# 2994923: finished 14052 episodes, mean reward 507.750, eps 0.02, speed 52.82 steps/s
# 2995190: finished 14053 episodes, mean reward 507.200, eps 0.02, speed 55.28 steps/s
# 2995506: finished 14054 episodes, mean reward 506.000, eps 0.02, speed 55.66 steps/s
# 2995642: finished 14055 episodes, mean reward 507.150, eps 0.02, speed 54.24 steps/s
# 2995917: finished 14056 episodes, mean reward 506.400, eps 0.02, speed 54.32 steps/s
# 2996174: finished 14057 episodes, mean reward 505.450, eps 0.02, speed 54.67 steps/s
# 2996321: finished 14058 episodes, mean reward 502.550, eps 0.02, speed 55.79 steps/s
# 2996524: finished 14059 episodes, mean reward 500.400, eps 0.02, speed 43.65 steps/s
# 2996681: finished 14060 episodes, mean reward 498.550, eps 0.02, speed 50.53 steps/s
# 2996888: finished 14061 episodes, mean reward 496.800, eps 0.02, speed 52.30 steps/s
# 2997011: finished 14062 episodes, mean reward 494.450, eps 0.02, speed 51.91 steps/s
# 2997220: finished 14063 episodes, mean reward 499.350, eps 0.02, speed 49.41 steps/s
# 2997342: finished 14064 episodes, mean reward 495.650, eps 0.02, speed 50.56 steps/s
# 2997654: finished 14065 episodes, mean reward 498.750, eps 0.02, speed 52.51 steps/s
# 2997910: finished 14066 episodes, mean reward 496.350, eps 0.02, speed 53.17 steps/s
# 2998211: finished 14067 episodes, mean reward 499.250, eps 0.02, speed 53.48 steps/s
# 2998512: finished 14068 episodes, mean reward 497.900, eps 0.02, speed 52.85 steps/s
# 2998720: finished 14069 episodes, mean reward 499.650, eps 0.02, speed 52.92 steps/s
# 2999027: finished 14070 episodes, mean reward 500.350, eps 0.02, speed 54.46 steps/s
# 2999229: finished 14071 episodes, mean reward 503.700, eps 0.02, speed 54.90 steps/s
# 2999432: finished 14072 episodes, mean reward 502.200, eps 0.02, speed 55.37 steps/s
# 2999702: finished 14073 episodes, mean reward 502.800, eps 0.02, speed 55.27 steps/s
# 2999987: finished 14074 episodes, mean reward 505.850, eps 0.02, speed 54.62 steps/s
# 3000140: finished 14075 episodes, mean reward 504.350, eps 0.02, speed 54.46 steps/s
# Solved in 3000140 steps with mean reward 504.350
# Model saved as models/ALE/SpaceInvaders-v5-2024-02-18,06-09-03.dat

# %% [markdown]
# ### grafico de demonstra a evolução do aprendizado

# %%
# Calculando a média móvel com uma janela de 100 episódios
janela = 200 # Suaviza as varianças para facilitar a leitura
#janela = 1 # Descomente para remover a suavisação

recompensas_suavizadas = np.convolve(lisat_fim, np.ones(janela)/janela, mode='valid')

# Criando uma lista de episódios para o eixo x
episodios = list(range(janela, janela + len(recompensas_suavizadas)))

# Plotando o gráfico das recompensas suavizadas ao longo do tempo
plt.plot(episodios, recompensas_suavizadas)
plt.title('Recompensas acumuladas suavizadas ao longo do treinamento')
plt.xlabel('Episódios')
plt.ylabel('Recompensas')
plt.show()

# %%
# Para carregar uma rede salva de arquivo, descomente o bloco abaixo
# Essa rede salva pode ser testada ou treinada por mais alguns passos

filename = "models/ALE/" + "SpaceInvaders-v5-2024-02-17,03-20-49.dat"
qnet.load_state_dict(torch.load(filename, map_location=lambda storage,loc: storage))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Gravando uma pratida pos treinamento com 1_200_000 passos

# %%
# Roda alguns episódigos com o modelo e salva os vídeos em arquivos
# Atenção: precisa rodar com os wrappers aplicados!
env2 = gym.make(ATARI_ENV_NAME, render_mode="rgb_array")
env2a = MaxAndSkipEnv(env2)
env2b = FireResetEnv(env2a)
env2c = ProcessFrame84(env2b)
env2d = ImageToPyTorch(env2c)
env2e = BufferWrapper(env2d, 4)
env2f = ScaledFloatFrame(env2e)

record_video_q_neuralnet(env2f, qnet, episodes=1, folder="./dqn-atari")
# Out:
# c:\Users\vinic\anaconda3\envs\APR24\Lib\site-packages\gymnasium\wrappers\record_video.py:87: UserWarning: WARN: Overwriting existing videos at c:\Users\vinic\OneDrive\Área de Trabalho\Faculdade\Repositorios\Repositorio_Academico_Multidisciplinar\Aprendizagem por Refoco\Projeto_Atari\dqn-atari folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# c:\Users\vinic\anaconda3\envs\APR24\Lib\site-packages\gymnasium\utils\passive_env_checker.py:364: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Moviepy - Building video c:\Users\vinic\OneDrive\Área de Trabalho\Faculdade\Repositorios\Repositorio_Academico_Multidisciplinar\Aprendizagem por Refoco\Projeto_Atari\dqn-atari\rl-video-episode-0.mp4.
# Moviepy - Writing video c:\Users\vinic\OneDrive\Área de Trabalho\Faculdade\Repositorios\Repositorio_Academico_Multidisciplinar\Aprendizagem por Refoco\Projeto_Atari\dqn-atari\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready c:\Users\vinic\OneDrive\Área de Trabalho\Faculdade\Repositorios\Repositorio_Academico_Multidisciplinar\Aprendizagem por Refoco\Projeto_Atari\dqn-atari\rl-video-episode-0.mp4
# Episode 0: 184 steps / return 545.00

# %%
display_videos_from_path('./dqn-atari')
# Out:
# <video alt="dqn-atari\rl-video-episode-0.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
#         <script>
#         var videos = document.getElementsByTagName('video');
#         for (var i = 0; i < videos.length; i++) {
#             videos[i].playbackRate = 1.0;
#         }
#         </script>

# %%
print(f"Tempo decorrido em horas para o treinamento: {(Tempo_total/3600):0.2f} horas")
# Out:
# Tempo decorrido em horas para o treinamento: 15.24 horas
