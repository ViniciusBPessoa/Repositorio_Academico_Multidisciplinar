# %% [markdown]
# ### Para o PPO a estrutura é muito parecida

# %%
import gymnasium as gym
import numpy as np
import tensorboard

# %load_ext tensorboard

import stable_baselines3
stable_baselines3.__version__
# Out:
# '2.1.0'

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# para treinar com ambientes Atari
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# %%
from stable_baselines3.ppo import CnnPolicy

# %%
# Defina os hiperparâmetros desejados
gamma = 0.99
learning_rate = 0.0003
n_epochs = 10
n_steps = 2046

ENV_NAME = 'ALE/SpaceInvaders-v5'
env = make_atari_env(ENV_NAME, n_envs=4, seed=12306488)
env = VecFrameStack(env, n_stack=4)

# Cria com uma rede convolucional como política e define os hiperparâmetros
model = PPO(CnnPolicy, env, gamma=gamma, learning_rate=learning_rate, n_epochs=n_epochs, tensorboard_log="log_dir", n_steps=n_steps, verbose=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 8184`, after every 127 untruncated mini-batches, there will be a truncated mini-batch of size 56
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2046 and n_envs=4)
#   warnings.warn(

# %%
# %tensorboard --logdir log_dir
# Out:
# Reusing TensorBoard on port 6006 (pid 18444), started 1 day, 17:01:50 ago. (Use '!kill 18444' to kill it.)
#       <iframe id="tensorboard-frame-6eecd8f463650d27" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6eecd8f463650d27");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Treina por 200 mil passos -- pode demorar mais de 5 min!
model.learn(total_timesteps=100_000)
# Out:
# Logging to log_dir\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    fps             | 231      |
# |    iterations      | 1        |
# |    time_elapsed    | 35       |
# |    total_timesteps | 8184     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 2           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 16368       |
# | train/                  |             |
# |    approx_kl            | 0.009032685 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.00326    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 0.502       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 3           |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 24552       |
# | train/                  |             |
# |    approx_kl            | 0.014640974 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0596      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 0.536       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 567         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 4           |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 32736       |
# | train/                  |             |
# |    approx_kl            | 0.022046138 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0215      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 0.487       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 575         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 5           |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 40920       |
# | train/                  |             |
# |    approx_kl            | 0.027189732 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0308      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0517     |
# |    value_loss           | 0.466       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 564        |
# |    ep_rew_mean          | 179        |
# | time/                   |            |
# |    fps                  | 179        |
# |    iterations           | 6          |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 49104      |
# | train/                  |            |
# |    approx_kl            | 0.03191726 |
# |    clip_fraction        | 0.341      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.7       |
# |    explained_variance   | 0.282      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0398    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0603    |
# |    value_loss           | 0.464      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 581         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 7           |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 57288       |
# | train/                  |             |
# |    approx_kl            | 0.039876126 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00181     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0628     |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 611         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 8           |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 65472       |
# | train/                  |             |
# |    approx_kl            | 0.048776425 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0378     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0696     |
# |    value_loss           | 0.394       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 9           |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 73656       |
# | train/                  |             |
# |    approx_kl            | 0.050513856 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0686     |
# |    value_loss           | 0.412       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 600        |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 10         |
# |    time_elapsed         | 464        |
# |    total_timesteps      | 81840      |
# | train/                  |            |
# |    approx_kl            | 0.05163259 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.332      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000991  |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0695    |
# |    value_loss           | 0.377      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 613         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 11          |
# |    time_elapsed         | 512         |
# |    total_timesteps      | 90024       |
# | train/                  |             |
# |    approx_kl            | 0.056548066 |
# |    clip_fraction        | 0.475       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0616     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0722     |
# |    value_loss           | 0.408       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 632        |
# |    ep_rew_mean          | 234        |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 12         |
# |    time_elapsed         | 562        |
# |    total_timesteps      | 98208      |
# | train/                  |            |
# |    approx_kl            | 0.06666117 |
# |    clip_fraction        | 0.497      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.336      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0467    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0739    |
# |    value_loss           | 0.354      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 621         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 13          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 106392      |
# | train/                  |             |
# |    approx_kl            | 0.070244245 |
# |    clip_fraction        | 0.501       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0268     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0756     |
# |    value_loss           | 0.299       |
# -----------------------------------------

# %% [markdown]
# ### Para esse caso precisamos avaliar os valores utilizando a lib optuna

# %%
import optuna

# %% [markdown]
# Como sugerido vou manter o range de otimização das variáveis entre 50% e 150% do valor original

# %%
def train_PPO(trial : optuna.Trial):
    # chama os métodos do "trial" (tentativa) para sugerir valores para os parâmetros
    n_steps    = trial.suggest_int('n_steps', 1023, 3069)
    gamma      = trial.suggest_float('gamma', 0.5, 1.50)
    lr         = trial.suggest_float('lr', 0.00015, 0.00045)
    n_epochs   = trial.suggest_int('n_epochs', 5, 15)
    # Defina os hiperparâmetros desejado

    ENV_NAME = 'ALE/SpaceInvaders-v5'
    env = make_atari_env(ENV_NAME, n_envs=4, seed=12306488)
    env = VecFrameStack(env, n_stack=4)

    # Crie o modelo com os hiperparâmetros sugeridos pelo Optuna
    model = PPO(CnnPolicy, env, gamma=gamma, learning_rate=lr, n_epochs=n_epochs, n_steps=n_steps, verbose=1)

    print(f"\nTRIAL NUMBER #{trial.number}: {trial.params}")

    # Treine o modelo por um número fixo de etapas
    model.learn(total_timesteps=100_000)

    mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)

    return mean_reward

# %%
study_PPO = optuna.create_study(direction='maximize',
                        storage='sqlite:///stud_PPO2.db',
                        study_name='validation_PPO',
                        load_if_exists=True)

# maximiza o valor de retorno de train_exp_sarsa, rodando "n_trials" vezes
# o parâmetro "n_jobs" indica a quantidade de CPUs a serem usadas (-1 para usar todas)
study_PPO.optimize(train_PPO, n_trials=12, n_jobs=-1)
# Out:
# [I 2024-02-18 05:48:15,673] A new study created in RDB with name: validation_PPO
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 9688`, after every 151 untruncated mini-batches, there will be a truncated mini-batch of size 24
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2422 and n_envs=4)
#   warnings.warn(
# Using cuda device
# Wrapping the env in a VecTransposeImage.
#
# TRIAL NUMBER #2: {'n_steps': 2422, 'gamma': 0.850299704721077, 'lr': 0.0002281152050716582, 'n_epochs': 6}
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 9592`, after every 149 untruncated mini-batches, there will be a truncated mini-batch of size 56
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2398 and n_envs=4)
#   warnings.warn(
# Using cuda device
# Wrapping the env in a VecTransposeImage.
#
# TRIAL NUMBER #0: {'n_steps': 2398, 'gamma': 0.6908464665742965, 'lr': 0.0003518997075672511, 'n_epochs': 12}
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5868`, after every 91 untruncated mini-batches, there will be a truncated mini-batch of size 44
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=1467 and n_envs=4)
#   warnings.warn(
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 11580`, after every 180 untruncated mini-batches, there will be a truncated mini-batch of size 60
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2895 and n_envs=4)
#   warnings.warn(
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 10016`, after every 156 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2504 and n_envs=4)
#   warnings.warn(
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4312`, after every 67 untruncated mini-batches, there will be a truncated mini-batch of size 24
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=1078 and n_envs=4)
#   warnings.warn(
# TRIAL NUMBER #5: {'n_steps': 1078, 'gamma': 0.797139096633719, 'lr': 0.00041944564908379795, 'n_epochs': 12}
#
# TRIAL NUMBER #4: {'n_steps': 2895, 'gamma': 0.6036412324990864, 'lr': 0.000375336135585277, 'n_epochs': 12}
#
# TRIAL NUMBER #3: {'n_steps': 1467, 'gamma': 0.6447064145967081, 'lr': 0.00023030603034713325, 'n_epochs': 7}
#
# TRIAL NUMBER #1: {'n_steps': 2504, 'gamma': 1.4688020233407568, 'lr': 0.00029710135406832834, 'n_epochs': 11}
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 506      |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    fps             | 42       |
# |    iterations      | 1        |
# |    time_elapsed    | 101      |
# |    total_timesteps | 4312     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 490      |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    fps             | 50       |
# |    iterations      | 1        |
# |    time_elapsed    | 117      |
# |    total_timesteps | 5868     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 529      |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    fps             | 54       |
# |    iterations      | 1        |
# |    time_elapsed    | 175      |
# |    total_timesteps | 9592     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 554      |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    fps             | 54       |
# |    iterations      | 1        |
# |    time_elapsed    | 177      |
# |    total_timesteps | 9688     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    fps             | 55       |
# |    iterations      | 1        |
# |    time_elapsed    | 180      |
# |    total_timesteps | 10016    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 542      |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    fps             | 60       |
# |    iterations      | 1        |
# |    time_elapsed    | 190      |
# |    total_timesteps | 11580    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 483         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 2           |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 11736       |
# | train/                  |             |
# |    approx_kl            | 0.011192795 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.00232    |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.00481    |
# |    n_updates            | 7           |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 0.0821      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 521       |
# |    ep_rew_mean          | 144       |
# | time/                   |           |
# |    fps                  | 35        |
# |    iterations           | 2         |
# |    time_elapsed         | 246       |
# |    total_timesteps      | 8624      |
# | train/                  |           |
# |    approx_kl            | 0.0300778 |
# |    clip_fraction        | 0.223     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.78     |
# |    explained_variance   | 0.0045    |
# |    learning_rate        | 0.000419  |
# |    loss                 | -0.101    |
# |    n_updates            | 12        |
# |    policy_gradient_loss | -0.0419   |
# |    value_loss           | 0.091     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 509        |
# |    ep_rew_mean          | 138        |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 2          |
# |    time_elapsed         | 332        |
# |    total_timesteps      | 19376      |
# | train/                  |            |
# |    approx_kl            | 0.01132061 |
# |    clip_fraction        | 0.0939     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | 0.0266     |
# |    learning_rate        | 0.000228   |
# |    loss                 | -0.00892   |
# |    n_updates            | 6          |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 0.152      |
# ----------------------------------------
# C:\Users\Pichau\AppData\Roaming\Python\Python311\site-packages\numpy\core\_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\Pichau\AppData\Roaming\Python\Python311\site-packages\numpy\core\_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\common\utils.py:65: RuntimeWarning: invalid value encountered in scalar divide
#   return np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 3           |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 17604       |
# | train/                  |             |
# |    approx_kl            | 0.013265374 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0289     |
# |    n_updates            | 14          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.0727      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 521        |
# |    ep_rew_mean          | 149        |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 3          |
# |    time_elapsed         | 380        |
# |    total_timesteps      | 12936      |
# | train/                  |            |
# |    approx_kl            | 0.04903601 |
# |    clip_fraction        | 0.402      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | 0.00892    |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.113     |
# |    n_updates            | 24         |
# |    policy_gradient_loss | -0.0782    |
# |    value_loss           | 0.0727     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 498         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 2           |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 19184       |
# | train/                  |             |
# |    approx_kl            | 0.030874431 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.00117    |
# |    learning_rate        | 0.000352    |
# |    loss                 | -0.0395     |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 0.0708      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 606       |
# |    ep_rew_mean          | 47.7      |
# | time/                   |           |
# |    fps                  | 44        |
# |    iterations           | 2         |
# |    time_elapsed         | 454       |
# |    total_timesteps      | 20032     |
# | train/                  |           |
# |    approx_kl            | 19353.504 |
# |    clip_fraction        | 0.969     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0961   |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.000297  |
# |    loss                 | 2.7e+22   |
# |    n_updates            | 11        |
# |    policy_gradient_loss | 0.175     |
# |    value_loss           | inf       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 517         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 4           |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 23472       |
# | train/                  |             |
# |    approx_kl            | 0.017814022 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0398     |
# |    n_updates            | 21          |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 0.0671      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 512         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 4           |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 17248       |
# | train/                  |             |
# |    approx_kl            | 0.070026875 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.000419    |
# |    loss                 | -0.103      |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0894     |
# |    value_loss           | 0.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 525         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 3           |
# |    time_elapsed         | 558         |
# |    total_timesteps      | 29064       |
# | train/                  |             |
# |    approx_kl            | 0.010933988 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.000228    |
# |    loss                 | 0.015       |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 0.143       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 553        |
# |    ep_rew_mean          | 158        |
# | time/                   |            |
# |    fps                  | 41         |
# |    iterations           | 2          |
# |    time_elapsed         | 555        |
# |    total_timesteps      | 23160      |
# | train/                  |            |
# |    approx_kl            | 0.03192633 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | -0.00506   |
# |    learning_rate        | 0.000375   |
# |    loss                 | -0.0954    |
# |    n_updates            | 12         |
# |    policy_gradient_loss | -0.0407    |
# |    value_loss           | 0.0628     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 5           |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 29340       |
# | train/                  |             |
# |    approx_kl            | 0.021127338 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0358     |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 0.0681      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 515        |
# |    ep_rew_mean          | 151        |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 5          |
# |    time_elapsed         | 663        |
# |    total_timesteps      | 21560      |
# | train/                  |            |
# |    approx_kl            | 0.08009583 |
# |    clip_fraction        | 0.548      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.66      |
# |    explained_variance   | 0.147      |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.119     |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.0911    |
# |    value_loss           | 0.0619     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 509         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 3           |
# |    time_elapsed         | 689         |
# |    total_timesteps      | 28776       |
# | train/                  |             |
# |    approx_kl            | 0.052674647 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.0672      |
# |    learning_rate        | 0.000352    |
# |    loss                 | -0.0796     |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0758     |
# |    value_loss           | 0.0582      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 693       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 40        |
# |    iterations           | 3         |
# |    time_elapsed         | 750       |
# |    total_timesteps      | 30048     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.000297  |
# |    loss                 | 3.14e+31  |
# |    n_updates            | 22        |
# |    policy_gradient_loss | -1.15e-09 |
# |    value_loss           | 1.95e+33  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 503         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 6           |
# |    time_elapsed         | 754         |
# |    total_timesteps      | 35208       |
# | train/                  |             |
# |    approx_kl            | 0.024108369 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0611     |
# |    n_updates            | 35          |
# |    policy_gradient_loss | -0.0509     |
# |    value_loss           | 0.064       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 521         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 4           |
# |    time_elapsed         | 768         |
# |    total_timesteps      | 38752       |
# | train/                  |             |
# |    approx_kl            | 0.014002995 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.000228    |
# |    loss                 | -0.0133     |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 522        |
# |    ep_rew_mean          | 161        |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 6          |
# |    time_elapsed         | 811        |
# |    total_timesteps      | 25872      |
# | train/                  |            |
# |    approx_kl            | 0.10631824 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.179      |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.137     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0555     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 506       |
# |    ep_rew_mean          | 143       |
# | time/                   |           |
# |    fps                  | 46        |
# |    iterations           | 7         |
# |    time_elapsed         | 877       |
# |    total_timesteps      | 41076     |
# | train/                  |           |
# |    approx_kl            | 0.0285124 |
# |    clip_fraction        | 0.311     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.68     |
# |    explained_variance   | 0.213     |
# |    learning_rate        | 0.00023   |
# |    loss                 | -0.0845   |
# |    n_updates            | 42        |
# |    policy_gradient_loss | -0.0547   |
# |    value_loss           | 0.0646    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 523        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 3          |
# |    time_elapsed         | 886        |
# |    total_timesteps      | 34740      |
# | train/                  |            |
# |    approx_kl            | 0.05774789 |
# |    clip_fraction        | 0.421      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.74      |
# |    explained_variance   | 0.129      |
# |    learning_rate        | 0.000375   |
# |    loss                 | -0.107     |
# |    n_updates            | 24         |
# |    policy_gradient_loss | -0.0743    |
# |    value_loss           | 0.0463     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 523         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 4           |
# |    time_elapsed         | 973         |
# |    total_timesteps      | 38368       |
# | train/                  |             |
# |    approx_kl            | 0.071958594 |
# |    clip_fraction        | 0.492       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.000352    |
# |    loss                 | -0.111      |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0839     |
# |    value_loss           | 0.0487      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 519        |
# |    ep_rew_mean          | 168        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 7          |
# |    time_elapsed         | 977        |
# |    total_timesteps      | 30184      |
# | train/                  |            |
# |    approx_kl            | 0.12731254 |
# |    clip_fraction        | 0.633      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.2        |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.0801    |
# |    n_updates            | 72         |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0515     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 538         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 5           |
# |    time_elapsed         | 989         |
# |    total_timesteps      | 48440       |
# | train/                  |             |
# |    approx_kl            | 0.017709984 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.000228    |
# |    loss                 | -0.0122     |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 542        |
# |    ep_rew_mean          | 165        |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 8          |
# |    time_elapsed         | 1018       |
# |    total_timesteps      | 46944      |
# | train/                  |            |
# |    approx_kl            | 0.03097288 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.66      |
# |    explained_variance   | 0.265      |
# |    learning_rate        | 0.00023    |
# |    loss                 | -0.0572    |
# |    n_updates            | 49         |
# |    policy_gradient_loss | -0.0573    |
# |    value_loss           | 0.0621     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 692       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 38        |
# |    iterations           | 4         |
# |    time_elapsed         | 1030      |
# |    total_timesteps      | 40064     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.000297  |
# |    loss                 | 2.73e+33  |
# |    n_updates            | 33        |
# |    policy_gradient_loss | -3.56e-10 |
# |    value_loss           | 1.46e+33  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 501       |
# |    ep_rew_mean          | 166       |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 8         |
# |    time_elapsed         | 1090      |
# |    total_timesteps      | 34496     |
# | train/                  |           |
# |    approx_kl            | 0.1357791 |
# |    clip_fraction        | 0.632     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.53     |
# |    explained_variance   | 0.228     |
# |    learning_rate        | 0.000419  |
# |    loss                 | -0.136    |
# |    n_updates            | 84        |
# |    policy_gradient_loss | -0.0988   |
# |    value_loss           | 0.0497    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 537        |
# |    ep_rew_mean          | 166        |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 9          |
# |    time_elapsed         | 1145       |
# |    total_timesteps      | 52812      |
# | train/                  |            |
# |    approx_kl            | 0.03462974 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | 0.254      |
# |    learning_rate        | 0.00023    |
# |    loss                 | -0.0632    |
# |    n_updates            | 56         |
# |    policy_gradient_loss | -0.0594    |
# |    value_loss           | 0.0637     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 544         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 6           |
# |    time_elapsed         | 1224        |
# |    total_timesteps      | 58128       |
# | train/                  |             |
# |    approx_kl            | 0.020794062 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.000228    |
# |    loss                 | -0.0526     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 520         |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 4           |
# |    time_elapsed         | 1228        |
# |    total_timesteps      | 46320       |
# | train/                  |             |
# |    approx_kl            | 0.078889266 |
# |    clip_fraction        | 0.511       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.000375    |
# |    loss                 | -0.116      |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0822     |
# |    value_loss           | 0.0362      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 580        |
# |    ep_rew_mean          | 181        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 5          |
# |    time_elapsed         | 1237       |
# |    total_timesteps      | 47960      |
# | train/                  |            |
# |    approx_kl            | 0.09517981 |
# |    clip_fraction        | 0.552      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.66      |
# |    explained_variance   | 0.221      |
# |    learning_rate        | 0.000352   |
# |    loss                 | -0.12      |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.0921    |
# |    value_loss           | 0.0436     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 518        |
# |    ep_rew_mean          | 182        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 9          |
# |    time_elapsed         | 1269       |
# |    total_timesteps      | 38808      |
# | train/                  |            |
# |    approx_kl            | 0.16586754 |
# |    clip_fraction        | 0.671      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.299      |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.139     |
# |    n_updates            | 96         |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 0.0523     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 535         |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 10          |
# |    time_elapsed         | 1289        |
# |    total_timesteps      | 58680       |
# | train/                  |             |
# |    approx_kl            | 0.036407534 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0843     |
# |    n_updates            | 63          |
# |    policy_gradient_loss | -0.0597     |
# |    value_loss           | 0.0593      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 692       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 38        |
# |    iterations           | 5         |
# |    time_elapsed         | 1310      |
# |    total_timesteps      | 50080     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.000297  |
# |    loss                 | 2.39e+33  |
# |    n_updates            | 44        |
# |    policy_gradient_loss | -5.36e-10 |
# |    value_loss           | 1.4e+33   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 555        |
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 10         |
# |    time_elapsed         | 1392       |
# |    total_timesteps      | 43120      |
# | train/                  |            |
# |    approx_kl            | 0.17652048 |
# |    clip_fraction        | 0.673      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.213      |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.125     |
# |    n_updates            | 108        |
# |    policy_gradient_loss | -0.108     |
# |    value_loss           | 0.051      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 11          |
# |    time_elapsed         | 1415        |
# |    total_timesteps      | 64548       |
# | train/                  |             |
# |    approx_kl            | 0.039893508 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0842     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0642     |
# |    value_loss           | 0.0615      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 556         |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 7           |
# |    time_elapsed         | 1433        |
# |    total_timesteps      | 67816       |
# | train/                  |             |
# |    approx_kl            | 0.022304842 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.000228    |
# |    loss                 | -0.0937     |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 0.123       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 528       |
# |    ep_rew_mean          | 177       |
# | time/                   |           |
# |    fps                  | 38        |
# |    iterations           | 6         |
# |    time_elapsed         | 1483      |
# |    total_timesteps      | 57552     |
# | train/                  |           |
# |    approx_kl            | 0.1276217 |
# |    clip_fraction        | 0.618     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.59     |
# |    explained_variance   | 0.214     |
# |    learning_rate        | 0.000352  |
# |    loss                 | -0.133    |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.0986   |
# |    value_loss           | 0.0396    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 568       |
# |    ep_rew_mean          | 221       |
# | time/                   |           |
# |    fps                  | 30        |
# |    iterations           | 11        |
# |    time_elapsed         | 1561      |
# |    total_timesteps      | 47432     |
# | train/                  |           |
# |    approx_kl            | 0.2119607 |
# |    clip_fraction        | 0.696     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.4      |
# |    explained_variance   | 0.217     |
# |    learning_rate        | 0.000419  |
# |    loss                 | -0.0996   |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -0.115    |
# |    value_loss           | 0.0514    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 510        |
# |    ep_rew_mean          | 156        |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 5          |
# |    time_elapsed         | 1564       |
# |    total_timesteps      | 57900      |
# | train/                  |            |
# |    approx_kl            | 0.10484432 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.315      |
# |    learning_rate        | 0.000375   |
# |    loss                 | -0.117     |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.0898    |
# |    value_loss           | 0.0319     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 545        |
# |    ep_rew_mean          | 189        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 12         |
# |    time_elapsed         | 1565       |
# |    total_timesteps      | 70416      |
# | train/                  |            |
# |    approx_kl            | 0.04308013 |
# |    clip_fraction        | 0.39       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.292      |
# |    learning_rate        | 0.00023    |
# |    loss                 | -0.0843    |
# |    n_updates            | 77         |
# |    policy_gradient_loss | -0.0644    |
# |    value_loss           | 0.058      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 693       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 6         |
# |    time_elapsed         | 1607      |
# |    total_timesteps      | 60096     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.000297  |
# |    loss                 | 1.84e+33  |
# |    n_updates            | 55        |
# |    policy_gradient_loss | -7.74e-10 |
# |    value_loss           | 1.42e+33  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 550        |
# |    ep_rew_mean          | 193        |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 8          |
# |    time_elapsed         | 1635       |
# |    total_timesteps      | 77504      |
# | train/                  |            |
# |    approx_kl            | 0.02744974 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.335      |
# |    learning_rate        | 0.000228   |
# |    loss                 | -0.0743    |
# |    n_updates            | 42         |
# |    policy_gradient_loss | -0.0514    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 552         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 13          |
# |    time_elapsed         | 1691        |
# |    total_timesteps      | 76284       |
# | train/                  |             |
# |    approx_kl            | 0.047666494 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0887     |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.0641     |
# |    value_loss           | 0.0626      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 574        |
# |    ep_rew_mean          | 224        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 12         |
# |    time_elapsed         | 1698       |
# |    total_timesteps      | 51744      |
# | train/                  |            |
# |    approx_kl            | 0.21207024 |
# |    clip_fraction        | 0.682      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.149     |
# |    n_updates            | 132        |
# |    policy_gradient_loss | -0.108     |
# |    value_loss           | 0.049      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 527        |
# |    ep_rew_mean          | 173        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 7          |
# |    time_elapsed         | 1739       |
# |    total_timesteps      | 67144      |
# | train/                  |            |
# |    approx_kl            | 0.14449786 |
# |    clip_fraction        | 0.639      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.242      |
# |    learning_rate        | 0.000352   |
# |    loss                 | -0.114     |
# |    n_updates            | 72         |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0391     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 537        |
# |    ep_rew_mean          | 208        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 14         |
# |    time_elapsed         | 1839       |
# |    total_timesteps      | 82152      |
# | train/                  |            |
# |    approx_kl            | 0.05294652 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.296      |
# |    learning_rate        | 0.00023    |
# |    loss                 | -0.0867    |
# |    n_updates            | 91         |
# |    policy_gradient_loss | -0.0675    |
# |    value_loss           | 0.0621     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 560        |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 13         |
# |    time_elapsed         | 1861       |
# |    total_timesteps      | 56056      |
# | train/                  |            |
# |    approx_kl            | 0.24008004 |
# |    clip_fraction        | 0.697      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.000419   |
# |    loss                 | -0.124     |
# |    n_updates            | 144        |
# |    policy_gradient_loss | -0.112     |
# |    value_loss           | 0.0471     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 575         |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 9           |
# |    time_elapsed         | 1869        |
# |    total_timesteps      | 87192       |
# | train/                  |             |
# |    approx_kl            | 0.030348158 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.000228    |
# |    loss                 | -0.00968    |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.0522     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 528        |
# |    ep_rew_mean          | 168        |
# ...
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.0447     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 509        |
# |    ep_rew_mean          | 169        |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 12         |
# |    time_elapsed         | 2560       |
# |    total_timesteps      | 104640     |
# | train/                  |            |
# |    approx_kl            | 0.09039916 |
# |    clip_fraction        | 0.522      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.261      |
# |    learning_rate        | 0.000295   |
# |    loss                 | -0.0839    |
# |    n_updates            | 88         |
# |    policy_gradient_loss | -0.0832    |
# |    value_loss           | 0.0414     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 546        |
# |    ep_rew_mean          | 192        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 10         |
# |    time_elapsed         | 1941       |
# |    total_timesteps      | 86280      |
# | train/                  |            |
# |    approx_kl            | 0.12759422 |
# |    clip_fraction        | 0.588      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.31       |
# |    learning_rate        | 0.000372   |
# |    loss                 | -0.121     |
# |    n_updates            | 81         |
# |    policy_gradient_loss | -0.0892    |
# |    value_loss           | 0.0354     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 729       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 47        |
# |    iterations           | 15        |
# |    time_elapsed         | 2060      |
# |    total_timesteps      | 97980     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.000281  |
# |    loss                 | 2.47e+23  |
# |    n_updates            | 112       |
# |    policy_gradient_loss | -7.03e-10 |
# |    value_loss           | inf       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 574        |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 8          |
# |    time_elapsed         | 2182       |
# |    total_timesteps      | 77632      |
# | train/                  |            |
# |    approx_kl            | 0.08772599 |
# |    clip_fraction        | 0.564      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.226      |
# |    learning_rate        | 0.000199   |
# |    loss                 | -0.125     |
# |    n_updates            | 91         |
# |    policy_gradient_loss | -0.0971    |
# |    value_loss           | 0.0553     |
# ----------------------------------------
# [I 2024-02-18 07:13:11,461] Trial 6 finished with value: 244.5 and parameters: {'n_steps': 2180, 'gamma': 0.5695731586684158, 'lr': 0.000294970703864418, 'n_epochs': 8}. Best is trial 2 with value: 333.0.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 538         |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 4           |
# |    time_elapsed         | 1546        |
# |    total_timesteps      | 48112       |
# | train/                  |             |
# |    approx_kl            | 0.038117345 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.000158    |
# |    loss                 | -0.0844     |
# |    n_updates            | 45          |
# |    policy_gradient_loss | -0.0761     |
# |    value_loss           | 0.0601      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 564        |
# |    ep_rew_mean          | 236        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 11         |
# |    time_elapsed         | 2739       |
# |    total_timesteps      | 100628     |
# | train/                  |            |
# |    approx_kl            | 0.22340356 |
# |    clip_fraction        | 0.687      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.306      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.122     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.109     |
# |    value_loss           | 0.0429     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 706       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 47        |
# |    iterations           | 16        |
# |    time_elapsed         | 2200      |
# |    total_timesteps      | 104512    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.000281  |
# |    loss                 | 5.56e+23  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -7.54e-10 |
# |    value_loss           | inf       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 553        |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 11         |
# |    time_elapsed         | 2128       |
# |    total_timesteps      | 94908      |
# | train/                  |            |
# |    approx_kl            | 0.14617501 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.327      |
# |    learning_rate        | 0.000372   |
# |    loss                 | -0.127     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0894    |
# |    value_loss           | 0.0337     |
# ----------------------------------------
# [I 2024-02-18 07:15:22,837] Trial 9 finished with value: 0.5 and parameters: {'n_steps': 1633, 'gamma': 1.2020778146262363, 'lr': 0.00028109118812255683, 'n_epochs': 8}. Best is trial 2 with value: 333.0.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 580        |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 9          |
# |    time_elapsed         | 2390       |
# |    total_timesteps      | 87336      |
# | train/                  |            |
# |    approx_kl            | 0.09801621 |
# |    clip_fraction        | 0.571      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.000199   |
# |    loss                 | -0.117     |
# |    n_updates            | 104        |
# |    policy_gradient_loss | -0.0991    |
# |    value_loss           | 0.0524     |
# ----------------------------------------
# [I 2024-02-18 07:16:29,619] Trial 7 finished with value: 365.0 and parameters: {'n_steps': 2287, 'gamma': 0.734780302742167, 'lr': 0.0003629340451380195, 'n_epochs': 11}. Best is trial 7 with value: 365.0.
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 543       |
# |    ep_rew_mean          | 206       |
# | time/                   |           |
# |    fps                  | 46        |
# |    iterations           | 12        |
# |    time_elapsed         | 2243      |
# |    total_timesteps      | 103536    |
# | train/                  |           |
# |    approx_kl            | 0.1591251 |
# |    clip_fraction        | 0.608     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.46     |
# |    explained_variance   | 0.356     |
# |    learning_rate        | 0.000372  |
# |    loss                 | -0.125    |
# |    n_updates            | 99        |
# |    policy_gradient_loss | -0.092    |
# |    value_loss           | 0.035     |
# ---------------------------------------
# [I 2024-02-18 07:17:45,955] Trial 10 finished with value: 279.5 and parameters: {'n_steps': 2157, 'gamma': 0.5671624686016697, 'lr': 0.00037206379938648426, 'n_epochs': 9}. Best is trial 7 with value: 365.0.
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 560         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 5           |
# |    time_elapsed         | 1850        |
# |    total_timesteps      | 60140       |
# | train/                  |             |
# |    approx_kl            | 0.050047863 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.000158    |
# |    loss                 | -0.0882     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0868     |
# |    value_loss           | 0.0545      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 604        |
# |    ep_rew_mean          | 246        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 10         |
# |    time_elapsed         | 2541       |
# |    total_timesteps      | 97040      |
# | train/                  |            |
# |    approx_kl            | 0.11183042 |
# |    clip_fraction        | 0.599      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.000199   |
# |    loss                 | -0.121     |
# |    n_updates            | 117        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0496     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 573        |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 11         |
# |    time_elapsed         | 2616       |
# |    total_timesteps      | 106744     |
# | train/                  |            |
# |    approx_kl            | 0.13698559 |
# |    clip_fraction        | 0.633      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.267      |
# |    learning_rate        | 0.000199   |
# |    loss                 | -0.148     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 0.0512     |
# ----------------------------------------
# [I 2024-02-18 07:21:10,503] Trial 8 finished with value: 292.0 and parameters: {'n_steps': 2426, 'gamma': 0.7769360757451391, 'lr': 0.00019881786569299022, 'n_epochs': 13}. Best is trial 7 with value: 365.0.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 592        |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 6          |
# |    time_elapsed         | 2006       |
# |    total_timesteps      | 72168      |
# | train/                  |            |
# |    approx_kl            | 0.06316606 |
# |    clip_fraction        | 0.501      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.276      |
# |    learning_rate        | 0.000158   |
# |    loss                 | -0.105     |
# |    n_updates            | 75         |
# |    policy_gradient_loss | -0.0933    |
# |    value_loss           | 0.0522     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 544        |
# |    ep_rew_mean          | 196        |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 7          |
# |    time_elapsed         | 2090       |
# |    total_timesteps      | 84196      |
# | train/                  |            |
# |    approx_kl            | 0.07703366 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.25       |
# |    learning_rate        | 0.000158   |
# |    loss                 | -0.124     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.101     |
# |    value_loss           | 0.047      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 549        |
# |    ep_rew_mean          | 192        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 8          |
# |    time_elapsed         | 2175       |
# |    total_timesteps      | 96224      |
# | train/                  |            |
# |    approx_kl            | 0.08734796 |
# |    clip_fraction        | 0.565      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.239      |
# |    learning_rate        | 0.000158   |
# |    loss                 | -0.127     |
# |    n_updates            | 105        |
# |    policy_gradient_loss | -0.101     |
# |    value_loss           | 0.0475     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 555        |
# |    ep_rew_mean          | 210        |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 9          |
# |    time_elapsed         | 2258       |
# |    total_timesteps      | 108252     |
# | train/                  |            |
# |    approx_kl            | 0.09982965 |
# |    clip_fraction        | 0.579      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.316      |
# |    learning_rate        | 0.000158   |
# |    loss                 | -0.128     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0439     |
# ----------------------------------------
# [I 2024-02-18 07:26:13,218] Trial 11 finished with value: 205.0 and parameters: {'n_steps': 3007, 'gamma': 0.7598685207617438, 'lr': 0.0001577475259813369, 'n_epochs': 15}. Best is trial 7 with value: 365.0.

# %%
print("MELHORES PARÂMETROS:")
print(study_PPO.best_params)
# Out:
# MELHORES PARÂMETROS:
# {'n_steps': 2287, 'gamma': 0.734780302742167, 'lr': 0.0003629340451380195, 'n_epochs': 11}

# %%
# Defina os hiperparâmetros desejados
gamma = study_PPO.best_params["gamma"]
learning_rate = study_PPO.best_params["lr"]
n_epochs = study_PPO.best_params["n_epochs"]
n_steps = study_PPO.best_params["n_steps"]

ENV_NAME = 'ALE/SpaceInvaders-v5'
env = make_atari_env(ENV_NAME, n_envs=4, seed=12306488)
env = VecFrameStack(env, n_stack=4)

# Cria com uma rede convolucional como política e define os hiperparâmetros
model = PPO(CnnPolicy, env, gamma=gamma, learning_rate=learning_rate, n_epochs=n_epochs, tensorboard_log="log_dir", n_steps=n_steps, verbose=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# %tensorboard --logdir=log_dir
# Out:
# Reusing TensorBoard on port 6009 (pid 20732), started 1 day, 9:43:22 ago. (Use '!kill 20732' to kill it.)
#       <iframe id="tensorboard-frame-b5d2e6e184746fd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b5d2e6e184746fd");
#           const url = new URL("http://localhost");
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.learn(total_timesteps=1_200_000)
# Out:
# Logging to log_dir_1\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 512      |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    fps             | 219      |
# |    iterations      | 1        |
# |    time_elapsed    | 41       |
# |    total_timesteps | 9148     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 504        |
# |    ep_rew_mean          | 140        |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 2          |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 18296      |
# | train/                  |            |
# |    approx_kl            | 0.02612856 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | -0.0607    |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0655    |
# |    n_updates            | 11         |
# |    policy_gradient_loss | -0.035     |
# |    value_loss           | 0.0751     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 513         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 3           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 27444       |
# | train/                  |             |
# |    approx_kl            | 0.047462363 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.000363    |
# |    loss                 | -0.0992     |
# |    n_updates            | 22          |
# |    policy_gradient_loss | -0.0724     |
# |    value_loss           | 0.0604      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 521        |
# |    ep_rew_mean          | 160        |
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 4          |
# |    time_elapsed         | 207        |
# |    total_timesteps      | 36592      |
# | train/                  |            |
# |    approx_kl            | 0.06670893 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.251      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0985    |
# |    n_updates            | 33         |
# |    policy_gradient_loss | -0.0834    |
# |    value_loss           | 0.0536     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 529        |
# |    ep_rew_mean          | 161        |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 5          |
# |    time_elapsed         | 262        |
# |    total_timesteps      | 45740      |
# | train/                  |            |
# |    approx_kl            | 0.08468798 |
# |    clip_fraction        | 0.542      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.271      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.129     |
# |    n_updates            | 44         |
# |    policy_gradient_loss | -0.0899    |
# |    value_loss           | 0.0475     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 533         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 6           |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 54888       |
# | train/                  |             |
# |    approx_kl            | 0.102993146 |
# |    clip_fraction        | 0.574       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.322       |
# |    learning_rate        | 0.000363    |
# |    loss                 | -0.109      |
# |    n_updates            | 55          |
# |    policy_gradient_loss | -0.0941     |
# |    value_loss           | 0.042       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 526         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 7           |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 64036       |
# | train/                  |             |
# |    approx_kl            | 0.119848974 |
# |    clip_fraction        | 0.609       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.000363    |
# |    loss                 | -0.129      |
# |    n_updates            | 66          |
# |    policy_gradient_loss | -0.0972     |
# |    value_loss           | 0.0417      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 520        |
# |    ep_rew_mean          | 181        |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 8          |
# |    time_elapsed         | 428        |
# |    total_timesteps      | 73184      |
# | train/                  |            |
# |    approx_kl            | 0.14353198 |
# |    clip_fraction        | 0.636      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.364      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.137     |
# |    n_updates            | 77         |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0394     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 527        |
# |    ep_rew_mean          | 207        |
# | time/                   |            |
# |    fps                  | 169        |
# |    iterations           | 9          |
# |    time_elapsed         | 484        |
# |    total_timesteps      | 82332      |
# | train/                  |            |
# |    approx_kl            | 0.16010903 |
# |    clip_fraction        | 0.656      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.349      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.144     |
# |    n_updates            | 88         |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0421     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 514        |
# |    ep_rew_mean          | 198        |
# | time/                   |            |
# |    fps                  | 169        |
# |    iterations           | 10         |
# |    time_elapsed         | 540        |
# |    total_timesteps      | 91480      |
# | train/                  |            |
# |    approx_kl            | 0.18886052 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.355      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.127     |
# |    n_updates            | 99         |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0412     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 544      |
# |    ep_rew_mean          | 224      |
# | time/                   |          |
# |    fps                  | 169      |
# |    iterations           | 11       |
# |    time_elapsed         | 595      |
# |    total_timesteps      | 100628   |
# | train/                  |          |
# |    approx_kl            | 0.199943 |
# |    clip_fraction        | 0.667    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.41    |
# |    explained_variance   | 0.379    |
# |    learning_rate        | 0.000363 |
# |    loss                 | -0.129   |
# |    n_updates            | 110      |
# |    policy_gradient_loss | -0.105   |
# |    value_loss           | 0.0412   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 553        |
# |    ep_rew_mean          | 242        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 12         |
# |    time_elapsed         | 650        |
# |    total_timesteps      | 109776     |
# | train/                  |            |
# |    approx_kl            | 0.22101955 |
# |    clip_fraction        | 0.672      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.388      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.126     |
# |    n_updates            | 121        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0409     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 551       |
# |    ep_rew_mean          | 250       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 13        |
# |    time_elapsed         | 705       |
# |    total_timesteps      | 118924    |
# | train/                  |           |
# |    approx_kl            | 0.2440063 |
# |    clip_fraction        | 0.672     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.33     |
# |    explained_variance   | 0.406     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.123    |
# |    n_updates            | 132       |
# |    policy_gradient_loss | -0.104    |
# |    value_loss           | 0.0432    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 573        |
# |    ep_rew_mean          | 274        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 14         |
# |    time_elapsed         | 760        |
# |    total_timesteps      | 128072     |
# | train/                  |            |
# |    approx_kl            | 0.25312325 |
# |    clip_fraction        | 0.684      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.131     |
# |    n_updates            | 143        |
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.0385     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 581       |
# |    ep_rew_mean          | 279       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 15        |
# |    time_elapsed         | 816       |
# |    total_timesteps      | 137220    |
# | train/                  |           |
# |    approx_kl            | 0.2881379 |
# |    clip_fraction        | 0.686     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.27     |
# |    explained_variance   | 0.445     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.124    |
# |    n_updates            | 154       |
# |    policy_gradient_loss | -0.107    |
# |    value_loss           | 0.0396    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 576        |
# |    ep_rew_mean          | 287        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 16         |
# |    time_elapsed         | 871        |
# |    total_timesteps      | 146368     |
# | train/                  |            |
# |    approx_kl            | 0.31262553 |
# |    clip_fraction        | 0.684      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.42       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.114     |
# |    n_updates            | 165        |
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.041      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 572        |
# |    ep_rew_mean          | 299        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 17         |
# |    time_elapsed         | 926        |
# |    total_timesteps      | 155516     |
# | train/                  |            |
# |    approx_kl            | 0.34896973 |
# |    clip_fraction        | 0.681      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.466      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.128     |
# |    n_updates            | 176        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0409     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 550       |
# |    ep_rew_mean          | 273       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 18        |
# |    time_elapsed         | 981       |
# |    total_timesteps      | 164664    |
# | train/                  |           |
# |    approx_kl            | 0.3694524 |
# |    clip_fraction        | 0.675     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.16     |
# |    explained_variance   | 0.499     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.145    |
# |    n_updates            | 187       |
# |    policy_gradient_loss | -0.103    |
# |    value_loss           | 0.0408    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 589        |
# |    ep_rew_mean          | 296        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 19         |
# |    time_elapsed         | 1036       |
# |    total_timesteps      | 173812     |
# | train/                  |            |
# |    approx_kl            | 0.35718504 |
# |    clip_fraction        | 0.67       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.466      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.11      |
# |    n_updates            | 198        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0425     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 580        |
# |    ep_rew_mean          | 280        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 20         |
# |    time_elapsed         | 1091       |
# |    total_timesteps      | 182960     |
# | train/                  |            |
# |    approx_kl            | 0.44367272 |
# |    clip_fraction        | 0.689      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.403      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.128     |
# |    n_updates            | 209        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.0442     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 573       |
# |    ep_rew_mean          | 285       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 21        |
# |    time_elapsed         | 1146      |
# |    total_timesteps      | 192108    |
# | train/                  |           |
# |    approx_kl            | 0.4330244 |
# |    clip_fraction        | 0.683     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.449     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.146    |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -0.103    |
# |    value_loss           | 0.0416    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 583       |
# |    ep_rew_mean          | 298       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 22        |
# |    time_elapsed         | 1201      |
# |    total_timesteps      | 201256    |
# | train/                  |           |
# |    approx_kl            | 0.4228483 |
# |    clip_fraction        | 0.679     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.06     |
# |    explained_variance   | 0.449     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.141    |
# |    n_updates            | 231       |
# |    policy_gradient_loss | -0.102    |
# |    value_loss           | 0.0431    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 615        |
# |    ep_rew_mean          | 331        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 23         |
# |    time_elapsed         | 1255       |
# |    total_timesteps      | 210404     |
# | train/                  |            |
# |    approx_kl            | 0.49537456 |
# |    clip_fraction        | 0.679      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.465      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.143     |
# |    n_updates            | 242        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0426     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 616        |
# |    ep_rew_mean          | 321        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 24         |
# |    time_elapsed         | 1310       |
# |    total_timesteps      | 219552     |
# | train/                  |            |
# |    approx_kl            | 0.53035545 |
# |    clip_fraction        | 0.681      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.997     |
# |    explained_variance   | 0.448      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.126     |
# |    n_updates            | 253        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0443     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 606       |
# |    ep_rew_mean          | 311       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 25        |
# |    time_elapsed         | 1364      |
# |    total_timesteps      | 228700    |
# | train/                  |           |
# |    approx_kl            | 0.4732982 |
# |    clip_fraction        | 0.667     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.979    |
# |    explained_variance   | 0.473     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.123    |
# |    n_updates            | 264       |
# |    policy_gradient_loss | -0.0985   |
# |    value_loss           | 0.0436    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 596        |
# |    ep_rew_mean          | 314        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 26         |
# |    time_elapsed         | 1419       |
# |    total_timesteps      | 237848     |
# | train/                  |            |
# |    approx_kl            | 0.54352444 |
# |    clip_fraction        | 0.673      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.969     |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.136     |
# |    n_updates            | 275        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0441     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 614       |
# |    ep_rew_mean          | 318       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 27        |
# |    time_elapsed         | 1474      |
# |    total_timesteps      | 246996    |
# | train/                  |           |
# |    approx_kl            | 0.5401236 |
# |    clip_fraction        | 0.669     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.951    |
# |    explained_variance   | 0.488     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.134    |
# |    n_updates            | 286       |
# |    policy_gradient_loss | -0.0973   |
# |    value_loss           | 0.0429    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 336       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 28        |
# |    time_elapsed         | 1528      |
# |    total_timesteps      | 256144    |
# | train/                  |           |
# |    approx_kl            | 0.5878872 |
# |    clip_fraction        | 0.677     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.939    |
# |    explained_variance   | 0.496     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.147    |
# |    n_updates            | 297       |
# |    policy_gradient_loss | -0.101    |
# |    value_loss           | 0.0423    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 652        |
# |    ep_rew_mean          | 349        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 29         |
# |    time_elapsed         | 1583       |
# |    total_timesteps      | 265292     |
# | train/                  |            |
# |    approx_kl            | 0.58701605 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.911     |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.119     |
# |    n_updates            | 308        |
# |    policy_gradient_loss | -0.1       |
# |    value_loss           | 0.0438     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 591        |
# |    ep_rew_mean          | 313        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 30         |
# |    time_elapsed         | 1638       |
# |    total_timesteps      | 274440     |
# | train/                  |            |
# |    approx_kl            | 0.62241834 |
# |    clip_fraction        | 0.667      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.906     |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.135     |
# |    n_updates            | 319        |
# |    policy_gradient_loss | -0.0992    |
# |    value_loss           | 0.0438     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 586       |
# |    ep_rew_mean          | 310       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 31        |
# |    time_elapsed         | 1693      |
# |    total_timesteps      | 283588    |
# | train/                  |           |
# |    approx_kl            | 0.5751335 |
# |    clip_fraction        | 0.661     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.908    |
# |    explained_variance   | 0.493     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.127    |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -0.0965   |
# |    value_loss           | 0.0448    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 593       |
# |    ep_rew_mean          | 308       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 32        |
# |    time_elapsed         | 1746      |
# |    total_timesteps      | 292736    |
# | train/                  |           |
# |    approx_kl            | 0.6253311 |
# |    clip_fraction        | 0.667     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.908    |
# |    explained_variance   | 0.472     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.128    |
# |    n_updates            | 341       |
# |    policy_gradient_loss | -0.0983   |
# |    value_loss           | 0.0443    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 589       |
# |    ep_rew_mean          | 308       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 33        |
# |    time_elapsed         | 1800      |
# |    total_timesteps      | 301884    |
# | train/                  |           |
# |    approx_kl            | 0.6019587 |
# |    clip_fraction        | 0.674     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.902    |
# |    explained_variance   | 0.47      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.12     |
# |    n_updates            | 352       |
# |    policy_gradient_loss | -0.0999   |
# |    value_loss           | 0.0439    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 595       |
# |    ep_rew_mean          | 325       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 34        |
# |    time_elapsed         | 1854      |
# |    total_timesteps      | 311032    |
# | train/                  |           |
# |    approx_kl            | 0.5918242 |
# |    clip_fraction        | 0.651     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.874    |
# |    explained_variance   | 0.461     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.111    |
# |    n_updates            | 363       |
# |    policy_gradient_loss | -0.0949   |
# |    value_loss           | 0.0461    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 598       |
# |    ep_rew_mean          | 340       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 35        |
# |    time_elapsed         | 1908      |
# |    total_timesteps      | 320180    |
# | train/                  |           |
# |    approx_kl            | 0.6961816 |
# |    clip_fraction        | 0.667     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.872    |
# |    explained_variance   | 0.466     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.135    |
# |    n_updates            | 374       |
# |    policy_gradient_loss | -0.098    |
# |    value_loss           | 0.047     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 562        |
# |    ep_rew_mean          | 290        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 36         |
# |    time_elapsed         | 1963       |
# |    total_timesteps      | 329328     |
# | train/                  |            |
# |    approx_kl            | 0.64565504 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.879     |
# |    explained_variance   | 0.483      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.12      |
# |    n_updates            | 385        |
# |    policy_gradient_loss | -0.0971    |
# |    value_loss           | 0.0446     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 599        |
# |    ep_rew_mean          | 323        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 37         |
# |    time_elapsed         | 2018       |
# |    total_timesteps      | 338476     |
# | train/                  |            |
# |    approx_kl            | 0.62950194 |
# |    clip_fraction        | 0.648      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.865     |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.139     |
# |    n_updates            | 396        |
# |    policy_gradient_loss | -0.0951    |
# |    value_loss           | 0.0439     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 640        |
# |    ep_rew_mean          | 359        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 38         |
# |    time_elapsed         | 2071       |
# |    total_timesteps      | 347624     |
# | train/                  |            |
# |    approx_kl            | 0.71313024 |
# |    clip_fraction        | 0.652      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.835     |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.121     |
# |    n_updates            | 407        |
# |    policy_gradient_loss | -0.0969    |
# |    value_loss           | 0.0468     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 580        |
# |    ep_rew_mean          | 324        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 39         |
# |    time_elapsed         | 2125       |
# |    total_timesteps      | 356772     |
# | train/                  |            |
# |    approx_kl            | 0.69197255 |
# |    clip_fraction        | 0.64       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.826     |
# |    explained_variance   | 0.526      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.106     |
# |    n_updates            | 418        |
# |    policy_gradient_loss | -0.0941    |
# |    value_loss           | 0.0456     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 584       |
# |    ep_rew_mean          | 320       |
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 40        |
# |    time_elapsed         | 2178      |
# |    total_timesteps      | 365920    |
# | train/                  |           |
# |    approx_kl            | 0.6890819 |
# |    clip_fraction        | 0.632     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.813    |
# |    explained_variance   | 0.572     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0946   |
# |    n_updates            | 429       |
# |    policy_gradient_loss | -0.0914   |
# |    value_loss           | 0.0432    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 632       |
# |    ep_rew_mean          | 355       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 41        |
# |    time_elapsed         | 2231      |
# |    total_timesteps      | 375068    |
# | train/                  |           |
# |    approx_kl            | 0.7094557 |
# |    clip_fraction        | 0.638     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.796    |
# |    explained_variance   | 0.488     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.123    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0926   |
# |    value_loss           | 0.0462    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 638       |
# |    ep_rew_mean          | 369       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 42        |
# |    time_elapsed         | 2285      |
# |    total_timesteps      | 384216    |
# | train/                  |           |
# |    approx_kl            | 0.8920348 |
# |    clip_fraction        | 0.647     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.799    |
# |    explained_variance   | 0.49      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.119    |
# |    n_updates            | 451       |
# |    policy_gradient_loss | -0.0954   |
# |    value_loss           | 0.0469    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 609        |
# |    ep_rew_mean          | 340        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 43         |
# |    time_elapsed         | 2338       |
# |    total_timesteps      | 393364     |
# | train/                  |            |
# |    approx_kl            | 0.70463026 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.801     |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.136     |
# |    n_updates            | 462        |
# |    policy_gradient_loss | -0.0954    |
# |    value_loss           | 0.0457     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 633       |
# |    ep_rew_mean          | 356       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 44        |
# |    time_elapsed         | 2391      |
# |    total_timesteps      | 402512    |
# | train/                  |           |
# |    approx_kl            | 0.7359348 |
# |    clip_fraction        | 0.642     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.793    |
# |    explained_variance   | 0.498     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.112    |
# |    n_updates            | 473       |
# |    policy_gradient_loss | -0.0929   |
# |    value_loss           | 0.0477    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 606       |
# |    ep_rew_mean          | 330       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 45        |
# |    time_elapsed         | 2445      |
# |    total_timesteps      | 411660    |
# | train/                  |           |
# |    approx_kl            | 0.7466225 |
# |    clip_fraction        | 0.636     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.777    |
# |    explained_variance   | 0.503     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.117    |
# |    n_updates            | 484       |
# |    policy_gradient_loss | -0.0931   |
# |    value_loss           | 0.0479    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 583        |
# |    ep_rew_mean          | 316        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 46         |
# |    time_elapsed         | 2498       |
# |    total_timesteps      | 420808     |
# | train/                  |            |
# |    approx_kl            | 0.74699074 |
# |    clip_fraction        | 0.641      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.782     |
# |    explained_variance   | 0.524      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.109     |
# |    n_updates            | 495        |
# |    policy_gradient_loss | -0.093     |
# |    value_loss           | 0.0462     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 584       |
# |    ep_rew_mean          | 318       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 47        |
# |    time_elapsed         | 2552      |
# |    total_timesteps      | 429956    |
# | train/                  |           |
# |    approx_kl            | 0.7484313 |
# |    clip_fraction        | 0.627     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.76     |
# |    explained_variance   | 0.524     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.122    |
# |    n_updates            | 506       |
# |    policy_gradient_loss | -0.0902   |
# |    value_loss           | 0.0461    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 622        |
# |    ep_rew_mean          | 356        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 48         |
# |    time_elapsed         | 2605       |
# |    total_timesteps      | 439104     |
# | train/                  |            |
# |    approx_kl            | 0.73593605 |
# |    clip_fraction        | 0.627      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.778     |
# |    explained_variance   | 0.55       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.107     |
# |    n_updates            | 517        |
# |    policy_gradient_loss | -0.0914    |
# |    value_loss           | 0.0463     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 612       |
# |    ep_rew_mean          | 355       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 49        |
# |    time_elapsed         | 2658      |
# |    total_timesteps      | 448252    |
# | train/                  |           |
# |    approx_kl            | 0.8142905 |
# |    clip_fraction        | 0.632     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.757    |
# |    explained_variance   | 0.528     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.102    |
# |    n_updates            | 528       |
# |    policy_gradient_loss | -0.0934   |
# |    value_loss           | 0.0477    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 574       |
# |    ep_rew_mean          | 333       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 50        |
# |    time_elapsed         | 2712      |
# |    total_timesteps      | 457400    |
# | train/                  |           |
# |    approx_kl            | 0.8068176 |
# |    clip_fraction        | 0.616     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.747    |
# |    explained_variance   | 0.53      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.115    |
# |    n_updates            | 539       |
# |    policy_gradient_loss | -0.0895   |
# |    value_loss           | 0.0459    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 610        |
# |    ep_rew_mean          | 344        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 51         |
# |    time_elapsed         | 2765       |
# |    total_timesteps      | 466548     |
# | train/                  |            |
# |    approx_kl            | 0.80152696 |
# |    clip_fraction        | 0.624      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.75      |
# |    explained_variance   | 0.521      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.114     |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0899    |
# |    value_loss           | 0.0479     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 620       |
# |    ep_rew_mean          | 334       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 52        |
# |    time_elapsed         | 2818      |
# |    total_timesteps      | 475696    |
# | train/                  |           |
# |    approx_kl            | 0.7703291 |
# |    clip_fraction        | 0.646     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.784    |
# |    explained_variance   | 0.504     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.122    |
# |    n_updates            | 561       |
# |    policy_gradient_loss | -0.0949   |
# |    value_loss           | 0.0478    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 570       |
# |    ep_rew_mean          | 293       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 53        |
# |    time_elapsed         | 2872      |
# |    total_timesteps      | 484844    |
# | train/                  |           |
# |    approx_kl            | 0.8433994 |
# |    clip_fraction        | 0.654     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.812    |
# |    explained_variance   | 0.453     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.112    |
# |    n_updates            | 572       |
# |    policy_gradient_loss | -0.0961   |
# |    value_loss           | 0.0501    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 583        |
# |    ep_rew_mean          | 315        |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 54         |
# |    time_elapsed         | 2926       |
# |    total_timesteps      | 493992     |
# | train/                  |            |
# |    approx_kl            | 0.75135386 |
# |    clip_fraction        | 0.643      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.802     |
# |    explained_variance   | 0.458      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.121     |
# |    n_updates            | 583        |
# |    policy_gradient_loss | -0.0927    |
# |    value_loss           | 0.0509     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 630      |
# |    ep_rew_mean          | 347      |
# | time/                   |          |
# |    fps                  | 168      |
# |    iterations           | 55       |
# |    time_elapsed         | 2979     |
# |    total_timesteps      | 503140   |
# | train/                  |          |
# |    approx_kl            | 0.78466  |
# |    clip_fraction        | 0.628    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.764   |
# |    explained_variance   | 0.507    |
# |    learning_rate        | 0.000363 |
# |    loss                 | -0.088   |
# |    n_updates            | 594      |
# |    policy_gradient_loss | -0.0917  |
# |    value_loss           | 0.0491   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 583       |
# |    ep_rew_mean          | 319       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 56        |
# |    time_elapsed         | 3033      |
# |    total_timesteps      | 512288    |
# | train/                  |           |
# |    approx_kl            | 0.7825899 |
# |    clip_fraction        | 0.633     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.78     |
# |    explained_variance   | 0.503     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.103    |
# |    n_updates            | 605       |
# |    policy_gradient_loss | -0.0946   |
# |    value_loss           | 0.0497    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 596       |
# |    ep_rew_mean          | 339       |
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 57        |
# |    time_elapsed         | 3086      |
# |    total_timesteps      | 521436    |
# | train/                  |           |
# |    approx_kl            | 0.7196605 |
# |    clip_fraction        | 0.614     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.764    |
# |    explained_variance   | 0.576     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.118    |
# |    n_updates            | 616       |
# |    policy_gradient_loss | -0.0902   |
# |    value_loss           | 0.0491    |
# ...
# |    ep_len_mean          | 651       |
# |    ep_rew_mean          | 369       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 114       |
# |    time_elapsed         | 6125      |
# |    total_timesteps      | 1042872   |
# | train/                  |           |
# |    approx_kl            | 0.6478661 |
# |    clip_fraction        | 0.545     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.681    |
# |    explained_variance   | 0.631     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.103    |
# |    n_updates            | 1243      |
# |    policy_gradient_loss | -0.0788   |
# |    value_loss           | 0.0623    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 674        |
# |    ep_rew_mean          | 386        |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 115        |
# |    time_elapsed         | 6178       |
# |    total_timesteps      | 1052020    |
# | train/                  |            |
# |    approx_kl            | 0.64985615 |
# |    clip_fraction        | 0.562      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.705     |
# |    explained_variance   | 0.587      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0909    |
# |    n_updates            | 1254       |
# |    policy_gradient_loss | -0.0837    |
# |    value_loss           | 0.0685     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 616       |
# |    ep_rew_mean          | 355       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 116       |
# |    time_elapsed         | 6231      |
# |    total_timesteps      | 1061168   |
# | train/                  |           |
# |    approx_kl            | 0.7392482 |
# |    clip_fraction        | 0.555     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.708    |
# |    explained_variance   | 0.64      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.113    |
# |    n_updates            | 1265      |
# |    policy_gradient_loss | -0.0802   |
# |    value_loss           | 0.0646    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 610       |
# |    ep_rew_mean          | 342       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 117       |
# |    time_elapsed         | 6285      |
# |    total_timesteps      | 1070316   |
# | train/                  |           |
# |    approx_kl            | 0.5919627 |
# |    clip_fraction        | 0.552     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.713    |
# |    explained_variance   | 0.621     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0847   |
# |    n_updates            | 1276      |
# |    policy_gradient_loss | -0.0801   |
# |    value_loss           | 0.0662    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 621       |
# |    ep_rew_mean          | 343       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 118       |
# |    time_elapsed         | 6338      |
# |    total_timesteps      | 1079464   |
# | train/                  |           |
# |    approx_kl            | 0.6436057 |
# |    clip_fraction        | 0.565     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.741    |
# |    explained_variance   | 0.592     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0906   |
# |    n_updates            | 1287      |
# |    policy_gradient_loss | -0.0836   |
# |    value_loss           | 0.0685    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 615       |
# |    ep_rew_mean          | 352       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 119       |
# |    time_elapsed         | 6391      |
# |    total_timesteps      | 1088612   |
# | train/                  |           |
# |    approx_kl            | 0.6291947 |
# |    clip_fraction        | 0.568     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.736    |
# |    explained_variance   | 0.574     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0783   |
# |    n_updates            | 1298      |
# |    policy_gradient_loss | -0.0838   |
# |    value_loss           | 0.0699    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 607        |
# |    ep_rew_mean          | 339        |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 120        |
# |    time_elapsed         | 6444       |
# |    total_timesteps      | 1097760    |
# | train/                  |            |
# |    approx_kl            | 0.60023284 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.735     |
# |    explained_variance   | 0.604      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.075     |
# |    n_updates            | 1309       |
# |    policy_gradient_loss | -0.0834    |
# |    value_loss           | 0.0654     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 624        |
# |    ep_rew_mean          | 345        |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 121        |
# |    time_elapsed         | 6497       |
# |    total_timesteps      | 1106908    |
# | train/                  |            |
# |    approx_kl            | 0.59778666 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.723     |
# |    explained_variance   | 0.596      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0879    |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | -0.0845    |
# |    value_loss           | 0.0698     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 610        |
# |    ep_rew_mean          | 337        |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 122        |
# |    time_elapsed         | 6550       |
# |    total_timesteps      | 1116056    |
# | train/                  |            |
# |    approx_kl            | 0.59509766 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | 0.624      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.108     |
# |    n_updates            | 1331       |
# |    policy_gradient_loss | -0.0825    |
# |    value_loss           | 0.0676     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 648       |
# |    ep_rew_mean          | 374       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 123       |
# |    time_elapsed         | 6603      |
# |    total_timesteps      | 1125204   |
# | train/                  |           |
# |    approx_kl            | 0.6343928 |
# |    clip_fraction        | 0.55      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.699    |
# |    explained_variance   | 0.618     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.1      |
# |    n_updates            | 1342      |
# |    policy_gradient_loss | -0.0808   |
# |    value_loss           | 0.0659    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 653       |
# |    ep_rew_mean          | 368       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 124       |
# |    time_elapsed         | 6656      |
# |    total_timesteps      | 1134352   |
# | train/                  |           |
# |    approx_kl            | 0.5869334 |
# |    clip_fraction        | 0.544     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.713    |
# |    explained_variance   | 0.629     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0976   |
# |    n_updates            | 1353      |
# |    policy_gradient_loss | -0.0807   |
# |    value_loss           | 0.0679    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 640       |
# |    ep_rew_mean          | 367       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 125       |
# |    time_elapsed         | 6709      |
# |    total_timesteps      | 1143500   |
# | train/                  |           |
# |    approx_kl            | 0.5518447 |
# |    clip_fraction        | 0.542     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.713    |
# |    explained_variance   | 0.633     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.107    |
# |    n_updates            | 1364      |
# |    policy_gradient_loss | -0.0811   |
# |    value_loss           | 0.066     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 640        |
# |    ep_rew_mean          | 376        |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 126        |
# |    time_elapsed         | 6762       |
# |    total_timesteps      | 1152648    |
# | train/                  |            |
# |    approx_kl            | 0.62031865 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.708     |
# |    explained_variance   | 0.637      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0916    |
# |    n_updates            | 1375       |
# |    policy_gradient_loss | -0.082     |
# |    value_loss           | 0.066      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 650       |
# |    ep_rew_mean          | 371       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 127       |
# |    time_elapsed         | 6815      |
# |    total_timesteps      | 1161796   |
# | train/                  |           |
# |    approx_kl            | 0.5710169 |
# |    clip_fraction        | 0.558     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.704    |
# |    explained_variance   | 0.597     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0936   |
# |    n_updates            | 1386      |
# |    policy_gradient_loss | -0.0813   |
# |    value_loss           | 0.0704    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 671       |
# |    ep_rew_mean          | 385       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 128       |
# |    time_elapsed         | 6867      |
# |    total_timesteps      | 1170944   |
# | train/                  |           |
# |    approx_kl            | 0.5654424 |
# |    clip_fraction        | 0.551     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.717    |
# |    explained_variance   | 0.6       |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0917   |
# |    n_updates            | 1397      |
# |    policy_gradient_loss | -0.0829   |
# |    value_loss           | 0.0717    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 672       |
# |    ep_rew_mean          | 398       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 129       |
# |    time_elapsed         | 6920      |
# |    total_timesteps      | 1180092   |
# | train/                  |           |
# |    approx_kl            | 0.6036682 |
# |    clip_fraction        | 0.55      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.707    |
# |    explained_variance   | 0.622     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.111    |
# |    n_updates            | 1408      |
# |    policy_gradient_loss | -0.0808   |
# |    value_loss           | 0.0679    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 676       |
# |    ep_rew_mean          | 400       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 130       |
# |    time_elapsed         | 6973      |
# |    total_timesteps      | 1189240   |
# | train/                  |           |
# |    approx_kl            | 0.6150499 |
# |    clip_fraction        | 0.55      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.7      |
# |    explained_variance   | 0.617     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0948   |
# |    n_updates            | 1419      |
# |    policy_gradient_loss | -0.0815   |
# |    value_loss           | 0.0699    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 648       |
# |    ep_rew_mean          | 376       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 131       |
# |    time_elapsed         | 7026      |
# |    total_timesteps      | 1198388   |
# | train/                  |           |
# |    approx_kl            | 0.5938062 |
# |    clip_fraction        | 0.54      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.683    |
# |    explained_variance   | 0.616     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.108    |
# |    n_updates            | 1430      |
# |    policy_gradient_loss | -0.0798   |
# |    value_loss           | 0.0718    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 648       |
# |    ep_rew_mean          | 374       |
# | time/                   |           |
# |    fps                  | 170       |
# |    iterations           | 132       |
# |    time_elapsed         | 7078      |
# |    total_timesteps      | 1207536   |
# | train/                  |           |
# |    approx_kl            | 0.5869529 |
# |    clip_fraction        | 0.53      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.679    |
# |    explained_variance   | 0.643     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0849   |
# |    n_updates            | 1441      |
# |    policy_gradient_loss | -0.0777   |
# |    value_loss           | 0.068     |
# ---------------------------------------

# %%
# Defina os hiperparâmetros desejados
gamma = study_PPO.best_params["gamma"]
learning_rate = study_PPO.best_params["lr"]
n_epochs = study_PPO.best_params["n_epochs"]
n_steps = study_PPO.best_params["n_steps"]

ENV_NAME = 'ALE/SpaceInvaders-v5'
env2 = make_atari_env(ENV_NAME, n_envs=4, seed=12306488)
env2 = VecFrameStack(env, n_stack=4)

# Cria com uma rede convolucional como política e define os hiperparâmetros
model2 = PPO(CnnPolicy, env2, gamma=gamma, learning_rate=learning_rate, n_epochs=n_epochs, tensorboard_log="log_dir", n_steps=n_steps, verbose=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# c:\Users\Pichau\anaconda3\envs\rl23\Lib\site-packages\stable_baselines3\ppo\ppo.py:148: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 9148`, after every 142 untruncated mini-batches, there will be a truncated mini-batch of size 60
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2287 and n_envs=4)
#   warnings.warn(

# %%
model2.learn(total_timesteps=5_000_000)
# Out:
# Logging to log_dir\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 512      |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    fps             | 224      |
# |    iterations      | 1        |
# |    time_elapsed    | 40       |
# |    total_timesteps | 9148     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 545         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 2           |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 18296       |
# | train/                  |             |
# |    approx_kl            | 0.025526892 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.0223     |
# |    learning_rate        | 0.000363    |
# |    loss                 | -0.0475     |
# |    n_updates            | 11          |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.0803      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 518         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 3           |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 27444       |
# | train/                  |             |
# |    approx_kl            | 0.049282815 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.000363    |
# |    loss                 | -0.0948     |
# |    n_updates            | 22          |
# |    policy_gradient_loss | -0.0683     |
# |    value_loss           | 0.062       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 532        |
# |    ep_rew_mean          | 153        |
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 4          |
# |    time_elapsed         | 259        |
# |    total_timesteps      | 36592      |
# | train/                  |            |
# |    approx_kl            | 0.06665002 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0953    |
# |    n_updates            | 33         |
# |    policy_gradient_loss | -0.0797    |
# |    value_loss           | 0.054      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 524        |
# |    ep_rew_mean          | 155        |
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 5          |
# |    time_elapsed         | 330        |
# |    total_timesteps      | 45740      |
# | train/                  |            |
# |    approx_kl            | 0.08937905 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.299      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.128     |
# |    n_updates            | 44         |
# |    policy_gradient_loss | -0.0876    |
# |    value_loss           | 0.0457     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 551        |
# |    ep_rew_mean          | 176        |
# | time/                   |            |
# |    fps                  | 135        |
# |    iterations           | 6          |
# |    time_elapsed         | 405        |
# |    total_timesteps      | 54888      |
# | train/                  |            |
# |    approx_kl            | 0.11059701 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.132     |
# |    n_updates            | 55         |
# |    policy_gradient_loss | -0.0918    |
# |    value_loss           | 0.0402     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 536        |
# |    ep_rew_mean          | 180        |
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 7          |
# |    time_elapsed         | 479        |
# |    total_timesteps      | 64036      |
# | train/                  |            |
# |    approx_kl            | 0.14364843 |
# |    clip_fraction        | 0.638      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.314      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.126     |
# |    n_updates            | 66         |
# |    policy_gradient_loss | -0.0995    |
# |    value_loss           | 0.0395     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 538        |
# |    ep_rew_mean          | 184        |
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 8          |
# |    time_elapsed         | 549        |
# |    total_timesteps      | 73184      |
# | train/                  |            |
# |    approx_kl            | 0.14837019 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.356      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.119     |
# |    n_updates            | 77         |
# |    policy_gradient_loss | -0.0967    |
# |    value_loss           | 0.0394     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 518       |
# |    ep_rew_mean          | 180       |
# | time/                   |           |
# |    fps                  | 132       |
# |    iterations           | 9         |
# |    time_elapsed         | 620       |
# |    total_timesteps      | 82332     |
# | train/                  |           |
# |    approx_kl            | 0.1873102 |
# |    clip_fraction        | 0.674     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.52     |
# |    explained_variance   | 0.355     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.117    |
# |    n_updates            | 88        |
# |    policy_gradient_loss | -0.101    |
# |    value_loss           | 0.0405    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 555        |
# |    ep_rew_mean          | 196        |
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 10         |
# |    time_elapsed         | 690        |
# |    total_timesteps      | 91480      |
# | train/                  |            |
# |    approx_kl            | 0.20131977 |
# |    clip_fraction        | 0.677      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.34       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.137     |
# |    n_updates            | 99         |
# |    policy_gradient_loss | -0.101     |
# |    value_loss           | 0.0388     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 575        |
# |    ep_rew_mean          | 208        |
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 11         |
# |    time_elapsed         | 760        |
# |    total_timesteps      | 100628     |
# | train/                  |            |
# |    approx_kl            | 0.23852292 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.366      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.134     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.0371     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 532        |
# |    ep_rew_mean          | 209        |
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 12         |
# |    time_elapsed         | 830        |
# |    total_timesteps      | 109776     |
# | train/                  |            |
# |    approx_kl            | 0.28319022 |
# |    clip_fraction        | 0.713      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.375      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.131     |
# |    n_updates            | 121        |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 0.0383     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 512        |
# |    ep_rew_mean          | 199        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 13         |
# |    time_elapsed         | 901        |
# |    total_timesteps      | 118924     |
# | train/                  |            |
# |    approx_kl            | 0.27904484 |
# |    clip_fraction        | 0.701      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.413      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.135     |
# |    n_updates            | 132        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.0407     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 550        |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 14         |
# |    time_elapsed         | 971        |
# |    total_timesteps      | 128072     |
# | train/                  |            |
# |    approx_kl            | 0.30605054 |
# |    clip_fraction        | 0.71       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.405      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.14      |
# |    n_updates            | 143        |
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.0407     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 570        |
# |    ep_rew_mean          | 256        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 15         |
# |    time_elapsed         | 1041       |
# |    total_timesteps      | 137220     |
# | train/                  |            |
# |    approx_kl            | 0.34287405 |
# |    clip_fraction        | 0.719      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.346      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.142     |
# |    n_updates            | 154        |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 0.0433     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 545       |
# |    ep_rew_mean          | 245       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 16        |
# |    time_elapsed         | 1112      |
# |    total_timesteps      | 146368    |
# | train/                  |           |
# |    approx_kl            | 0.3595049 |
# |    clip_fraction        | 0.71      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.25     |
# |    explained_variance   | 0.327     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.119    |
# |    n_updates            | 165       |
# |    policy_gradient_loss | -0.105    |
# |    value_loss           | 0.0471    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 518        |
# |    ep_rew_mean          | 228        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 17         |
# |    time_elapsed         | 1183       |
# |    total_timesteps      | 155516     |
# | train/                  |            |
# |    approx_kl            | 0.39397296 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.399      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.135     |
# |    n_updates            | 176        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.043      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 586        |
# |    ep_rew_mean          | 274        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 18         |
# |    time_elapsed         | 1253       |
# |    total_timesteps      | 164664     |
# | train/                  |            |
# |    approx_kl            | 0.40143013 |
# |    clip_fraction        | 0.707      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.435      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.133     |
# |    n_updates            | 187        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0419     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 597        |
# |    ep_rew_mean          | 280        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 19         |
# |    time_elapsed         | 1322       |
# |    total_timesteps      | 173812     |
# | train/                  |            |
# |    approx_kl            | 0.42222467 |
# |    clip_fraction        | 0.704      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.418      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.137     |
# |    n_updates            | 198        |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 0.044      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 588        |
# |    ep_rew_mean          | 277        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 20         |
# |    time_elapsed         | 1392       |
# |    total_timesteps      | 182960     |
# | train/                  |            |
# |    approx_kl            | 0.41568166 |
# |    clip_fraction        | 0.708      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.426      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.131     |
# |    n_updates            | 209        |
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.0445     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 578        |
# |    ep_rew_mean          | 272        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 21         |
# |    time_elapsed         | 1464       |
# |    total_timesteps      | 192108     |
# | train/                  |            |
# |    approx_kl            | 0.45025527 |
# |    clip_fraction        | 0.702      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.416      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.13      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.042      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 579       |
# |    ep_rew_mean          | 281       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 22        |
# |    time_elapsed         | 1534      |
# |    total_timesteps      | 201256    |
# | train/                  |           |
# |    approx_kl            | 0.4901105 |
# |    clip_fraction        | 0.703     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.43      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.14     |
# |    n_updates            | 231       |
# |    policy_gradient_loss | -0.103    |
# |    value_loss           | 0.0461    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 585        |
# |    ep_rew_mean          | 279        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 23         |
# |    time_elapsed         | 1604       |
# |    total_timesteps      | 210404     |
# | train/                  |            |
# |    approx_kl            | 0.48398387 |
# |    clip_fraction        | 0.708      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.419      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.125     |
# |    n_updates            | 242        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0473     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 582       |
# |    ep_rew_mean          | 275       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 24        |
# |    time_elapsed         | 1674      |
# |    total_timesteps      | 219552    |
# | train/                  |           |
# |    approx_kl            | 0.5160282 |
# |    clip_fraction        | 0.711     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.08     |
# |    explained_variance   | 0.418     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.138    |
# |    n_updates            | 253       |
# |    policy_gradient_loss | -0.104    |
# |    value_loss           | 0.0459    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 598        |
# |    ep_rew_mean          | 283        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 25         |
# |    time_elapsed         | 1744       |
# |    total_timesteps      | 228700     |
# | train/                  |            |
# |    approx_kl            | 0.51955026 |
# |    clip_fraction        | 0.71       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.42       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.131     |
# |    n_updates            | 264        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0474     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 593       |
# |    ep_rew_mean          | 282       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 26        |
# |    time_elapsed         | 1814      |
# |    total_timesteps      | 237848    |
# | train/                  |           |
# |    approx_kl            | 0.5632974 |
# |    clip_fraction        | 0.707     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.04     |
# |    explained_variance   | 0.359     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.109    |
# |    n_updates            | 275       |
# |    policy_gradient_loss | -0.104    |
# |    value_loss           | 0.051     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 609        |
# |    ep_rew_mean          | 304        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 27         |
# |    time_elapsed         | 1884       |
# |    total_timesteps      | 246996     |
# | train/                  |            |
# |    approx_kl            | 0.57969576 |
# |    clip_fraction        | 0.701      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.43       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.138     |
# |    n_updates            | 286        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0475     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 610       |
# |    ep_rew_mean          | 307       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 28        |
# |    time_elapsed         | 1954      |
# |    total_timesteps      | 256144    |
# | train/                  |           |
# |    approx_kl            | 0.5876039 |
# |    clip_fraction        | 0.699     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | 0.415     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.114    |
# |    n_updates            | 297       |
# |    policy_gradient_loss | -0.102    |
# |    value_loss           | 0.0503    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 620        |
# |    ep_rew_mean          | 336        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 29         |
# |    time_elapsed         | 2023       |
# |    total_timesteps      | 265292     |
# | train/                  |            |
# |    approx_kl            | 0.59793764 |
# |    clip_fraction        | 0.704      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.423      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.109     |
# |    n_updates            | 308        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0479     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 581        |
# |    ep_rew_mean          | 304        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 30         |
# |    time_elapsed         | 2093       |
# |    total_timesteps      | 274440     |
# | train/                  |            |
# |    approx_kl            | 0.61147165 |
# |    clip_fraction        | 0.707      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.439      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.117     |
# |    n_updates            | 319        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.0481     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 579       |
# |    ep_rew_mean          | 285       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 31        |
# |    time_elapsed         | 2163      |
# |    total_timesteps      | 283588    |
# | train/                  |           |
# |    approx_kl            | 0.5856354 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.991    |
# |    explained_variance   | 0.465     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.108    |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -0.102    |
# |    value_loss           | 0.0491    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 587        |
# |    ep_rew_mean          | 278        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 32         |
# |    time_elapsed         | 2233       |
# |    total_timesteps      | 292736     |
# | train/                  |            |
# |    approx_kl            | 0.59050626 |
# |    clip_fraction        | 0.705      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.463      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.11      |
# |    n_updates            | 341        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.0465     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 613        |
# |    ep_rew_mean          | 297        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 33         |
# |    time_elapsed         | 2303       |
# |    total_timesteps      | 301884     |
# | train/                  |            |
# |    approx_kl            | 0.61856806 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.442      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.128     |
# |    n_updates            | 352        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0481     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 637        |
# |    ep_rew_mean          | 324        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 34         |
# |    time_elapsed         | 2373       |
# |    total_timesteps      | 311032     |
# | train/                  |            |
# |    approx_kl            | 0.61794055 |
# |    clip_fraction        | 0.701      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.443      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.127     |
# |    n_updates            | 363        |
# |    policy_gradient_loss | -0.103     |
# |    value_loss           | 0.0505     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 631        |
# |    ep_rew_mean          | 320        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 35         |
# |    time_elapsed         | 2443       |
# |    total_timesteps      | 320180     |
# | train/                  |            |
# |    approx_kl            | 0.64668375 |
# |    clip_fraction        | 0.707      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.449      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.104     |
# |    n_updates            | 374        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.051      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 617        |
# |    ep_rew_mean          | 313        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 36         |
# |    time_elapsed         | 2513       |
# |    total_timesteps      | 329328     |
# | train/                  |            |
# |    approx_kl            | 0.62762487 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.439      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.114     |
# |    n_updates            | 385        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0539     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 614       |
# |    ep_rew_mean          | 309       |
# | time/                   |           |
# |    fps                  | 131       |
# |    iterations           | 37        |
# |    time_elapsed         | 2582      |
# |    total_timesteps      | 338476    |
# | train/                  |           |
# |    approx_kl            | 0.6882308 |
# |    clip_fraction        | 0.708     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.997    |
# |    explained_variance   | 0.395     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.122    |
# |    n_updates            | 396       |
# |    policy_gradient_loss | -0.104    |
# |    value_loss           | 0.0526    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 606      |
# |    ep_rew_mean          | 321      |
# | time/                   |          |
# |    fps                  | 131      |
# |    iterations           | 38       |
# |    time_elapsed         | 2652     |
# |    total_timesteps      | 347624   |
# | train/                  |          |
# |    approx_kl            | 0.627777 |
# |    clip_fraction        | 0.699    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.964   |
# |    explained_variance   | 0.45     |
# |    learning_rate        | 0.000363 |
# |    loss                 | -0.104   |
# |    n_updates            | 407      |
# |    policy_gradient_loss | -0.1     |
# |    value_loss           | 0.0513   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 590        |
# |    ep_rew_mean          | 308        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 39         |
# |    time_elapsed         | 2723       |
# |    total_timesteps      | 356772     |
# | train/                  |            |
# |    approx_kl            | 0.64737713 |
# |    clip_fraction        | 0.702      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.97      |
# |    explained_variance   | 0.45       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.127     |
# |    n_updates            | 418        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 0.0495     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 615       |
# |    ep_rew_mean          | 321       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 40        |
# |    time_elapsed         | 2793      |
# |    total_timesteps      | 365920    |
# | train/                  |           |
# |    approx_kl            | 0.6429119 |
# |    clip_fraction        | 0.688     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.958    |
# |    explained_variance   | 0.47      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0986   |
# |    n_updates            | 429       |
# |    policy_gradient_loss | -0.1      |
# |    value_loss           | 0.0515    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 613       |
# |    ep_rew_mean          | 320       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 41        |
# |    time_elapsed         | 2863      |
# |    total_timesteps      | 375068    |
# | train/                  |           |
# |    approx_kl            | 0.6974724 |
# |    clip_fraction        | 0.694     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.941    |
# |    explained_variance   | 0.445     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.12     |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.101    |
# |    value_loss           | 0.0502    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 560        |
# |    ep_rew_mean          | 289        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 42         |
# |    time_elapsed         | 2933       |
# |    total_timesteps      | 384216     |
# | train/                  |            |
# |    approx_kl            | 0.72602856 |
# |    clip_fraction        | 0.692      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.911     |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.117     |
# |    n_updates            | 451        |
# |    policy_gradient_loss | -0.0997    |
# |    value_loss           | 0.0501     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 604       |
# |    ep_rew_mean          | 317       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 43        |
# |    time_elapsed         | 3004      |
# |    total_timesteps      | 393364    |
# | train/                  |           |
# |    approx_kl            | 0.7105776 |
# |    clip_fraction        | 0.679     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.905    |
# |    explained_variance   | 0.513     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.112    |
# |    n_updates            | 462       |
# |    policy_gradient_loss | -0.0988   |
# |    value_loss           | 0.0488    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 635       |
# |    ep_rew_mean          | 340       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 44        |
# |    time_elapsed         | 3075      |
# |    total_timesteps      | 402512    |
# | train/                  |           |
# |    approx_kl            | 0.7722546 |
# |    clip_fraction        | 0.687     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.903    |
# |    explained_variance   | 0.475     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.119    |
# |    n_updates            | 473       |
# |    policy_gradient_loss | -0.0991   |
# |    value_loss           | 0.0516    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 576       |
# |    ep_rew_mean          | 297       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 45        |
# |    time_elapsed         | 3146      |
# |    total_timesteps      | 411660    |
# | train/                  |           |
# |    approx_kl            | 0.7582468 |
# |    clip_fraction        | 0.685     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.896    |
# |    explained_variance   | 0.444     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.105    |
# |    n_updates            | 484       |
# |    policy_gradient_loss | -0.0986   |
# |    value_loss           | 0.0549    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 611       |
# |    ep_rew_mean          | 313       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 46        |
# |    time_elapsed         | 3217      |
# |    total_timesteps      | 420808    |
# | train/                  |           |
# |    approx_kl            | 0.6782214 |
# |    clip_fraction        | 0.687     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.912    |
# |    explained_variance   | 0.45      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.123    |
# |    n_updates            | 495       |
# |    policy_gradient_loss | -0.0992   |
# |    value_loss           | 0.0545    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 601       |
# |    ep_rew_mean          | 312       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 47        |
# |    time_elapsed         | 3288      |
# |    total_timesteps      | 429956    |
# | train/                  |           |
# |    approx_kl            | 0.7311337 |
# |    clip_fraction        | 0.692     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.894    |
# |    explained_variance   | 0.446     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.124    |
# |    n_updates            | 506       |
# |    policy_gradient_loss | -0.0996   |
# |    value_loss           | 0.0545    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 590        |
# |    ep_rew_mean          | 303        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 48         |
# |    time_elapsed         | 3358       |
# |    total_timesteps      | 439104     |
# | train/                  |            |
# |    approx_kl            | 0.70219696 |
# |    clip_fraction        | 0.679      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.887     |
# |    explained_variance   | 0.459      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.116     |
# |    n_updates            | 517        |
# |    policy_gradient_loss | -0.097     |
# |    value_loss           | 0.0522     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 590       |
# |    ep_rew_mean          | 310       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 49        |
# |    time_elapsed         | 3429      |
# |    total_timesteps      | 448252    |
# | train/                  |           |
# |    approx_kl            | 0.7683586 |
# |    clip_fraction        | 0.686     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.894    |
# |    explained_variance   | 0.513     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.12     |
# |    n_updates            | 528       |
# |    policy_gradient_loss | -0.0979   |
# |    value_loss           | 0.0507    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 596       |
# |    ep_rew_mean          | 309       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 50        |
# |    time_elapsed         | 3499      |
# |    total_timesteps      | 457400    |
# | train/                  |           |
# |    approx_kl            | 0.7131443 |
# |    clip_fraction        | 0.685     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.891    |
# |    explained_variance   | 0.47      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.13     |
# |    n_updates            | 539       |
# |    policy_gradient_loss | -0.0984   |
# |    value_loss           | 0.0536    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 600       |
# |    ep_rew_mean          | 305       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 51        |
# |    time_elapsed         | 3571      |
# |    total_timesteps      | 466548    |
# | train/                  |           |
# |    approx_kl            | 0.7335699 |
# |    clip_fraction        | 0.688     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.891    |
# |    explained_variance   | 0.41      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.129    |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0989   |
# |    value_loss           | 0.0566    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 620       |
# |    ep_rew_mean          | 328       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 52        |
# |    time_elapsed         | 3643      |
# |    total_timesteps      | 475696    |
# | train/                  |           |
# |    approx_kl            | 0.7307685 |
# |    clip_fraction        | 0.67      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.857    |
# |    explained_variance   | 0.431     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.116    |
# |    n_updates            | 561       |
# |    policy_gradient_loss | -0.094    |
# |    value_loss           | 0.0569    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 614        |
# |    ep_rew_mean          | 331        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 53         |
# |    time_elapsed         | 3715       |
# |    total_timesteps      | 484844     |
# | train/                  |            |
# |    approx_kl            | 0.77572227 |
# |    clip_fraction        | 0.67       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.84      |
# |    explained_variance   | 0.45       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.115     |
# |    n_updates            | 572        |
# |    policy_gradient_loss | -0.0964    |
# |    value_loss           | 0.0579     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 626      |
# |    ep_rew_mean          | 333      |
# | time/                   |          |
# |    fps                  | 130      |
# |    iterations           | 54       |
# |    time_elapsed         | 3786     |
# |    total_timesteps      | 493992   |
# | train/                  |          |
# |    approx_kl            | 0.83173  |
# |    clip_fraction        | 0.662    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.843   |
# |    explained_variance   | 0.456    |
# |    learning_rate        | 0.000363 |
# |    loss                 | -0.125   |
# |    n_updates            | 583      |
# |    policy_gradient_loss | -0.0957  |
# |    value_loss           | 0.0581   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 574       |
# |    ep_rew_mean          | 302       |
# | time/                   |           |
# |    fps                  | 130       |
# |    iterations           | 55        |
# |    time_elapsed         | 3857      |
# |    total_timesteps      | 503140    |
# | train/                  |           |
# |    approx_kl            | 0.7504169 |
# |    clip_fraction        | 0.658     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.836    |
# |    explained_variance   | 0.508     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.125    |
# |    n_updates            | 594       |
# |    policy_gradient_loss | -0.0933   |
# |    value_loss           | 0.0574    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 572        |
# |    ep_rew_mean          | 307        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 56         |
# |    time_elapsed         | 3928       |
# |    total_timesteps      | 512288     |
# | train/                  |            |
# |    approx_kl            | 0.70890754 |
# |    clip_fraction        | 0.643      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.847     |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0948    |
# |    n_updates            | 605        |
# |    policy_gradient_loss | -0.092     |
# |    value_loss           | 0.0534     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 625        |
# |    ep_rew_mean          | 330        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 57         |
# |    time_elapsed         | 3998       |
# |    total_timesteps      | 521436     |
# | train/                  |            |
# |    approx_kl            | 0.80843776 |
# |    clip_fraction        | 0.652      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.844     |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.11      |
# |    n_updates            | 616        |
# ...
# |    iterations           | 529       |
# |    time_elapsed         | 38551     |
# |    total_timesteps      | 4839292   |
# | train/                  |           |
# |    approx_kl            | 0.5632158 |
# |    clip_fraction        | 0.399     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.437    |
# |    explained_variance   | 0.72      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0303   |
# |    n_updates            | 5808      |
# |    policy_gradient_loss | -0.055    |
# |    value_loss           | 0.0808    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 645        |
# |    ep_rew_mean          | 389        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 530        |
# |    time_elapsed         | 38624      |
# |    total_timesteps      | 4848440    |
# | train/                  |            |
# |    approx_kl            | 0.56189626 |
# |    clip_fraction        | 0.402      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.434     |
# |    explained_variance   | 0.71       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.025     |
# |    n_updates            | 5819       |
# |    policy_gradient_loss | -0.0506    |
# |    value_loss           | 0.0843     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 648        |
# |    ep_rew_mean          | 391        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 531        |
# |    time_elapsed         | 38697      |
# |    total_timesteps      | 4857588    |
# | train/                  |            |
# |    approx_kl            | 0.60614645 |
# |    clip_fraction        | 0.407      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.45      |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0344    |
# |    n_updates            | 5830       |
# |    policy_gradient_loss | -0.0553    |
# |    value_loss           | 0.0837     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 652        |
# |    ep_rew_mean          | 398        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 532        |
# |    time_elapsed         | 38770      |
# |    total_timesteps      | 4866736    |
# | train/                  |            |
# |    approx_kl            | 0.52345777 |
# |    clip_fraction        | 0.392      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.429     |
# |    explained_variance   | 0.706      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0463    |
# |    n_updates            | 5841       |
# |    policy_gradient_loss | -0.052     |
# |    value_loss           | 0.0853     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 673       |
# |    ep_rew_mean          | 407       |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 533       |
# |    time_elapsed         | 38845     |
# |    total_timesteps      | 4875884   |
# | train/                  |           |
# |    approx_kl            | 0.5467744 |
# |    clip_fraction        | 0.407     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.439    |
# |    explained_variance   | 0.687     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0462   |
# |    n_updates            | 5852      |
# |    policy_gradient_loss | -0.0542   |
# |    value_loss           | 0.0884    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 646        |
# |    ep_rew_mean          | 397        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 534        |
# |    time_elapsed         | 38918      |
# |    total_timesteps      | 4885032    |
# | train/                  |            |
# |    approx_kl            | 0.63040054 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.44      |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0657    |
# |    n_updates            | 5863       |
# |    policy_gradient_loss | -0.0516    |
# |    value_loss           | 0.0859     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 622       |
# |    ep_rew_mean          | 373       |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 535       |
# |    time_elapsed         | 38991     |
# |    total_timesteps      | 4894180   |
# | train/                  |           |
# |    approx_kl            | 0.6497566 |
# |    clip_fraction        | 0.415     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.45     |
# |    explained_variance   | 0.708     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0251   |
# |    n_updates            | 5874      |
# |    policy_gradient_loss | -0.0539   |
# |    value_loss           | 0.0824    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 631        |
# |    ep_rew_mean          | 368        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 536        |
# |    time_elapsed         | 39064      |
# |    total_timesteps      | 4903328    |
# | train/                  |            |
# |    approx_kl            | 0.64213145 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.444     |
# |    explained_variance   | 0.68       |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.022     |
# |    n_updates            | 5885       |
# |    policy_gradient_loss | -0.0535    |
# |    value_loss           | 0.0856     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 640       |
# |    ep_rew_mean          | 373       |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 537       |
# |    time_elapsed         | 39138     |
# |    total_timesteps      | 4912476   |
# | train/                  |           |
# |    approx_kl            | 0.5865565 |
# |    clip_fraction        | 0.424     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.452    |
# |    explained_variance   | 0.697     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0501   |
# |    n_updates            | 5896      |
# |    policy_gradient_loss | -0.0555   |
# |    value_loss           | 0.0808    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 591        |
# |    ep_rew_mean          | 334        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 538        |
# |    time_elapsed         | 39211      |
# |    total_timesteps      | 4921624    |
# | train/                  |            |
# |    approx_kl            | 0.60125095 |
# |    clip_fraction        | 0.416      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.452     |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0713    |
# |    n_updates            | 5907       |
# |    policy_gradient_loss | -0.0565    |
# |    value_loss           | 0.083      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 611        |
# |    ep_rew_mean          | 343        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 539        |
# |    time_elapsed         | 39284      |
# |    total_timesteps      | 4930772    |
# | train/                  |            |
# |    approx_kl            | 0.72726035 |
# |    clip_fraction        | 0.41       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.455     |
# |    explained_variance   | 0.695      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0497    |
# |    n_updates            | 5918       |
# |    policy_gradient_loss | -0.0531    |
# |    value_loss           | 0.0841     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 662        |
# |    ep_rew_mean          | 408        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 540        |
# |    time_elapsed         | 39357      |
# |    total_timesteps      | 4939920    |
# | train/                  |            |
# |    approx_kl            | 0.56479466 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.433     |
# |    explained_variance   | 0.691      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.00867   |
# |    n_updates            | 5929       |
# |    policy_gradient_loss | -0.0516    |
# |    value_loss           | 0.0858     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 597        |
# |    ep_rew_mean          | 356        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 541        |
# |    time_elapsed         | 39430      |
# |    total_timesteps      | 4949068    |
# | train/                  |            |
# |    approx_kl            | 0.52264243 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.428     |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0277    |
# |    n_updates            | 5940       |
# |    policy_gradient_loss | -0.0547    |
# |    value_loss           | 0.0825     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 598        |
# |    ep_rew_mean          | 348        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 542        |
# |    time_elapsed         | 39504      |
# |    total_timesteps      | 4958216    |
# | train/                  |            |
# |    approx_kl            | 0.59832174 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.438     |
# |    explained_variance   | 0.715      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0493    |
# |    n_updates            | 5951       |
# |    policy_gradient_loss | -0.0525    |
# |    value_loss           | 0.0844     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 373       |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 543       |
# |    time_elapsed         | 39576     |
# |    total_timesteps      | 4967364   |
# | train/                  |           |
# |    approx_kl            | 0.5698437 |
# |    clip_fraction        | 0.416     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.46     |
# |    explained_variance   | 0.715     |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0733   |
# |    n_updates            | 5962      |
# |    policy_gradient_loss | -0.0539   |
# |    value_loss           | 0.0822    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 637        |
# |    ep_rew_mean          | 367        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 544        |
# |    time_elapsed         | 39649      |
# |    total_timesteps      | 4976512    |
# | train/                  |            |
# |    approx_kl            | 0.57728904 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.446     |
# |    explained_variance   | 0.717      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0659    |
# |    n_updates            | 5973       |
# |    policy_gradient_loss | -0.0551    |
# |    value_loss           | 0.08       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 613       |
# |    ep_rew_mean          | 358       |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 545       |
# |    time_elapsed         | 39723     |
# |    total_timesteps      | 4985660   |
# | train/                  |           |
# |    approx_kl            | 0.5310024 |
# |    clip_fraction        | 0.408     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.448    |
# |    explained_variance   | 0.72      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0556   |
# |    n_updates            | 5984      |
# |    policy_gradient_loss | -0.0511   |
# |    value_loss           | 0.0808    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 624       |
# |    ep_rew_mean          | 366       |
# | time/                   |           |
# |    fps                  | 125       |
# |    iterations           | 546       |
# |    time_elapsed         | 39796     |
# |    total_timesteps      | 4994808   |
# | train/                  |           |
# |    approx_kl            | 0.6326813 |
# |    clip_fraction        | 0.411     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.439    |
# |    explained_variance   | 0.71      |
# |    learning_rate        | 0.000363  |
# |    loss                 | -0.0536   |
# |    n_updates            | 5995      |
# |    policy_gradient_loss | -0.0555   |
# |    value_loss           | 0.0826    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 627        |
# |    ep_rew_mean          | 350        |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 547        |
# |    time_elapsed         | 39870      |
# |    total_timesteps      | 5003956    |
# | train/                  |            |
# |    approx_kl            | 0.58682275 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.447     |
# |    explained_variance   | 0.694      |
# |    learning_rate        | 0.000363   |
# |    loss                 | -0.0573    |
# |    n_updates            | 6006       |
# |    policy_gradient_loss | -0.0552    |
# |    value_loss           | 0.0831     |
# ----------------------------------------
